# %% [markdown]
# <a href="https://mybinder.org/badge_logo.svg)](https://play-sydney.neurodesk.org/v2/gh/neurodesk/example-notebooks/main?labpath=%2Ffunctional_imaging%2Fnipype_fsl_first_level_flanker.ipynb" target="_parent"><img src="https://img.shields.io/badge/launch-binder-579aca.svg?logo=data:image/png;base64,..." alt="Open In Binder"/>  </a>
# <a href="https://colab.research.google.com/github/NeuroDesk/example-notebooks/blob/main/functional_imaging/nipype_fsl_first_level_flanker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>   </a>

# %% [markdown]
# Author: Monika Doerig
#
# Original peper: https://www.frontiersin.org/articles/10.3389/fnimg.2022.953215/full
#
# Original code: https://osf.io/prg53/?view_only=9d7974834a484cdb972bcc3989589b78

# %% [markdown]
# ## Setup Neurodesk

# %%
# %%capture
import os
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  os.environ["LD_PRELOAD"] = "";
  os.environ["APPTAINER_BINDPATH"] = "/content"
  os.environ["MPLCONFIGDIR"] = "/content/matplotlib-mpldir"
  os.environ["LMOD_CMD"] = "/usr/share/lmod/lmod/libexec/lmod"

  # !curl -J -O https://raw.githubusercontent.com/NeuroDesk/neurocommand/main/googlecolab_setup.sh
  # !chmod +x googlecolab_setup.sh
  # !./googlecolab_setup.sh

  os.environ["MODULEPATH"] = ':'.join(map(str, list(map(lambda x: os.path.join(os.path.abspath('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/'), x),os.listdir('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/')))))

# %%
# %%capture
# !pip install pandas nilearn matplotlib

# %% [markdown]
# # First-level GLM using Nipype FSL
#
# In this notebook, we recreate the first-level GLM and the first level GLM of FSL GUI using nipype code. For each nipype node, we list the corresponding fsl command from the log file. The dataset we use is a Flanker task, which can be downloaded [here](https://openneuro.org/datasets/ds000102/versions/00001).
#
# We also borrow some helps from this [document](https://nipype.readthedocs.io/en/latest/users/examples/fmri_fsl.html).

# %%
#load fsl module
import lmod
await lmod.purge(force=True)
await lmod.load('fsl/6.0.5.1') #Original pipeline: FSL 6.0.4, nipype 1.6.1.
await lmod.list()
# Out:
# ['fsl/6.0.5.1']

# %%
import os
os.environ["FSLDIR"]="/cvmfs/neurodesk.ardc.edu.au/containers/fsl_6.0.5.1_20221016/fsl_6.0.5.1_20221016.simg/opt/fsl-6.0.5.1/"
os.environ["FSLOUTPUTTYPE"]="NIFTI_GZ"
os.environ["SINGULARITY_BINDPATH"]="/data,/neurodesktop-storage,/tmp,/cvmfs"

# %% [markdown]
# ## Preparation
# Import all the relevant libraries needed for the preprocessing stage.

# %%
from __future__ import print_function
from __future__ import division
from builtins import str
from builtins import range

from glob import glob

from nipype import Function
from nipype.interfaces import fsl, utility as util, io as nio
import nipype.pipeline.engine as pe  # pypeline engine
import nipype.algorithms.modelgen as model  # model generation
import nipype.algorithms.rapidart as ra  # artifact detection
import matplotlib.pyplot as plt

import nilearn
from nilearn import surface
from nilearn import plotting

# %%
# check output type and fsl version
print(fsl.Info.output_type())
print(fsl.Info.version())
# Out:
# NIFTI_GZ
# 6.0.5.1:57b01774

# %% [markdown]
# #### Set up data path

# %%
# Input: Set the BIDS path
base_dir = '/neurodesktop-storage/Data/Flanker'
data_dir_first = '/neurodesktop-storage/Data/Flanker/ds000102'
# Output: Set path where nipype will store stepwise results
exp_dir_first = '/neurodesktop-storage/Data/Flanker/output_level1'

# Input: Set path of first level outputs
data_dir_second = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/'
# Output: Set path where nipype will store stepwise results
exp_dir_second = '/neurodesktop-storage/Data/Flanker/output_level2/'

# Input: Set path of second level outputs
data_dir_third = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/'
# Output: Set path where nipype will store stepwise results
exp_dir_third = '/neurodesktop-storage/Data/Flanker/output_level3/'

PATTERN = "sub-0*"
# Check if the directory exists, otherwise create it
if not os.path.exists(base_dir):
    os.makedirs(base_dir)
# !cd $base_dir && datalad install https://github.com/OpenNeuroDatasets/ds000102.git && cd $data_dir_first && datalad get $PATTERN && chmod a+rw $base_dir -R
# Out:
# Total:   0%|                                    | 0.00/345M [00:00<?, ? Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   0%|            | 0.00/10.7M [00:00<?, ? Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   0%|   | 15.9k/10.7M [00:00<02:17, 78.0k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   0%|   | 32.2k/10.7M [00:00<03:19, 53.7k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   0%|   | 49.6k/10.7M [00:01<04:48, 37.0k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   1%|   | 67.1k/10.7M [00:01<04:03, 43.7k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   1%|    | 102k/10.7M [00:01<02:14, 79.2k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   1%|    | 119k/10.7M [00:01<02:23, 73.8k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   1%|    | 137k/10.7M [00:02<02:14, 78.5k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   1%|    | 154k/10.7M [00:02<02:15, 77.7k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   2%|    | 172k/10.7M [00:02<02:16, 77.1k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   2%|    | 189k/10.7M [00:03<03:20, 52.6k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   2%|     | 241k/10.7M [00:03<01:40, 104k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   3%|▏    | 276k/10.7M [00:03<01:36, 108k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   3%|▏    | 293k/10.7M [00:03<01:36, 108k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   3%|▏    | 311k/10.7M [00:03<01:34, 111k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   4%|▏    | 380k/10.7M [00:03<00:49, 208k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   4%|▏    | 415k/10.7M [00:04<00:57, 180k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   4%|▏    | 450k/10.7M [00:04<00:58, 175k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   5%|▏    | 520k/10.7M [00:04<00:48, 211k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   5%|▎    | 589k/10.7M [00:04<00:46, 217k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   6%|▎    | 694k/10.7M [00:05<00:30, 333k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   7%|▎    | 746k/10.7M [00:05<00:28, 354k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:   8%|▍    | 868k/10.7M [00:05<00:32, 300k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  10%|▍   | 1.06M/10.7M [00:05<00:18, 512k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  12%|▍   | 1.23M/10.7M [00:06<00:19, 475k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  13%|▌   | 1.41M/10.7M [00:06<00:18, 508k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  15%|▌   | 1.56M/10.7M [00:06<00:16, 572k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  17%|▋   | 1.77M/10.7M [00:07<00:14, 605k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  18%|▋   | 1.98M/10.7M [00:07<00:12, 719k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  21%|▊   | 2.23M/10.7M [00:07<00:11, 729k Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  24%|▋  | 2.56M/10.7M [00:07<00:07, 1.07M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  26%|▊  | 2.77M/10.7M [00:07<00:07, 1.06M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  29%|▊  | 3.06M/10.7M [00:08<00:07, 1.02M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  32%|▉  | 3.39M/10.7M [00:08<00:05, 1.24M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  35%|█  | 3.72M/10.7M [00:08<00:04, 1.54M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  38%|█▏ | 4.11M/10.7M [00:08<00:04, 1.60M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  42%|█▎ | 4.54M/10.7M [00:09<00:04, 1.34M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  46%|█▍ | 4.98M/10.7M [00:09<00:03, 1.66M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  51%|█▌ | 5.46M/10.7M [00:09<00:03, 1.52M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  56%|█▋ | 5.99M/10.7M [00:09<00:02, 2.02M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  61%|█▊ | 6.53M/10.7M [00:10<00:02, 1.70M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  70%|██ | 7.54M/10.7M [00:10<00:01, 2.82M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  79%|██▎| 8.42M/10.7M [00:10<00:00, 2.84M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  83%|██▍| 8.85M/10.7M [00:10<00:00, 2.64M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  89%|██▋| 9.54M/10.7M [00:10<00:00, 2.88M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  93%|██▊| 9.91M/10.7M [00:11<00:00, 2.46M Bytes/s]
# Get sub-07/a .. 7_T1w.nii.gz:  96%|██▉| 10.3M/10.7M [00:11<00:00, 2.71M Bytes/s]
# Total:   3%|▊                           | 10.7M/345M [00:13<06:56, 804k Bytes/s]
# Get sub-07/f .. _bold.nii.gz:   0%|            | 0.00/28.9M [00:00<?, ? Bytes/s]
# Get sub-07/f .. _bold.nii.gz:   3%|    | 877k/28.9M [00:00<00:03, 7.96M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:   6%|▏  | 1.74M/28.9M [00:00<00:07, 3.86M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:   8%|▏  | 2.30M/28.9M [00:00<00:08, 3.11M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  10%|▎  | 2.90M/28.9M [00:00<00:08, 3.07M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  13%|▍  | 3.66M/28.9M [00:01<00:08, 3.07M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  14%|▍  | 4.08M/28.9M [00:01<00:08, 3.03M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  16%|▍  | 4.61M/28.9M [00:01<00:08, 2.95M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  19%|▌  | 5.51M/28.9M [00:02<00:11, 1.98M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  20%|▌  | 5.88M/28.9M [00:02<00:10, 2.14M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  22%|▋  | 6.24M/28.9M [00:02<00:11, 2.01M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  23%|▋  | 6.56M/28.9M [00:02<00:14, 1.54M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  24%|▋  | 7.00M/28.9M [00:02<00:11, 1.91M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  26%|▊  | 7.57M/28.9M [00:03<00:08, 2.40M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  27%|▊  | 7.92M/28.9M [00:03<00:08, 2.38M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  29%|▊  | 8.42M/28.9M [00:03<00:08, 2.40M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  30%|▉  | 8.73M/28.9M [00:03<00:08, 2.52M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  31%|▉  | 9.05M/28.9M [00:03<00:08, 2.44M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  34%|█  | 9.70M/28.9M [00:03<00:07, 2.51M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  35%|█  | 10.2M/28.9M [00:04<00:07, 2.53M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  36%|█  | 10.5M/28.9M [00:04<00:07, 2.57M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  37%|█  | 10.8M/28.9M [00:04<00:07, 2.49M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  38%|█▏ | 11.1M/28.9M [00:04<00:06, 2.55M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  39%|█▏ | 11.4M/28.9M [00:04<00:06, 2.56M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  41%|█▏ | 11.9M/28.9M [00:04<00:06, 2.58M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  43%|█▎ | 12.4M/28.9M [00:04<00:05, 2.95M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  44%|█▎ | 12.9M/28.9M [00:05<00:06, 2.42M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  46%|█▎ | 13.2M/28.9M [00:05<00:08, 1.84M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  50%|█▌ | 14.5M/28.9M [00:05<00:06, 2.31M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  52%|█▌ | 15.1M/28.9M [00:06<00:05, 2.55M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:  53%|█▌ | 15.4M/28.9M [00:06<00:06, 2.21M Bytes/s]
# Get sub-07/f .. _bold.nii.gz:
Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  89%|██▋| 25.7M/28.8M [00:17<00:02, 1.24M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  90%|██▋| 25.9M/28.8M [00:17<00:02, 1.35M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  91%|██▋| 26.1M/28.8M [00:18<00:02, 1.27M Bytes/s]
# Total:  92%|█████████████████████████▋  | 317M/345M [03:00<00:16, 1.76M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  93%|██▊| 26.6M/28.8M [00:18<00:01, 1.60M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  94%|██▊| 27.0M/28.8M [00:18<00:01, 1.49M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  95%|██▊| 27.3M/28.8M [00:18<00:01, 1.46M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  95%|██▊| 27.4M/28.8M [00:18<00:00, 1.39M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  97%|██▉| 28.0M/28.8M [00:19<00:00, 1.21M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  98%|██▉| 28.2M/28.8M [00:19<00:00, 1.27M Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  99%|███▉| 28.4M/28.8M [00:19<00:00, 999k Bytes/s]
# Get sub-03/f .. _bold.nii.gz:  99%|███▉| 28.5M/28.8M [00:20<00:00, 820k Bytes/s]
# Get sub-03/f .. _bold.nii.gz: 100%|██▉| 28.8M/28.8M [00:20<00:00, 1.08M Bytes/s]
# get(ok): sub-07/anat/sub-07_T1w.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-07/func/sub-07_task-flanker_run-1_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-07/func/sub-07_task-flanker_run-2_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-06/anat/sub-06_T1w.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-06/func/sub-06_task-flanker_run-1_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-06/func/sub-06_task-flanker_run-2_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-05/anat/sub-05_T1w.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-05/func/sub-05_task-flanker_run-1_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-05/func/sub-05_task-flanker_run-2_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/anat/sub-02_T1w.nii.gz (file) [from s3-PUBLIC...]
#   [5 similar messages have been suppressed; disable with datalad.ui.suppress-similar-results=off]
# get(ok): sub-07 (directory)
# get(ok): sub-06 (directory)
# get(ok): sub-05 (directory)
# get(ok): sub-02 (directory)
# get(ok): sub-03 (directory)
# action summary:
#   get (notneeded: 4, ok: 20)

# %% [markdown]
# #### Start the workflow

# %%
wf_first = pe.Workflow(name='level1', base_dir=exp_dir_first)
wf_first.config["execution"]["crashfile_format"] = "txt"

# %% [markdown]
# The following two nodes (`infosource` & `dg`) together define all inputs required for the preprocessing workflow

# %%
# get subject_id list
subj_list = [x.split('-')[-1] for x in glob(data_dir_first+"/"+PATTERN)]
subj_list.sort()
print(subj_list)
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09']

# %%
infosource_first = pe.Node(util.IdentityInterface(fields=["subject_id"]),
                  name="infosource")
infosource_first.iterables = [("subject_id", subj_list)]

# %%
dg_first = pe.Node(
    interface=nio.DataGrabber(
        infields=["subject_id","run_id"], outfields=["struct", "func", "events"]
    ),
    name="dg_first"
)

# Specify run_ids and return a sorted filelist to ensure we match files to correct runs/tasks
dg_first.inputs.run_id = [1,2]
dg_first.inputs.sort_filelist = True
dg_first.inputs.template = "*"
dg_first.inputs.base_directory = data_dir_first

# Define arguments fill the wildcards in the below paths 
dg_first.inputs.template_args = dict(
    struct=[["subject_id","subject_id"]],
    func=[["subject_id","subject_id","run_id"]],
    events=[["subject_id","subject_id","run_id"]]
)

dg_first.inputs.field_template = dict(
    struct = "sub-%s/anat/sub-%s_T1w.nii.gz",
    func="sub-%s/func/sub-%s_task-flanker_run-%d_bold.nii.gz",
    events="sub-%s/func/sub-%s_task-flanker_run-%d_events.tsv", 
)

wf_first.connect([
        (infosource_first, dg_first, [("subject_id", "subject_id")])
])

# %% [markdown]
# ## Initialisation

# %% [markdown]
# Convert functional images to float representation. Since there can be more than one functional run we use a MapNode to convert each run.
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths ../sub-11/func/sub-11_task-flanker_run-1_bold prefiltered_func_data -odt float
# ```

# %%
img2float = pe.MapNode(
    interface=fsl.ImageMaths(out_data_type='float', op_string='', suffix='_dtype'),
    name='img2float',
    iterfield=['in_file'])
wf_first.connect(dg_first, 'func', img2float, 'in_file')

# %% [markdown]
# Extract the middle volume of the first run as the reference
#
# (Head movement, motion-correction)
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslroi prefiltered_func_data example_func 73 1
# ```

# %%
# Extract one roi
extract_ref = pe.MapNode(interface=fsl.ExtractROI(t_size=1), 
                         name='extractref',
                         iterfield=['in_file'])
wf_first.connect(img2float, 'out_file', extract_ref, 'in_file')

# Define a function to return the 1 based index of the middle volume
def getmiddlevolume(func):
    from nibabel import load
    funcfile = func
    if isinstance(func, list):
        funcfile = func[0]
    _, _, _, timepoints = load(funcfile).shape
    return int(timepoints/2) 

wf_first.connect(img2float, ('out_file', getmiddlevolume), extract_ref, 't_min')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Motion Correction

# %% [markdown]
# Realign the functional runs to the middle volume of each run
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/mcflirt -in prefiltered_func_data -out prefiltered_func_data_mcf -mats -plots -reffile example_func -rmsrel -rmsabs -spline_final
# ```
#
# ```
# save_mats (a boolean) – Save transformation matrices. Maps to a command-line argument: -mats.
# save_plots (a boolean) – Save transformation parameters. Maps to a command-line argument: -plots.
# save_rms (a boolean) – Save rms displacement parameters. Maps to a command-line argument: -rmsabs -rmsrel.
# Interpolation (‘spline’ or ‘nn’ or ‘sinc’) – Interpolation method for transformation. Maps to a command-line argument: -%s_final.
# ```

# %%
motion_correct = pe.MapNode(
    interface=fsl.MCFLIRT(save_mats=True, save_plots=True, save_rms=True, interpolation='spline'),
    name='realign',
    iterfield=['in_file','ref_file'])
wf_first.connect(img2float, 'out_file', motion_correct, 'in_file')
wf_first.connect(extract_ref, 'roi_file', motion_correct, 'ref_file')

# %% [markdown]
# Plot the estimated motion parameters
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fsl_tsplot -i prefiltered_func_data_mcf.par -t 'MCFLIRT estimated rotations (radians)' -u 1 --start=1 --finish=3 -a x,y,z -w 640 -h 144 -o rot.png
#
# /usr/local/fsl/bin/fsl_tsplot -i prefiltered_func_data_mcf.par -t 'MCFLIRT estimated translations (mm)' -u 1 --start=4 --finish=6 -a x,y,z -w 640 -h 144 -o trans.png
#
# /usr/local/fsl/bin/fsl_tsplot -i prefiltered_func_data_mcf_abs.rms,prefiltered_func_data_mcf_rel.rms -t 'MCFLIRT estimated mean displacement (mm)' -u 1 -w 640 -h 144 -a absolute,relative -o disp.png
# ```

# %%
plot_motion = pe.MapNode(
    interface=fsl.PlotMotionParams(in_source='fsl'),
    name='plot_motion',
    iterfield=['in_file'])
plot_motion.iterables = ('plot_type', ['rotations', 'translations','displacement'])
wf_first.connect(motion_correct, 'par_file', plot_motion, 'in_file')

# %% [markdown]
# ### Functionally Masking
#
# ```
# Passing the reference volume to the FSL command-line tool bet to generate a binary brain mask and afterward multiplying the processed functional time series by the brain mask using the fslmaths command to produce a skull-stripped time series.
# ```
#
# See [Ciric et al.(2018)](https://www.nature.com/articles/s41596-018-0065-y#Sec24)

# %% [markdown]
# Extract the mean volume of each functional run
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_mcf -Tmean mean_func
# ```

# %%
meanfunc = pe.MapNode(
    interface=fsl.ImageMaths(op_string='-Tmean', suffix='_mean'),
    name='meanfunc',
    iterfield=['in_file'])
wf_first.connect(motion_correct, 'out_file', meanfunc, 'in_file')

# %% [markdown]
# Strip the skull from the mean functional to generate a mask
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/bet2 mean_func mask -f 0.3 -n -m; /usr/local/fsl/bin/immv mask_mask mask
# ```

# %%
meanfuncmask = pe.MapNode(
    interface=fsl.BET(mask=True, no_output=True, frac=0.3),
    name='meanfuncmask',
    iterfield=['in_file'])
wf_first.connect(meanfunc, 'out_file', meanfuncmask, 'in_file')

# %% [markdown]
# Mask the functional data with the extracted mask
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_mcf -mas mask prefiltered_func_data_bet
# ```

# %%
maskfunc = pe.MapNode(
    interface=fsl.ImageMaths(suffix='_bet', op_string='-mas'),
    name='maskfunc',
    iterfield=['in_file','in_file2'])
wf_first.connect(motion_correct, 'out_file', maskfunc, 'in_file')
wf_first.connect(meanfuncmask, 'mask_file', maskfunc, 'in_file2')

# %% [markdown]
# ### Grand Mean Scaling

# %% [markdown]
# Determine the 2nd and 98th percentile intensities
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslstats prefiltered_func_data_bet -p 2 -p 98
# 0.000000 873.492249 (these numbers are for subject-11 run-01)
# ```
#
# More info [here](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/Fslutils#fslstats)

# %%
getthresh = pe.MapNode(
    interface=fsl.ImageStats(op_string='-p 2 -p 98'),
    name='getthreshold',
    iterfield=['in_file'])
wf_first.connect(maskfunc, 'out_file', getthresh, 'in_file')

# %% [markdown]
# Threshold the first TR of the functional data at 10% of the 98th percentile
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_bet -thr 87.3492249 -Tmin -bin mask -odt char
# ```

# %%
threshold = pe.MapNode(
    interface=fsl.ImageMaths(out_data_type='char', suffix='_thresh'),
    name='threshold',
    iterfield=['in_file','op_string'])
wf_first.connect(maskfunc, 'out_file', threshold, 'in_file')

# Define a function to get 10% of the intensity
def getthreshop(thresh):
    return ['-thr %.10f -Tmin -bin' % (0.1 * th[1]) for th in thresh]

wf_first.connect(getthresh, ('out_stat', getthreshop), threshold, 'op_string')

# %% [markdown]
# Determine the median value of the TRs using the mask
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslstats prefiltered_func_data_mcf -k mask -p 50
# 728.800232 (this number is for subject-11 run-01)
# ```

# %%
medianval = pe.MapNode(
    interface=fsl.ImageStats(op_string='-k %s -p 50'),
    name='medianval',
    iterfield=['in_file','mask_file'])
wf_first.connect(motion_correct, 'out_file', medianval, 'in_file')
wf_first.connect(threshold, 'out_file', medianval, 'mask_file')

# %% [markdown]
# Dilate the mask
#
# The brain mask is "dilated" slightly before being used. Because it is normally important that masking be liberal (ie that there be little risk of cutting out valid brain voxels)

# %% [markdown]
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths mask -dilF mask
# ```
#
# The output of `dilatemask` (i.e., `/srv/scratch/yc/fsl/hw2/level1/_subject_id_26/dilatemask/mapflow/_dilatemask0/sub-26_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil.nii.gz`) is equivalent to `mask.nii.gz` from FSL GUI.

# %%
dilatemask = pe.MapNode(
    interface=fsl.ImageMaths(suffix='_dil', op_string='-dilF'),
    name='dilatemask',
    iterfield=['in_file'])
wf_first.connect(threshold, 'out_file', dilatemask, 'in_file')

# %% [markdown]
# Mask the motion corrected functional runs with the dilated mask
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_mcf -mas mask prefiltered_func_data_thresh
# ```

# %%
maskfunc2 = pe.MapNode(
    interface=fsl.ImageMaths(suffix='_thresh', op_string='-mas'),
    iterfield=['in_file','in_file2'],
    name='maskfunc2')
wf_first.connect(motion_correct, 'out_file', maskfunc2, 'in_file')
wf_first.connect(dilatemask, 'out_file', maskfunc2, 'in_file2')

# %% [markdown]
# ### SUSAN Noise Reduction

# %% [markdown]
# Determine the mean image from each TR
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_thresh -Tmean mean_func
# ```

# %%
meanfunc2 = pe.MapNode(
    interface=fsl.ImageMaths(op_string='-Tmean', suffix='_mean'),
    name='meanfunc2',
    iterfield=['in_file'])
wf_first.connect(maskfunc2, 'out_file', meanfunc2, 'in_file')

# %% [markdown]
# Merge the median values with the mean functional images into a coupled list
#
# The output of this `merge` node will go into `susan` as `usans`,

# %%
# why here use node not mapnode?
mergenode = pe.Node(interface=util.Merge(2, axis='hstack'), 
                       name='merge')
wf_first.connect(meanfunc2, 'out_file', mergenode, 'in1')
wf_first.connect(medianval, 'out_stat', mergenode, 'in2')

# %% [markdown]
# Smooth each run using SUSAN with the brightness threshold set to 75% of the median value for each run and a mask constituting the mean functional
#
# ```
# Usage: susan <input> <bt> <dt> <dim> <use_median> <n_usans> [<usan1> <bt1> [<usan2> <bt2>]] <output>
# <bt> is brightness threshold and should be greater than noise level and less than contrast of edges to be preserved.
# <dt> is spatial size (sigma, i.e., half-width) of smoothing, in mm.
# <dim> is dimensionality (2 or 3), depending on whether smoothing is to be within-plane (2) or fully 3D (3).
# <use_median> determines whether to use a local median filter in the cases where single-point noise is detected (0 or 1).
# <n_usans> determines whether the smoothing area (USAN) is to be found from secondary images (0, 1 or 2).
# A negative value for any brightness threshold will auto-set the threshold at 10% of the robust range
# ```
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/susan prefiltered_func_data_thresh 546.600174 2.12314225053 3 1 1 mean_func 546.600174 prefiltered_func_data_smooth
# ```
#
# **Note:**
#
# for `<bt>`, Nipype uses a different algorithm to calculate it -> `float(fwhm) / np.sqrt(8 * np.log(2))`. Therefore, to get `2.12314225053`, fwhm should be `4.9996179300001655` instead of `5`

# %%
fwhm_thr = 4.9996179300001655

smooth = pe.MapNode(
    interface=fsl.SUSAN(fwhm = fwhm_thr),
    name='smooth',
    iterfield=['in_file', 'brightness_threshold', 'usans'])

# Define a function to get the brightness threshold for SUSAN
def getbtthresh(medianvals):
    return [0.75 * val for val in medianvals]

def getusans(x):
    return [[tuple([val[0], 0.75 * val[1]])] for val in x]

wf_first.connect(maskfunc2, 'out_file', smooth, 'in_file')
wf_first.connect(medianval, ('out_stat', getbtthresh), smooth,
                'brightness_threshold')
wf_first.connect(mergenode, ('out', getusans), smooth, 'usans')

# %% [markdown]
# Mask the smoothed data with the dilated mask
#
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_smooth -mas mask prefiltered_func_data_smooth
# ```

# %%
maskfunc3 = pe.MapNode(
    interface=fsl.ImageMaths(op_string='-mas'),
    name='maskfunc3',
    iterfield=['in_file','in_file2'])
wf_first.connect(smooth, 'smoothed_file', maskfunc3, 'in_file')
wf_first.connect(dilatemask, 'out_file', maskfunc3, 'in_file2')

# %% [markdown]
# Scale each volume of the TR so that the median value of the TR is set to 10000
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_smooth -mul 13.7211811425 prefiltered_func_data_intnorm
# (this number is for subject-11 run-01)
# ```

# %%
intnorm = pe.MapNode(
    interface=fsl.ImageMaths(suffix='_intnorm'),
    iterfield=['in_file', 'op_string'],
    name='intnorm')
wf_first.connect(maskfunc3, 'out_file', intnorm, 'in_file')

# Define a function to get the scaling factor for intensity normalization
def getinormscale(medianvals):
    return ['-mul %.10f' % (10000. / val) for val in medianvals]

wf_first.connect(medianval, ('out_stat', getinormscale), intnorm, 'op_string')

# %% [markdown]
# ### Temporal Filtering

# %% [markdown]
# Perform temporal highpass filtering on the data
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_intnorm -Tmean tempMean
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_intnorm -bptf 25.0 -1 -add tempMean prefiltered_func_data_tempfilt
# ```
#
# The output of `highpass` (i.e., `sub-11_task-flanker_run-1_bold_dtype_mcf_mask_smooth_mask_intnorm_tempfilt.nii.gz`) is equivalent to `filtered_func_data.nii.gz` from FSL GUI.

# %%
# Generate a mean functional image from the scaled data and this mean func will be used in performing temporal highpass filtering
meanfunc3 = pe.MapNode(
    interface=fsl.ImageMaths(op_string='-Tmean'),
    iterfield=['in_file'],
    name='meanfunc3')
wf_first.connect(intnorm, 'out_file', meanfunc3, 'in_file')

# %%
# Perform temporal highpass filtering on the data
hpcutoff = 100
TR = 2.  # ensure float

highpass = pe.MapNode(
    interface=fsl.ImageMaths(suffix='_tempfilt'),
    name='highpass',
    iterfield=['in_file','op_string'])

# 25 = (hpcutoff / 2*TR) not (hpcutoff / TR)
def gethpstring(tempMean):
    return ['-bptf 25 -1 -add %s' % (tm) for tm in tempMean]

wf_first.connect(intnorm, 'out_file', highpass, 'in_file')
wf_first.connect(meanfunc3, ('out_file',gethpstring), highpass, 'op_string')

# %% [markdown]
# Generate a mean functional image from the functional run
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths prefiltered_func_data_tempfilt filtered_func_data
# /usr/local/fsl/bin/fslmaths filtered_func_data -Tmean mean_func
# ```

# %%
meanfunc4 = pe.MapNode(
    interface=fsl.ImageMaths(op_string='-Tmean', suffix='_mean'),
    iterfield=['in_file'],
    name='meanfunc4')
wf_first.connect(highpass, 'out_file', meanfunc4, 'in_file')

# %% [markdown]
# ## First-Level GLM

# %% [markdown]
# ### Get events

# %%
def subjinfo(events):
    from nipype.interfaces.base import Bunch
    import pandas as pd
    import numpy as np

    subject_info = []

    ev = pd.read_csv(events, sep="\t")
    ev = ev[ev['correctness']=='correct']
    ev['new_type'] = ev['trial_type'].apply(lambda x: str(x).split('_')[0])

    run_info = Bunch(onsets=[], 
                     durations=[])

    run_info.set(conditions=[g[0] for g in ev.groupby("new_type")])

    for group in ev.groupby("new_type"):
        run_info.onsets.append(group[1].onset.tolist())
        run_info.durations.append(group[1].duration.tolist())
    subject_info.append(run_info)

    return subject_info

get_sub_info = pe.MapNode(
    Function(
        function=subjinfo, input_names=["events"], output_names="subject_info"
    ),
    name="get_sub_info", iterfield=["events"]
)

# Connect to workflow
wf_first.connect(dg_first, 'events', get_sub_info, 'events')

# %% [markdown]
# ### Set-up contrasts

# %%
condition_names = ["congruent", "incongruent"]

# Activation Contrasts (similar to https://direct.mit.edu/jocn/article/23/10/3162/5327/Is-Morality-Unified-Evidence-that-Distinct-Neural)
## From FEAT: "The correct way to tell whether two conditions are significantly different is to run a differential contrast like [1 -1] between them"
cont01 = ("congruent", "T", condition_names,  [1, 0])
cont02 = ("incongruent", "T", condition_names, [0, 1])
cont03 = ("congruent-incongruent", "T", condition_names, [1, -1])
cont04 = ("incongruent-congruent", "T", condition_names,  [-1, 1])

contrast_list = [
    cont01,
    cont02,
    cont03,
    cont04
]

# %%
TR = 2.0  # Repetition Time
hpcutoff = 100  # highpass filter cutoff in seconds! 

modelspec = pe.MapNode(interface=model.SpecifyModel(), name="modelspec", iterfield=["subject_info","functional_runs"])
modelspec.inputs.input_units = "secs"
modelspec.inputs.high_pass_filter_cutoff = hpcutoff
modelspec.inputs.time_repetition = TR

wf_first.connect(get_sub_info, 'subject_info', modelspec,'subject_info')
wf_first.connect(highpass, 'out_file',modelspec,'functional_runs')

# %%
level1design = pe.MapNode(interface=fsl.Level1Design(), name="level1design", iterfield=["session_info"])
level1design.inputs.interscan_interval = TR
# Set HRF bases functions
level1design.inputs.bases = {"gamma": {"derivs": False, 'gammasigma':3, 'gammadelay':6}}
level1design.inputs.model_serial_correlations = True
level1design.inputs.contrasts = contrast_list

wf_first.connect(modelspec,'session_info', level1design, 'session_info')

# %%
modelgen = pe.MapNode(
    interface=fsl.FEATModel(),
    name='modelgen',
    iterfield=['fsf_file', 'ev_files'])

wf_first.connect([(level1design, modelgen, [('fsf_files', 'fsf_file'), 
                                    ('ev_files','ev_files')])])

# %% [markdown]
# **Corresponding fsl command:**
#
# ```
# /usr/local/fsl/bin/film_gls --in=filtered_func_data --rn=stats --pd=design.mat --thr=1000.0 --sa --ms=5 --con=design.con
#
# --thr: threshold
# --sa: smooth_autocorr
# --ms: mask_size
# ```

# %%
level1estimate = pe.MapNode(
    interface=fsl.FILMGLS(smooth_autocorr=True, mask_size=5, threshold=1000),
    name='level1estimate',
    iterfield=['design_file', 'in_file', 'tcon_file'])

wf_first.connect([
    (highpass,level1estimate,[('out_file','in_file')]),
    (modelgen,level1estimate,[('design_file','design_file'),
                               ('con_file','tcon_file')])
])

# %% [markdown]
# no need to use `ContrastMgr`,
#
# ```
# In interface mode this file assumes that all the required inputs are in the same location. This has deprecated for FSL versions 5.0.7+ as the necessary corrections file is no longer generated by FILMGLS.
# ```
# see this [link](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#contrastmgr)

# %% [markdown]
# ## Registration

# %% [markdown]
# According to [FSL UserGuide](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FEAT/UserGuide#Higher-Level_FEAT_Output), the different sessions need to be **registered** to each other before any multi-session or multi-subject analyses can be carried out. Registration inside FEAT uses `FLIRT` and is a two-statge process:
#
# 1. An example FMRI low resolution image is registered to an example high resolution image (normally the same subject's T1-weighted structural). The transformation for this is saved into the FEAT directory. Then the high res image is registered to a standard image (normally a T1-weighted image in standard space, such as the MNI 152 average image).
# 2. The two transformations are combined into a third, which will take the low resolution FMRI images (and the statistic images derived from the first-level analyses) straight into standard space, when applied later, during group analysis.

# %% [markdown]
# #### Step 1
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/flirt -in example_func -ref standard -out example_func2standard -omat example_func2standard.mat -cost corratio -dof 12 -searchrx -90 90 -searchry -90 90 -searchrz -90 90 -interp trilinear
#
# /usr/local/fsl/bin/convert_xfm -inverse -omat standard2example_func.mat example_func2standard.mat
# ```

# %%
flt = pe.MapNode(interface=fsl.FLIRT(cost='corratio', dof=12,
                                    searchr_x = [-90,90],
                                    searchr_y = [-90,90],
                                    searchr_z = [-90,90],
                                    interp = 'trilinear'), 
               name='example_func2standard',
               iterfield=['in_file'])

flt.inputs.reference = fsl.Info.standard_image('MNI152_T1_2mm_brain.nii.gz')
wf_first.connect(extract_ref, 'roi_file', flt, 'in_file')

convertxfm = pe.MapNode(interface=fsl.ConvertXFM(invert_xfm = True), 
                         name='convertxfm',
                         iterfield=['in_file'])
wf_first.connect(flt, 'out_matrix_file', convertxfm, 'in_file')

# %% [markdown]
# #### Step 2
#
# **Corresponding fsl command:**
#
# ```
# /usr/local/fsl/bin/flirt -ref reg/standard -in stats/cope1 -out /srv/scratch/yc/fsl/nipype_fsl_comp/gui/sub-01/run1.feat/frgrot_chksugax -applyxfm -init reg/example_func2standard.mat -interp trilinear -datatype float
# ```

# %%
def warp_files(copes, varcopes, masks, mat):
    # need to reimport here, otherwise errors come out
    import nipype.interfaces.fsl as fsl 
    
    out_copes = []
    out_varcopes = []
    out_masks = []
    
    # register mask, same function, different parameters
    warp_mask = fsl.FLIRT(apply_xfm = True, 
                     interp = 'nearestneighbour')
    warp_mask.inputs.reference = fsl.Info.standard_image('MNI152_T1_2mm_brain.nii.gz')
    warp_mask.inputs.in_matrix_file = mat
    warp_mask.inputs.output_type = "NIFTI_GZ"
    warp_mask.inputs.in_file = masks
    res_mask = warp_mask.run()
    out_masks.append(str(res_mask.outputs.out_file))
    
    # register copes & varcopes using same function, different parameters
    warp = fsl.FLIRT(apply_xfm = True, 
                     interp = 'trilinear')
    warp.inputs.reference = fsl.Info.standard_image('MNI152_T1_2mm_brain.nii.gz')
    warp.inputs.in_matrix_file = mat
    warp.inputs.output_type = "NIFTI_GZ"
    
    # register copes
    for cope in copes:
        warp.inputs.in_file = cope
        res = warp.run()
        out_copes.append(str(res.outputs.out_file))
        
     # register varcopes
    for varcope in varcopes:
        warp.inputs.in_file = varcope
        res = warp.run()
        out_varcopes.append(str(res.outputs.out_file))

    return out_copes, out_varcopes, out_masks

# %%
warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'masks', 'mat'],
                                    output_names=['out_copes', 'out_varcopes', 'out_masks'],
                                    function=warp_files),
                      iterfield=['copes', 'varcopes', 'masks','mat'],
                      name='warpfunc')

wf_first.connect(level1estimate, 'copes', warpfunc, 'copes')
wf_first.connect(level1estimate, 'varcopes', warpfunc, 'varcopes')
wf_first.connect(dilatemask, 'out_file', warpfunc, 'masks')
wf_first.connect(flt, 'out_matrix_file', warpfunc, 'mat')

# %%
# save all results into single/separate folder for further analysis use
datasink_first = pe.Node(nio.DataSink(), name='sinker')
datasink_first.inputs.base_directory=os.path.join(exp_dir_first, "level1_results")

wf_first.connect(infosource_first, 'subject_id', datasink_first, 'container')
wf_first.connect([(level1estimate, datasink_first, [('results_dir', 'results_dir')])])
wf_first.connect([(warpfunc, datasink_first, [('out_copes', 'reg_copes')])])
wf_first.connect([(warpfunc, datasink_first, [('out_varcopes', 'reg_varcopes')])])
wf_first.connect([(warpfunc, datasink_first, [('out_masks', 'reg_masks')])])

# %%
# Create 1st-level analysis output graph
wf_first.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=os.path.join(wf_first.base_dir, wf_first.name, 'graph.png'))
# Out:
# 230611-12:24:52,12 nipype.workflow INFO:
# 	 Generated workflow graph: /neurodesktop-storage/Data/Flanker/output_level1/level1/graph.png (graph2use=colored, simple_form=True).

# %%
# Run Workflow
wf_first.run(plugin="MultiProc", plugin_args={"n_procs": 8})
# Out:
# 230611-12:24:52,43 nipype.workflow INFO:
# 	 Workflow level1 settings: ['check', 'execution', 'logging', 'monitoring']
# 230611-12:24:52,179 nipype.workflow INFO:
# 	 Running in parallel.
# 230611-12:24:52,184 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:24:52,295 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_01/dg_first".
# 230611-12:24:52,298 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/dg_first".
# 230611-12:24:52,299 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,300 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/dg_first".
# 230611-12:24:52,303 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.001278s.
# 230611-12:24:52,302 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/dg_first".
# 230611-12:24:52,306 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,307 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,311 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.001356s.
# 230611-12:24:52,311 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,311 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.000956s.
# 230611-12:24:52,313 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/dg_first".
# 230611-12:24:52,314 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/dg_first".
# 230611-12:24:52,316 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.001398s.
# 230611-12:24:52,319 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,320 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,324 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.002202s.
# 230611-12:24:52,327 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.001001s.
# 230611-12:24:52,319 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/dg_first".
# 230611-12:24:52,320 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/dg_first".
# 230611-12:24:52,333 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,337 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.00129s.
# 230611-12:24:52,338 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:52,347 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.001377s.
# 230611-12:24:54,186 nipype.workflow INFO:
# 	 [Job 0] Completed (level1.dg_first).
# 230611-12:24:54,188 nipype.workflow INFO:
# 	 [Job 1] Completed (level1.dg_first).
# 230611-12:24:54,191 nipype.workflow INFO:
# 	 [Job 2] Completed (level1.dg_first).
# 230611-12:24:54,195 nipype.workflow INFO:
# 	 [Job 3] Completed (level1.dg_first).
# 230611-12:24:54,197 nipype.workflow INFO:
# 	 [Job 4] Completed (level1.dg_first).
# 230611-12:24:54,199 nipype.workflow INFO:
# 	 [Job 5] Completed (level1.dg_first).
# 230611-12:24:54,201 nipype.workflow INFO:
# 	 [Job 6] Completed (level1.dg_first).
# 230611-12:24:54,204 nipype.workflow INFO:
# 	 [Job 7] Completed (level1.dg_first).
# 230611-12:24:54,210 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 17 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:24:54,366 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.dg_first" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/dg_first".
# 230611-12:24:54,371 nipype.workflow INFO:
# 	 [Node] Executing "dg_first" <nipype.interfaces.io.DataGrabber>
# 230611-12:24:54,377 nipype.workflow INFO:
# 	 [Node] Finished "dg_first", elapsed time 0.000779s.
# 230611-12:24:56,190 nipype.workflow INFO:
# 	 [Job 8] Completed (level1.dg_first).
# 230611-12:24:56,199 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:24:56,306 nipype.workflow INFO:
# 	 [Job 288] Cached (_img2float0).
# 230611-12:24:56,309 nipype.workflow INFO:
# 	 [Job 289] Cached (_img2float1).
# 230611-12:24:56,311 nipype.workflow INFO:
# 	 [Job 290] Cached (_get_sub_info0).
# 230611-12:24:56,313 nipype.workflow INFO:
# 	 [Job 291] Cached (_get_sub_info1).
# 230611-12:24:56,316 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/img2float/mapflow/_img2float0".
# 230611-12:24:56,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/img2float/mapflow/_img2float1".
# 230611-12:24:56,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:24:56,318 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:24:56,320 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:24:56,320 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:24:56,320 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:24:56,321 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:24:56,344 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.020543s.
# 230611-12:24:56,344 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.020619s.
# 230611-12:24:58,191 nipype.workflow INFO:
# 	 [Job 294] Completed (_get_sub_info0).
# 230611-12:24:58,193 nipype.workflow INFO:
# 	 [Job 295] Completed (_get_sub_info1).
# 230611-12:24:58,196 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 31 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
# 230611-12:24:58,279 nipype.workflow INFO:
# 	 [Job 9] Cached (level1.img2float).
# 230611-12:24:58,282 nipype.workflow INFO:
# 	 [Job 10] Cached (level1.get_sub_info).
# 230611-12:24:58,288 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/img2float/mapflow/_img2float0".
# 230611-12:24:58,291 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:24:58,292 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:24:58,297 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:24:58,296 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:24:58,302 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:24:58,305 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:24:58,315 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:24:58,321 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.019817s.
# 230611-12:24:58,290 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/img2float/mapflow/_img2float1".
# 230611-12:24:58,326 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:24:58,330 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:24:58,331 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:00,194 nipype.workflow INFO:
# 	 [Job 12] Completed (level1.get_sub_info).
# 230611-12:25:00,195 nipype.workflow INFO:
# 	 [Job 298] Completed (_get_sub_info0).
# 230611-12:25:00,198 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 26 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:00,282 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:00,285 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/img2float/mapflow/_img2float1".
# 230611-12:25:00,284 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/img2float/mapflow/_img2float0".
# 230611-12:25:00,285 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:00,288 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:00,288 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:00,290 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:00,302 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.00782s.
# 230611-12:25:00,307 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:00,330 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.01434s.
# 230611-12:25:02,2 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 5.675496s.
# 230611-12:25:02,197 nipype.workflow INFO:
# 	 [Job 293] Completed (_img2float1).
# 230611-12:25:02,198 nipype.workflow INFO:
# 	 [Job 299] Completed (_get_sub_info1).
# 230611-12:25:02,199 nipype.workflow INFO:
# 	 [Job 302] Completed (_get_sub_info0).
# 230611-12:25:02,202 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 24 jobs ready. Free memory (GB): 16.40/17.40, Free processors: 3/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
#                        * _img2float0
# 230611-12:25:02,283 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:02,286 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:02,289 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:02,291 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/img2float/mapflow/_img2float0".
# 230611-12:25:02,295 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:02,292 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:02,290 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:02,306 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:02,308 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:02,311 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:02,320 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.006642s.
# 230611-12:25:02,782 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 6.459615s.
# 230611-12:25:04,199 nipype.workflow INFO:
# 	 [Job 292] Completed (_img2float0).
# 230611-12:25:04,200 nipype.workflow INFO:
# 	 [Job 14] Completed (level1.get_sub_info).
# 230611-12:25:04,201 nipype.workflow INFO:
# 	 [Job 303] Completed (_get_sub_info1).
# 230611-12:25:04,204 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 23 jobs ready. Free memory (GB): 16.40/17.40, Free processors: 3/8.
#                      Currently running:
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:04,288 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/img2float/mapflow/_img2float0".
# 230611-12:25:04,294 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:04,293 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:04,299 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:04,302 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/img2float/mapflow/_img2float1".
# 230611-12:25:04,293 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/img2float/mapflow/_img2float1".
# 230611-12:25:04,312 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:04,316 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:04,321 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 5.98753s.
# 230611-12:25:04,311 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:04,333 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:04,324 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:04,335 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:04,343 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:04,350 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:05,11 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 6.703259s.
# 230611-12:25:06,203 nipype.workflow INFO:
# 	 [Job 296] Completed (_img2float0).
# 230611-12:25:06,204 nipype.workflow INFO:
# 	 [Job 297] Completed (_img2float1).
# 230611-12:25:06,205 nipype.workflow INFO:
# 	 [Job 11] Completed (level1.img2float).
# 230611-12:25:06,207 nipype.workflow INFO:
# 	 [Job 16] Completed (level1.get_sub_info).
# 230611-12:25:06,211 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 22 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:06,298 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/img2float/mapflow/_img2float0".
# 230611-12:25:06,300 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:06,301 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:06,303 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/img2float/mapflow/_img2float1".
# 230611-12:25:06,305 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:06,310 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:06,308 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:06,312 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/img2float/mapflow/_img2float0".
# 230611-12:25:06,313 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:06,305 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:06,328 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.009003s.
# 230611-12:25:06,331 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:06,320 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:06,349 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.006374s.
# 230611-12:25:06,474 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 6.181096s.
# 230611-12:25:07,91 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 6.7889669999999995s.
# 230611-12:25:07,902 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 5.593001s.
# 230611-12:25:08,205 nipype.workflow INFO:
# 	 [Job 300] Completed (_img2float0).
# 230611-12:25:08,206 nipype.workflow INFO:
# 	 [Job 301] Completed (_img2float1).
# 230611-12:25:08,208 nipype.workflow INFO:
# 	 [Job 304] Completed (_img2float0).
# 230611-12:25:08,210 nipype.workflow INFO:
# 	 [Job 13] Completed (level1.img2float).
# 230611-12:25:08,213 nipype.workflow INFO:
# 	 [Job 306] Completed (_get_sub_info0).
# 230611-12:25:08,215 nipype.workflow INFO:
# 	 [Job 307] Completed (_get_sub_info1).
# 230611-12:25:08,218 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 22 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * _img2float0
#                        * _img2float1
# 230611-12:25:08,304 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/img2float/mapflow/_img2float0".
# 230611-12:25:08,305 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:08,308 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:08,313 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:08,311 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:08,315 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:08,315 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/img2float/mapflow/_img2float1".
# 230611-12:25:08,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:08,320 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/img2float/mapflow/_img2float1".
# 230611-12:25:08,318 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:08,319 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:08,321 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:08,326 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/img2float/mapflow/_img2float0".
# 230611-12:25:08,330 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:08,324 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:08,334 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:08,329 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:08,320 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:08,339 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:08,341 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:08,355 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.007636s.
# 230611-12:25:08,356 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.006749s.
# 230611-12:25:09,940 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 5.611329s.
# 230611-12:25:10,207 nipype.workflow INFO:
# 	 [Job 305] Completed (_img2float1).
# 230611-12:25:10,209 nipype.workflow INFO:
# 	 [Job 15] Completed (level1.img2float).
# 230611-12:25:10,211 nipype.workflow INFO:
# 	 [Job 18] Completed (level1.get_sub_info).
# 230611-12:25:10,213 nipype.workflow INFO:
# 	 [Job 310] Completed (_get_sub_info0).
# 230611-12:25:10,214 nipype.workflow INFO:
# 	 [Job 311] Completed (_get_sub_info1).
# 230611-12:25:10,217 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 20 jobs ready. Free memory (GB): 16.80/17.40, Free processors: 5/8.
#                      Currently running:
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:10,316 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:10,320 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:10,319 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/img2float/mapflow/_img2float1".
# 230611-12:25:10,319 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/img2float/mapflow/_img2float0".
# 230611-12:25:10,320 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:10,326 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:10,332 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:10,322 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:10,333 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:10,329 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:10,334 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/img2float/mapflow/_img2float1".
# 230611-12:25:10,336 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:10,326 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:10,336 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:10,341 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:10,343 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:10,354 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.01085s.
# 230611-12:25:10,358 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.007861s.
# 230611-12:25:10,351 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:10,361 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:12,27 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 5.694208s.
# 230611-12:25:12,209 nipype.workflow INFO:
# 	 [Job 308] Completed (_img2float0).
# 230611-12:25:12,210 nipype.workflow INFO:
# 	 [Job 17] Completed (level1.img2float).
# 230611-12:25:12,211 nipype.workflow INFO:
# 	 [Job 20] Completed (level1.get_sub_info).
# 230611-12:25:12,213 nipype.workflow INFO:
# 	 [Job 314] Completed (_get_sub_info0).
# 230611-12:25:12,214 nipype.workflow INFO:
# 	 [Job 315] Completed (_get_sub_info1).
# 230611-12:25:12,217 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 18 jobs ready. Free memory (GB): 16.80/17.40, Free processors: 5/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
# 230611-12:25:12,296 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:12,298 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:12,299 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:12,301 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:12,303 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:12,304 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:12,307 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/img2float/mapflow/_img2float0".
# 230611-12:25:12,310 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/img2float/mapflow/_img2float1".
# 230611-12:25:12,311 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:12,314 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:12,314 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:12,314 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:12,315 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:12,317 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:12,326 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.00903s.
# 230611-12:25:12,343 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.015039s.
# 230611-12:25:14,58 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 5.723013s.
# 230611-12:25:14,210 nipype.workflow INFO:
# 	 [Job 309] Completed (_img2float1).
# 230611-12:25:14,211 nipype.workflow INFO:
# 	 [Job 22] Completed (level1.get_sub_info).
# 230611-12:25:14,213 nipype.workflow INFO:
# 	 [Job 318] Completed (_get_sub_info0).
# 230611-12:25:14,214 nipype.workflow INFO:
# 	 [Job 319] Completed (_get_sub_info1).
# 230611-12:25:14,216 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 16 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:14,294 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/img2float/mapflow/_img2float0".
# 230611-12:25:14,296 nipype.workflow INFO:
# 	 [Node] Executing "_img2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:14,300 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/img2float/mapflow/_img2float0".
# 230611-12:25:14,295 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/img2float/mapflow/_img2float1".
# 230611-12:25:14,296 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:14,302 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:14,310 nipype.workflow INFO:
# 	 [Node] Executing "_img2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:25:14,307 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:14,318 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:14,325 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:14,328 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:14,311 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:14,333 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:14,343 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/img2float/mapflow/_img2float1".
# 230611-12:25:14,354 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:14,370 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:14,476 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 6.142071s.
# 230611-12:25:16,213 nipype.workflow INFO:
# 	 [Job 312] Completed (_img2float0).
# 230611-12:25:16,214 nipype.workflow INFO:
# 	 [Job 19] Completed (level1.img2float).
# 230611-12:25:16,215 nipype.workflow INFO:
# 	 [Job 24] Completed (level1.get_sub_info).
# 230611-12:25:16,219 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 13 jobs ready. Free memory (GB): 16.40/17.40, Free processors: 3/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
# 230611-12:25:16,305 nipype.workflow INFO:
# 	 [Job 324] Cached (_extractref0).
# 230611-12:25:16,305 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:16,309 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:16,317 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:16,321 nipype.workflow INFO:
# 	 [Node] Executing "_get_sub_info1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:25:16,336 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info0", elapsed time 0.008968s.
# 230611-12:25:16,360 nipype.workflow INFO:
# 	 [Node] Finished "_get_sub_info1", elapsed time 0.023202s.
# 230611-12:25:17,164 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 6.828224s.
# 230611-12:25:18,215 nipype.workflow INFO:
# 	 [Job 313] Completed (_img2float1).
# 230611-12:25:18,216 nipype.workflow INFO:
# 	 [Job 322] Completed (_get_sub_info0).
# 230611-12:25:18,217 nipype.workflow INFO:
# 	 [Job 323] Completed (_get_sub_info1).
# 230611-12:25:18,220 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 13 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:18,302 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/img2float/mapflow/_img2float0".
# 230611-12:25:18,307 nipype.workflow INFO:
# 	 [Job 325] Cached (_extractref1).
# 230611-12:25:18,312 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/get_sub_info/mapflow/_get_sub_info0".
# 230611-12:25:18,307 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:18,313 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:18,315 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/extractref/mapflow/_extractref0".
# 230611-12:25:18,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/img2float/mapflow/_img2float1".
# 230611-12:25:18,315 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info0" - collecting precomputed outputs
# 230611-12:25:18,325 nipype.workflow INFO:
# 	 [Node] "_get_sub_info0" found cached.
# 230611-12:25:18,328 nipype.workflow INFO:
# 	 [Node] Executing "_extractref0" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:18,328 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:18,334 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:18,333 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_sub_info1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/get_sub_info/mapflow/_get_sub_info1".
# 230611-12:25:18,344 nipype.workflow INFO:
# 	 [Node] Cached "_get_sub_info1" - collecting precomputed outputs
# 230611-12:25:18,347 nipype.workflow INFO:
# 	 [Node] "_get_sub_info1" found cached.
# 230611-12:25:18,518 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 6.192027s.
# 230611-12:25:18,708 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 6.383675s.
# 230611-12:25:19,134 nipype.workflow INFO:
# 	 [Node] Finished "_extractref0", elapsed time 0.804012s.
# 230611-12:25:20,217 nipype.workflow INFO:
# 	 [Job 316] Completed (_img2float0).
# 230611-12:25:20,217 nipype.workflow INFO:
# 	 [Job 317] Completed (_img2float1).
# 230611-12:25:20,218 nipype.workflow INFO:
# 	 [Job 21] Completed (level1.img2float).
# 230611-12:25:20,220 nipype.workflow INFO:
# 	 [Job 26] Completed (level1.get_sub_info).
# 230611-12:25:20,222 nipype.workflow INFO:
# 	 [Job 326] Completed (_extractref0).
# 230611-12:25:20,226 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 12 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * _img2float1
#                        * _img2float0
# 230611-12:25:20,305 nipype.workflow INFO:
# 	 [Job 27] Cached (level1.extractref).
# 230611-12:25:20,309 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/img2float/mapflow/_img2float0".
# 230611-12:25:20,312 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:20,313 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:20,315 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/img2float/mapflow/_img2float1".
# 230611-12:25:20,318 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:20,317 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:20,326 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/extractref/mapflow/_extractref1".
# 230611-12:25:20,329 nipype.workflow INFO:
# 	 [Node] Executing "_extractref1" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:20,328 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/extractref/mapflow/_extractref0".
# 230611-12:25:20,330 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/extractref/mapflow/_extractref1".
# 230611-12:25:20,332 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/extractref/mapflow/_extractref0".
# 230611-12:25:20,336 nipype.workflow INFO:
# 	 [Node] Executing "_extractref0" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:20,336 nipype.workflow INFO:
# 	 [Node] Executing "_extractref1" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:20,334 nipype.workflow INFO:
# 	 [Node] Executing "_extractref0" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:20,533 nipype.workflow INFO:
# 	 [Node] Finished "_img2float1", elapsed time 6.219297s.
# 230611-12:25:20,571 nipype.workflow INFO:
# 	 [Node] Finished "_img2float0", elapsed time 6.273507s.
# 230611-12:25:21,177 nipype.workflow INFO:
# 	 [Node] Finished "_extractref1", elapsed time 0.837013s.
# 230611-12:25:21,207 nipype.workflow INFO:
# 	 [Node] Finished "_extractref1", elapsed time 0.875148s.
# 230611-12:25:21,263 nipype.workflow INFO:
# 	 [Node] Finished "_extractref0", elapsed time 0.916072s.
# 230611-12:25:21,316 nipype.workflow INFO:
# 	 [Node] Finished "_extractref0", elapsed time 0.97782s.
# 230611-12:25:22,220 nipype.workflow INFO:
# 	 [Job 320] Completed (_img2float0).
# 230611-12:25:22,222 nipype.workflow INFO:
# 	 [Job 321] Completed (_img2float1).
# 230611-12:25:22,225 nipype.workflow INFO:
# 	 [Job 23] Completed (level1.img2float).
# 230611-12:25:22,230 nipype.workflow INFO:
# 	 [Job 327] Completed (_extractref1).
# 230611-12:25:22,232 nipype.workflow INFO:
# 	 [Job 328] Completed (_extractref0).
# 230611-12:25:22,233 nipype.workflow INFO:
# 	 [Job 329] Completed (_extractref1).
# 230611-12:25:22,234 nipype.workflow INFO:
# 	 [Job 330] Completed (_extractref0).
# 230611-12:25:22,237 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:25:22,313 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/img2float/mapflow/_img2float0".
# 230611-12:25:22,315 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/extractref/mapflow/_extractref0".
# 230611-12:25:22,316 nipype.workflow INFO:
# 	 [Node] "_img2float0" found cached.
# 230611-12:25:22,315 nipype.workflow INFO:
# 	 [Node] Cached "_img2float0" - collecting precomputed outputs
# 230611-12:25:22,316 nipype.workflow INFO:
# 	 [Node] Cached "_extractref0" - collecting precomputed outputs
# 230611-12:25:22,316 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/extractref/mapflow/_extractref0".
# 230611-12:25:22,318 nipype.workflow INFO:
# 	 [Node] "_extractref0" found cached.
# 230611-12:25:22,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_img2float1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/img2float/mapflow/_img2float1".
# 230611-12:25:22,319 nipype.workflow INFO:
# 	 [Node] Cached "_extractref0" - collecting precomputed outputs
# 230611-12:25:22,319 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_02/extractref/mapflow/_extractref1".
# 230611-12:25:22,319 nipype.workflow INFO:
# 	 [Node] Cached "_img2float1" - collecting precomputed outputs
# 230611-12:25:22,320 nipype.workflow INFO:
# 	 [Node] "_extractref0" found cached.
# 230611-12:25:22,320 nipype.workflow INFO:
# 	 [Node] "_img2float1" found cached.
# 230611-12:25:22,321 nipype.workflow INFO:
# 	 [Node] Cached "_extractref1" - collecting precomputed outputs
# 230611-12:25:22,322 nipype.workflow INFO:
# 	 [Node] "_extractref1" found cached.
# 230611-12:25:22,322 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/extractref/mapflow/_extractref1".
# 230611-12:25:22,325 nipype.workflow INFO:
# 	 [Node] Cached "_extractref1" - collecting precomputed outputs
# 230611-12:25:22,326 nipype.workflow INFO:
# 	 [Node] "_extractref1" found cached.
# 230611-12:25:22,346 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/extractref/mapflow/_extractref1".
# 230611-12:25:22,347 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/extractref/mapflow/_extractref0".
# 230611-12:25:22,349 nipype.workflow INFO:
# 	 [Node] Executing "_extractref1" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:22,348 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/extractref/mapflow/_extractref1".
# 230611-12:25:22,350 nipype.workflow INFO:
# 	 [Node] Executing "_extractref0" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:22,350 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/extractref/mapflow/_extractref0".
# 230611-12:25:22,350 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/extractref/mapflow/_extractref1".
# 230611-12:25:22,350 nipype.workflow INFO:
# 	 [Node] Executing "_extractref1" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:22,353 nipype.workflow INFO:
# 	 [Node] Executing "_extractref0" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:22,353 nipype.workflow INFO:
# 	 [Node] Executing "_extractref1" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:23,235 nipype.workflow INFO:
# 	 [Node] Finished "_extractref1", elapsed time 0.884431s.
# 230611-12:25:23,244 nipype.workflow INFO:
# 	 [Node] Finished "_extractref0", elapsed time 0.891365s.
# 230611-12:25:23,247 nipype.workflow INFO:
# 	 [Node] Finished "_extractref0", elapsed time 0.890533s.
# 230611-12:25:23,434 nipype.workflow INFO:
# 	 [Node] Finished "_extractref1", elapsed time 1.080954s.
# 230611-12:25:23,447 nipype.workflow INFO:
# 	 [Node] Finished "_extractref1", elapsed time 1.087653s.
# 230611-12:25:24,223 nipype.workflow INFO:
# 	 [Job 25] Completed (level1.img2float).
# 230611-12:25:24,228 nipype.workflow INFO:
# 	 [Job 28] Completed (level1.extractref).
# 230611-12:25:24,233 nipype.workflow INFO:
# 	 [Job 29] Completed (level1.extractref).
# 230611-12:25:24,236 nipype.workflow INFO:
# 	 [Job 331] Completed (_extractref1).
# 230611-12:25:24,239 nipype.workflow INFO:
# 	 [Job 332] Completed (_extractref0).
# 230611-12:25:24,244 nipype.workflow INFO:
# 	 [Job 333] Completed (_extractref1).
# 230611-12:25:24,247 nipype.workflow INFO:
# 	 [Job 334] Completed (_extractref0).
# 230611-12:25:24,249 nipype.workflow INFO:
# 	 [Job 335] Completed (_extractref1).
# 230611-12:25:24,256 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:25:24,347 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/extractref/mapflow/_extractref0".
# 230611-12:25:24,348 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/extractref/mapflow/_extractref0".
# 230611-12:25:24,349 nipype.workflow INFO:
# 	 [Node] Cached "_extractref0" - collecting precomputed outputs
# 230611-12:25:24,349 nipype.workflow INFO:
# 	 [Node] Cached "_extractref0" - collecting precomputed outputs
# 230611-12:25:24,350 nipype.workflow INFO:
# 	 [Node] "_extractref0" found cached.
# 230611-12:25:24,350 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/extractref/mapflow/_extractref0".
# 230611-12:25:24,351 nipype.workflow INFO:
# 	 [Node] "_extractref0" found cached.
# 230611-12:25:24,351 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/extractref/mapflow/_extractref1".
# 230611-12:25:24,352 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/extractref/mapflow/_extractref1".
# 230611-12:25:24,352 nipype.workflow INFO:
# 	 [Node] Cached "_extractref0" - collecting precomputed outputs
# 230611-12:25:24,353 nipype.workflow INFO:
# 	 [Node] "_extractref0" found cached.
# 230611-12:25:24,354 nipype.workflow INFO:
# 	 [Node] Cached "_extractref1" - collecting precomputed outputs
# 230611-12:25:24,354 nipype.workflow INFO:
# 	 [Node] Cached "_extractref1" - collecting precomputed outputs
# 230611-12:25:24,355 nipype.workflow INFO:
# 	 [Node] "_extractref1" found cached.
# 230611-12:25:24,355 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/extractref/mapflow/_extractref1".
# 230611-12:25:24,356 nipype.workflow INFO:
# 	 [Node] "_extractref1" found cached.
# 230611-12:25:24,358 nipype.workflow INFO:
# 	 [Node] Cached "_extractref1" - collecting precomputed outputs
# 230611-12:25:24,359 nipype.workflow INFO:
# 	 [Node] "_extractref1" found cached.
# 230611-12:25:24,396 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/extractref/mapflow/_extractref0".
# 230611-12:25:24,397 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/extractref/mapflow/_extractref1".
# 230611-12:25:24,398 nipype.workflow INFO:
# 	 [Node] Setting-up "_extractref0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/extractref/mapflow/_extractref0".
# 230611-12:25:24,399 nipype.workflow INFO:
# 	 [Node] Executing "_extractref0" <nipype.interfaces.fsl.utils.ExtractROI>
# 230611-12:25:24,399 nipype.workflow INFO:
# ...
# 230611-12:35:05,203 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:05,204 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:05,217 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:05,254 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:05,284 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:05,290 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:05,762 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.567297s.
# 230611-12:35:06,250 nipype.workflow INFO:
# 	 [Node] Finished "_level1estimate1", elapsed time 49.036313s.
# 230611-12:35:07,21 nipype.workflow INFO:
# 	 [Job 793] Completed (_level1estimate1).
# 230611-12:35:07,33 nipype.workflow INFO:
# 	 [Job 273] Completed (level1.warpfunc).
# 230611-12:35:07,43 nipype.workflow INFO:
# 	 [Job 280] Completed (level1.sinker).
# 230611-12:35:07,59 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 6 jobs ready. Free memory (GB): 16.40/17.40, Free processors: 3/8.
#                      Currently running:
#                        * _warpfunc1
#                        * _warpfunc0
#                        * _warpfunc1
#                        * _warpfunc0
#                        * _warpfunc1
# 230611-12:35:07,219 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_04/sinker".
# 230611-12:35:07,223 nipype.workflow INFO:
# 	 [Node] Setting-up "_level1estimate0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/level1estimate/mapflow/_level1estimate0".
# 230611-12:35:07,235 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:07,223 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:07,242 nipype.workflow INFO:
# 	 [Node] Cached "_level1estimate0" - collecting precomputed outputs
# 230611-12:35:07,246 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:07,251 nipype.workflow INFO:
# 	 [Node] "_level1estimate0" found cached.
# 230611-12:35:07,270 nipype.workflow INFO:
# 	 [Node] Setting-up "_level1estimate1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/level1estimate/mapflow/_level1estimate1".
# 230611-12:35:07,277 nipype.workflow INFO:
# 	 [Node] Cached "_level1estimate1" - collecting precomputed outputs
# 230611-12:35:07,283 nipype.workflow INFO:
# 	 [Node] "_level1estimate1" found cached.
# 230611-12:35:07,732 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.493536s.
# 230611-12:35:09,24 nipype.workflow INFO:
# 	 [Job 269] Completed (level1.level1estimate).
# 230611-12:35:09,27 nipype.workflow INFO:
# 	 [Job 282] Completed (level1.sinker).
# 230611-12:35:09,39 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 4 jobs ready. Free memory (GB): 16.20/17.40, Free processors: 2/8.
#                      Currently running:
#                        * _warpfunc0
#                        * _warpfunc1
#                        * _warpfunc0
#                        * _warpfunc1
#                        * _warpfunc0
#                        * _warpfunc1
# 230611-12:35:09,23 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc1", elapsed time 5.782959s.
# 230611-12:35:09,53 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc0", elapsed time 5.818208s.
# 230611-12:35:09,246 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:09,248 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:09,258 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:09,276 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:09,375 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc1", elapsed time 6.143075s.
# 230611-12:35:10,980 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc1", elapsed time 5.769996s.
# 230611-12:35:11,26 nipype.workflow INFO:
# 	 [Job 799] Completed (_warpfunc1).
# 230611-12:35:11,27 nipype.workflow INFO:
# 	 [Job 800] Completed (_warpfunc0).
# 230611-12:35:11,29 nipype.workflow INFO:
# 	 [Job 801] Completed (_warpfunc1).
# 230611-12:35:11,32 nipype.workflow INFO:
# 	 [Job 803] Completed (_warpfunc1).
# 230611-12:35:11,60 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 5 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * _warpfunc0
#                        * _warpfunc1
#                        * _warpfunc0
#                        * _warpfunc0
# 230611-12:35:11,99 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc0", elapsed time 5.884082s.
# 230611-12:35:11,227 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:11,234 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:11,242 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:11,239 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:11,247 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:11,246 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:11,251 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:11,230 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:11,251 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:11,256 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:11,259 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:11,257 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc0" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:11,259 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:11,260 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:11,264 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:11,272 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:13,27 nipype.workflow INFO:
# 	 [Job 802] Completed (_warpfunc0).
# 230611-12:35:13,30 nipype.workflow INFO:
# 	 [Job 272] Completed (level1.warpfunc).
# 230611-12:35:13,36 nipype.workflow INFO:
# 	 [Job 274] Completed (level1.warpfunc).
# 230611-12:35:13,46 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 4 jobs ready. Free memory (GB): 16.40/17.40, Free processors: 3/8.
#                      Currently running:
#                        * _warpfunc0
#                        * _warpfunc1
#                        * _warpfunc0
#                        * _warpfunc1
#                        * _warpfunc0
# 230611-12:35:13,77 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc0", elapsed time 5.821364s.
# 230611-12:35:13,194 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_05/sinker".
# 230611-12:35:13,198 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:13,207 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:13,194 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_03/sinker".
# 230611-12:35:13,222 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:13,204 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:13,230 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:13,244 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:13,248 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:13,257 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:13,681 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.456261s.
# 230611-12:35:13,798 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.589069s.
# 230611-12:35:14,457 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc1", elapsed time 5.181451s.
# 230611-12:35:14,628 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc0", elapsed time 5.34142s.
# 230611-12:35:15,29 nipype.workflow INFO:
# 	 [Job 804] Completed (_warpfunc0).
# 230611-12:35:15,30 nipype.workflow INFO:
# 	 [Job 805] Completed (_warpfunc1).
# 230611-12:35:15,32 nipype.workflow INFO:
# 	 [Job 806] Completed (_warpfunc0).
# 230611-12:35:15,35 nipype.workflow INFO:
# 	 [Job 275] Completed (level1.warpfunc).
# 230611-12:35:15,39 nipype.workflow INFO:
# 	 [Job 281] Completed (level1.sinker).
# 230611-12:35:15,41 nipype.workflow INFO:
# 	 [Job 283] Completed (level1.sinker).
# 230611-12:35:15,48 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * _warpfunc0
#                        * _warpfunc1
# 230611-12:35:15,192 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_06/sinker".
# 230611-12:35:15,192 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:15,200 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:15,195 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:15,205 nipype.workflow INFO:
# 	 [Node] Executing "_warpfunc1" <nipype.interfaces.utility.wrappers.Function>
# 230611-12:35:15,209 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:15,210 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:15,212 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:15,215 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:15,218 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:15,657 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.449501s.
# 230611-12:35:16,27 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc1", elapsed time 4.787971s.
# 230611-12:35:16,87 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc0", elapsed time 4.825264s.
# 230611-12:35:17,30 nipype.workflow INFO:
# 	 [Job 807] Completed (_warpfunc1).
# 230611-12:35:17,31 nipype.workflow INFO:
# 	 [Job 808] Completed (_warpfunc0).
# 230611-12:35:17,33 nipype.workflow INFO:
# 	 [Job 276] Completed (level1.warpfunc).
# 230611-12:35:17,36 nipype.workflow INFO:
# 	 [Job 284] Completed (level1.sinker).
# 230611-12:35:17,41 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 17.20/17.40, Free processors: 7/8.
#                      Currently running:
#                        * _warpfunc1
# 230611-12:35:17,152 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_07/sinker".
# 230611-12:35:17,160 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:17,161 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:17,162 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:17,170 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:17,176 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:17,180 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:17,181 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:17,563 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.400516s.
# 230611-12:35:18,438 nipype.workflow INFO:
# 	 [Node] Finished "_warpfunc1", elapsed time 3.215236s.
# 230611-12:35:19,34 nipype.workflow INFO:
# 	 [Job 809] Completed (_warpfunc1).
# 230611-12:35:19,36 nipype.workflow INFO:
# 	 [Job 277] Completed (level1.warpfunc).
# 230611-12:35:19,37 nipype.workflow INFO:
# 	 [Job 285] Completed (level1.sinker).
# 230611-12:35:19,40 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:35:19,137 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_08/sinker".
# 230611-12:35:19,139 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc0" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/warpfunc/mapflow/_warpfunc0".
# 230611-12:35:19,141 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc0" - collecting precomputed outputs
# 230611-12:35:19,142 nipype.workflow INFO:
# 	 [Node] "_warpfunc0" found cached.
# 230611-12:35:19,143 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:19,144 nipype.workflow INFO:
# 	 [Node] Setting-up "_warpfunc1" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/warpfunc/mapflow/_warpfunc1".
# 230611-12:35:19,146 nipype.workflow INFO:
# 	 [Node] Cached "_warpfunc1" - collecting precomputed outputs
# 230611-12:35:19,146 nipype.workflow INFO:
# 	 [Node] "_warpfunc1" found cached.
# 230611-12:35:19,474 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.329919s.
# 230611-12:35:21,36 nipype.workflow INFO:
# 	 [Job 278] Completed (level1.warpfunc).
# 230611-12:35:21,37 nipype.workflow INFO:
# 	 [Job 286] Completed (level1.sinker).
# 230611-12:35:21,40 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:35:21,144 nipype.workflow INFO:
# 	 [Node] Setting-up "level1.sinker" in "/neurodesktop-storage/Data/Flanker/output_level1/level1/_subject_id_09/sinker".
# 230611-12:35:21,148 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:35:21,455 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.305375s.
# 230611-12:35:23,37 nipype.workflow INFO:
# 	 [Job 287] Completed (level1.sinker).
# 230611-12:35:23,41 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.

# %% [markdown]
# ## The first-level GLM
#
# Here we randomly choose the four copes from subject-11 run-1

# %%
fsaverage = nilearn.datasets.fetch_surf_fsaverage()
plotting.show()

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/results_dir/_subject_id_11/_level1estimate0/results/cope1.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/results_dir/_subject_id_11/_level1estimate0/results/cope2.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/results_dir/_subject_id_11/_level1estimate0/results/cope3.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/results_dir/_subject_id_11/_level1estimate0/results/cope4.nii.gz'

# %%
plotting.plot_stat_map(nipype_cope1, bg_img=nipype_cope1, title = 'Nipype - COPE1', cmap = 'bwr', colorbar = False)
plt.show()
plotting.plot_stat_map(nipype_cope2, bg_img=nipype_cope1, title = 'Nipype - COPE2', cmap = 'bwr', colorbar = False)
plt.show()
plotting.plot_stat_map(nipype_cope3, bg_img=nipype_cope1, title = 'Nipype - COPE3', cmap = 'bwr', colorbar = False)
plt.show()
plotting.plot_stat_map(nipype_cope4, bg_img=nipype_cope1, title = 'Nipype - COPE4', cmap = 'bwr', colorbar = False)
plt.show()

# %% [markdown]
# # Second level GLM using Nipype FSL

# %%
wf_second = pe.Workflow(name='level2', base_dir=exp_dir_second)
wf_second.config["execution"]["crashfile_format"] = "txt"

# %% [markdown]
# The following two nodes (`infosource` & `dg`) together define all inputs required for the preprocessing workflow

# %%
# we want to group the outcome by contrast not subject
contr_list = [1,2,3,4]
infosource_second = pe.Node(util.IdentityInterface(fields=["contr_id"]),
                  name="infosource_second")
infosource_second.iterables = [("contr_id", contr_list)]

# %%
# here we use SelectFiles, instead of DataGrabber, because the former is more flexible with formatting syntax
templates_second = {
    "reg_copes":"*/reg_copes/*/*/cope{contr_id}_flirt.nii.gz",
    "reg_varcopes":"*/reg_varcopes/*/*/varcope{contr_id}_flirt.nii.gz",
    "reg_masks":"*/reg_masks/*/*/*.nii.gz"
}
dg_second = pe.Node(interface=nio.SelectFiles(templates_second),
             name="selectfiles_second")
dg_second.inputs.base_directory = data_dir_second

wf_second.connect([
        (infosource_second, dg_second, [("contr_id", "contr_id")])
])

# %% [markdown]
# ## Second-level GLM
# Combining results from multiple runs of one subject into one
#
# ### Higher-level input files preparation
# #### Step 1: Merge registered copes & varcopes & masks
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmerge -t mask (masks from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t cope (copes from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t varcop (varcopes from all 52 inputs)
# ```

# %%
copemerge_second = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge_second")

varcopemerge_second = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge_second")

maskmerge_second = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="maskmerge_second")


def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i, [])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

wf_second.connect(dg_second, 'reg_varcopes', varcopemerge_second, 'in_files')
wf_second.connect(dg_second, 'reg_copes', copemerge_second, 'in_files')
wf_second.connect(dg_second, 'reg_masks', maskmerge_second, 'in_files')

# %% [markdown]
# #### Step 2: Making mask
#
# In FSL, there are many commands about `maskunique`, which is unless for the second level. We can ignore it.
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
# ```

# %%
minmask_second = pe.Node(
    interface=fsl.ImageMaths(op_string='-Tmin'),
    iterfield=['in_file'],
    name='minmask_second')

wf_second.connect(maskmerge_second, 'merged_file', minmask_second, 'in_file')

# %% [markdown]
# #### Step 3: Masking copes & varcopes
#
# **Corresponding FSL command:**
#
# we have four contrasts so the following commands repeat four times
#
# ```
# /usr/local/fsl/bin/fslmaths cope1 -mas mask cope1
# /usr/local/fsl/bin/fslmaths varcope1 -mas mask varcope1
# ```

# %%
maskcope_second = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskcope_second')

maskvarcope_second = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskvarcope_second')

wf_second.connect(copemerge_second, 'merged_file', maskcope_second, 'in_file')
wf_second.connect(minmask_second, 'out_file', maskcope_second, 'in_file2')
wf_second.connect(varcopemerge_second, 'merged_file', maskvarcope_second, 'in_file')
wf_second.connect(minmask_second, 'out_file', maskvarcope_second, 'in_file2')

# %% [markdown]
# ### Set up second-level contrasts and fixed-effects

# %%
def get_contrasts_l2(in_files):
    import numpy as np
    import glob
    total = len(in_files)
    print(in_files)
    print(total)
    n_sub = len(glob.glob('/neurodesktop-storage/Data/Flanker/ds000102/'+"sub-0*"))    
    # n_sub = 26
    ev_list = ['ev'+str(x) for x in range(1,n_sub+1)]
    weight_mtx = np.zeros((n_sub,n_sub))
    weight_mtx = weight_mtx.astype(np.float64)
    np.fill_diagonal(weight_mtx,1.)
    #contr = ['','T',ev_list,list(weight_mtx[0])] --> original paper
    contr = np.array(['','T', ev_list, list(weight_mtx[0])], dtype=object) #adaptation so the construction of the array works
    contr_lst = np.tile(contr, (n_sub,n_sub))
    contr_lst = [tuple(x) for x in contr_lst] 
    for i in range(n_sub):
        # Instead of trying to change the tuple, create a new tuple with the changed value.
        contr_lst[i] = (contr_lst[i][0], contr_lst[i][1], contr_lst[i][2], list(weight_mtx[i]))

    reg_dict = {k:None for k in ev_list}
    for k in reg_dict.keys():
        start_lst = [0.0] * total
        idx = ev_list.index(k)
        start_idx = idx*2
        end_idx = idx*2 + 1
        start_lst[start_idx] = 1.
        start_lst[end_idx] = 1.
        reg_dict[k] = start_lst    
    return contr_lst, reg_dict

contrastgen_l2 = pe.Node(util.Function(input_names=['in_files'],
                                    output_names=['contr_lst', 'reg_dict'],
                                    function=get_contrasts_l2),
                      iterfield=['in_files'],
                      name='contrastgen_l2')

wf_second.connect(dg_second,'reg_copes', contrastgen_l2, 'in_files')

# %% [markdown]
# Nipype recommands using [L2Model](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#l2model), which only works for the single subject. It takes the number of runs (copes at the first level) as input and does estimations for subject one by one.
# Instead, we use [MultipleRegressDesign](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#multipleregressdesign). As it's name indicates, this one can deal with multiple predictors (subjects) at the same time.

# %%
level2model = pe.Node(interface=fsl.MultipleRegressDesign(),
                      name='l2model')

wf_second.connect([(contrastgen_l2, level2model, [('contr_lst','contrasts'),
                                        ('reg_dict','regressors')])])

level2estimate = pe.Node(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="level2estimate",
    iterfield=['cope_file', 'var_cope_file'])

wf_second.connect([
    (maskcope_second, level2estimate, [('out_file', 'cope_file')]),
    (maskvarcope_second, level2estimate, [('out_file', 'var_cope_file')]),
    (minmask_second, level2estimate, [('out_file', 'mask_file')]),
    (level2model, level2estimate, [('design_mat', 'design_file'),
                                   ('design_con', 't_con_file'), 
                                   ('design_grp', 'cov_split_file')]),
])

datasink_second = pe.Node(nio.DataSink(), name='sinker')
datasink_second.inputs.base_directory=os.path.join(exp_dir_second, "level2_results")

int2string = lambda x: 'contrast_'+str(x)
    
wf_second.connect(infosource_second, ('contr_id',int2string), datasink_second, 'container')
wf_second.connect([(level2estimate, datasink_second, [('stats_dir', 'stats_dir')])])

# Create 1st-level analysis output graph
wf_second.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=os.path.join(wf_second.base_dir, wf_second.name, 'graph.png'))
# Out:
# 230611-12:35:30,103 nipype.workflow INFO:
# 	 Generated workflow graph: /neurodesktop-storage/Data/Flanker/output_level2/level2/graph.png (graph2use=colored, simple_form=True).

# %%
# Run Workflow
wf_second.run(plugin="MultiProc", plugin_args={"n_procs": 8})
# Out:
# 230611-12:35:30,123 nipype.workflow INFO:
# 	 Workflow level2 settings: ['check', 'execution', 'logging', 'monitoring']
# 230611-12:35:30,152 nipype.workflow INFO:
# 	 Running in parallel.
# 230611-12:35:30,155 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:35:30,316 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/selectfiles_second".
# 230611-12:35:30,321 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/selectfiles_second".
# 230611-12:35:30,323 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/selectfiles_second".
# 230611-12:35:30,325 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_second" <nipype.interfaces.io.SelectFiles>
# 230611-12:35:30,327 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_second" <nipype.interfaces.io.SelectFiles>
# 230611-12:35:30,326 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/selectfiles_second".
# 230611-12:35:30,330 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_second" <nipype.interfaces.io.SelectFiles>
# 230611-12:35:30,333 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_second" <nipype.interfaces.io.SelectFiles>
# 230611-12:35:30,350 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_second", elapsed time 0.021472s.
# 230611-12:35:30,350 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_second", elapsed time 0.014953s.
# 230611-12:35:30,351 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_second", elapsed time 0.01022s.
# 230611-12:35:30,350 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_second", elapsed time 0.019305s.
# 230611-12:35:32,157 nipype.workflow INFO:
# 	 [Job 0] Completed (level2.selectfiles_second).
# 230611-12:35:32,159 nipype.workflow INFO:
# 	 [Job 1] Completed (level2.selectfiles_second).
# 230611-12:35:32,160 nipype.workflow INFO:
# 	 [Job 2] Completed (level2.selectfiles_second).
# 230611-12:35:32,161 nipype.workflow INFO:
# 	 [Job 3] Completed (level2.selectfiles_second).
# 230611-12:35:32,164 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:35:32,291 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.varcopemerge_second".
# 230611-12:35:32,295 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.copemerge_second".
# 230611-12:35:32,295 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.varcopemerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/varcopemerge_second".
# 230611-12:35:32,297 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.varcopemerge_second".
# 230611-12:35:32,302 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskmerge_second".
# 230611-12:35:32,302 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.copemerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/copemerge_second".
# 230611-12:35:32,304 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:32,305 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.copemerge_second".
# 230611-12:35:32,310 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230611-12:35:32,310 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskmerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/maskmerge_second".
# 230611-12:35:32,312 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskmerge_second".
# 230611-12:35:32,313 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:32,313 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id
cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/21/reg_copes/_subject_id_21/_warpfunc1/cope2_flirt.nii.gz']
# 22
# 230611-12:35:32,423 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.030598s.
# 230611-12:35:33,590 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_second", elapsed time 1.246123s.
# 230611-12:35:33,628 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_second", elapsed time 1.2487759999999999s.
# 230611-12:35:34,159 nipype.workflow INFO:
# 	 [Job 6] Completed (level2.maskmerge_second).
# 230611-12:35:34,161 nipype.workflow INFO:
# 	 [Job 7] Completed (level2.contrastgen_l2).
# 230611-12:35:34,165 nipype.workflow INFO:
# 	 [Job 10] Completed (level2.maskmerge_second).
# 230611-12:35:34,169 nipype.workflow INFO:
# 	 [Job 11] Completed (level2.contrastgen_l2).
# 230611-12:35:34,175 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * level2.copemerge_second
#                        * level2.varcopemerge_second
#                        * level2.copemerge_second
#                        * level2.varcopemerge_second
# 230611-12:35:34,294 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.varcopemerge_second".
# 230611-12:35:34,303 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.varcopemerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/varcopemerge_second".
# 230611-12:35:34,310 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.copemerge_second".
# 230611-12:35:34,309 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.varcopemerge_second".
# 230611-12:35:34,316 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:34,325 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.copemerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/copemerge_second".
# 230611-12:35:34,327 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskmerge_second".
# 230611-12:35:34,333 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskmerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/maskmerge_second".
# 230611-12:35:34,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.copemerge_second".
# 230611-12:35:34,347 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230611-12:35:34,346 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskmerge_second".
# 230611-12:35:34,358 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/contrastgen_l2".
# 230611-12:35:34,361 nipype.workflow INFO:
# 	 [Node] Executing "maskmerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:34,353 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:34,361 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230611-12:35:34,380 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l2" <nipype.interfaces.utility.wrappers.Function>
# ['/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/21/reg_copes/_subject_id_21/_warpfunc1/cope3_flirt.nii.gz']
# 22
# 230611-12:35:34,412 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.021274s.
# 230611-12:35:34,779 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_second", elapsed time 2.436303s.
# 230611-12:35:34,825 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_second", elapsed time 2.518316s.
# 230611-12:35:34,852 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_second", elapsed time 2.481699s.
# 230611-12:35:34,884 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_second", elapsed time 2.566309s.
# 230611-12:35:35,605 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_second", elapsed time 1.240855s.
# 230611-12:35:36,165 nipype.workflow INFO:
# 	 [Job 4] Completed (level2.varcopemerge_second).
# 230611-12:35:36,171 nipype.workflow INFO:
# 	 [Job 5] Completed (level2.copemerge_second).
# 230611-12:35:36,173 nipype.workflow INFO:
# 	 [Job 8] Completed (level2.varcopemerge_second).
# 230611-12:35:36,184 nipype.workflow INFO:
# 	 [Job 9] Completed (level2.copemerge_second).
# 230611-12:35:36,191 nipype.workflow INFO:
# 	 [Job 14] Completed (level2.maskmerge_second).
# 230611-12:35:36,193 nipype.workflow INFO:
# 	 [Job 15] Completed (level2.contrastgen_l2).
# 230611-12:35:36,195 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * level2.copemerge_second
#                        * level2.varcopemerge_second
# 230611-12:35:36,300 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.varcopemerge_second".
# 230611-12:35:36,307 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.varcopemerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/varcopemerge_second".
# 230611-12:35:36,308 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.varcopemerge_second".
# 230611-12:35:36,310 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.copemerge_second".
# 230611-12:35:36,313 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:36,314 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.copemerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/copemerge_second".
# 230611-12:35:36,318 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskmerge_second".
# 230611-12:35:36,318 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.copemerge_second".
# 230611-12:35:36,325 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskmerge_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/maskmerge_second".
# 230611-12:35:36,324 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:36,329 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230611-12:35:36,327 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskmerge_second".
# 230611-12:35:36,333 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/contrastgen_l2".
# 230611-12:35:36,343 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230611-12:35:36,347 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:36,342 nipype.workflow INFO:
# 	 [Node] Executing "maskmerge_second" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:35:36,356 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l2" <nipype.interfaces.utility.wrappers.Function>
# ['/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/21/reg_copes/_subject_id_21/_warpfunc1/cope4_flirt.nii.gz']230611-12:35:36,350 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.minmask_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/minmask_second".
# 230611-12:35:36,371 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:36,376 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:36,378 nipype.workflow INFO:
# 	 [Node] Executing "minmask_second" <nipype.interfaces.fsl.utils.ImageMaths>
#
# 22
# 230611-12:35:36,393 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.029801s.
# 230611-12:35:36,394 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.l2model" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/l2model".
# 230611-12:35:36,411 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:36,426 nipype.workflow INFO:
# 	 [Node] Executing "l2model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230611-12:35:36,440 nipype.workflow INFO:
# 	 [Node] Finished "l2model", elapsed time 0.003341s.
# 230611-12:35:36,671 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_second", elapsed time 2.349246s.
# 230611-12:35:36,671 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_second", elapsed time 2.2839679999999998s.
# 230611-12:35:37,458 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_second", elapsed time 1.09907s.
# 230611-12:35:38,168 nipype.workflow INFO:
# 	 [Job 12] Completed (level2.varcopemerge_second).
# 230611-12:35:38,171 nipype.workflow INFO:
# 	 [Job 13] Completed (level2.copemerge_second).
# 230611-12:35:38,173 nipype.workflow INFO:
# 	 [Job 18] Completed (level2.maskmerge_second).
# 230611-12:35:38,174 nipype.workflow INFO:
# 	 [Job 19] Completed (level2.contrastgen_l2).
# 230611-12:35:38,176 nipype.workflow INFO:
# 	 [Job 21] Completed (level2.l2model).
# 230611-12:35:38,179 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 6 jobs ready. Free memory (GB): 16.80/17.40, Free processors: 5/8.
#                      Currently running:
#                        * level2.minmask_second
#                        * level2.copemerge_second
#                        * level2.varcopemerge_second
# 230611-12:35:38,280 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:38,294 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:38,284 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.minmask_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/minmask_second".
# 230611-12:35:38,295 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:38,298 nipype.workflow INFO:
# 	 [Node] Executing "minmask_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:38,304 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.l2model" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/l2model".
# 230611-12:35:38,309 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:38,318 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:38,320 nipype.workflow INFO:
# 	 [Node] Executing "l2model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230611-12:35:38,326 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.minmask_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/minmask_second".
# 230611-12:35:38,328 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:38,328 nipype.workflow INFO:
# 	 [Node] Finished "l2model", elapsed time 0.002732s.
# 230611-12:35:38,341 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:38,331 nipype.workflow INFO:
# 	 [Node] Executing "minmask_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:38,347 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.l2model" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/l2model".
# 230611-12:35:38,349 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:38,356 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.minmask_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/minmask_second".
# 230611-12:35:38,357 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.minmask_second".
# 230611-12:35:38,360 nipype.workflow INFO:
# 	 [Node] Executing "minmask_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:38,361 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_second", elapsed time 2.046283s.
# 230611-12:35:38,371 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:38,404 nipype.workflow INFO:
# 	 [Node] Executing "l2model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230611-12:35:38,434 nipype.workflow INFO:
# 	 [Node] Finished "l2model", elapsed time 0.002973s.
# 230611-12:35:38,536 nipype.workflow INFO:
# 	 [Node] Finished "minmask_second", elapsed time 2.155877s.
# 230611-12:35:38,687 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_second", elapsed time 2.359218s.
# 230611-12:35:40,120 nipype.workflow INFO:
# 	 [Node] Finished "minmask_second", elapsed time 1.7561529999999999s.
# 230611-12:35:40,164 nipype.workflow INFO:
# 	 [Node] Finished "minmask_second", elapsed time 1.8563619999999998s.
# 230611-12:35:40,169 nipype.workflow INFO:
# 	 [Node] Finished "minmask_second", elapsed time 1.826211s.
# 230611-12:35:40,170 nipype.workflow INFO:
# 	 [Job 16] Completed (level2.varcopemerge_second).
# 230611-12:35:40,173 nipype.workflow INFO:
# 	 [Job 17] Completed (level2.copemerge_second).
# 230611-12:35:40,175 nipype.workflow INFO:
# 	 [Job 20] Completed (level2.minmask_second).
# 230611-12:35:40,177 nipype.workflow INFO:
# 	 [Job 22] Completed (level2.minmask_second).
# 230611-12:35:40,179 nipype.workflow INFO:
# 	 [Job 23] Completed (level2.l2model).
# 230611-12:35:40,181 nipype.workflow INFO:
# 	 [Job 24] Completed (level2.minmask_second).
# 230611-12:35:40,185 nipype.workflow INFO:
# 	 [Job 25] Completed (level2.l2model).
# 230611-12:35:40,187 nipype.workflow INFO:
# 	 [Job 26] Completed (level2.minmask_second).
# 230611-12:35:40,190 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:35:40,298 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:40,306 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.l2model" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/l2model".
# 230611-12:35:40,307 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,307 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.l2model".
# 230611-12:35:40,309 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/maskcope_second".
# 230611-12:35:40,310 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,313 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:40,313 nipype.workflow INFO:
# 	 [Node] Executing "l2model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230611-12:35:40,313 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:40,316 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskvarcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/maskvarcope_second".
# 230611-12:35:40,317 nipype.workflow INFO:
# 	 [Node] Finished "l2model", elapsed time 0.002395s.
# 230611-12:35:40,320 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:40,322 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,324 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:40,325 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/maskcope_second".
# 230611-12:35:40,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,328 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:40,329 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:40,334 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,331 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskvarcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/maskvarcope_second".
# 230611-12:35:40,339 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/maskcope_second".
# 230611-12:35:40,341 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,346 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:40,368 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:40,372 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskvarcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/maskvarcope_second".
# 230611-12:35:40,373 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,373 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:40,375 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/maskcope_second".
# 230611-12:35:40,377 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskcope_second".
# 230611-12:35:40,394 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:40,394 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:40,394 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:40,395 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:42,171 nipype.workflow INFO:
# 	 [Job 27] Completed (level2.l2model).
# 230611-12:35:42,175 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 1 jobs ready. Free memory (GB): 16.00/17.40, Free processors: 1/8.
#                      Currently running:
#                        * level2.maskcope_second
#                        * level2.maskvarcope_second
#                        * level2.maskcope_second
#                        * level2.maskvarcope_second
#                        * level2.maskcope_second
#                        * level2.maskvarcope_second
#                        * level2.maskcope_second
# 230611-12:35:42,440 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:42,443 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskvarcope_second" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/maskvarcope_second".
# 230611-12:35:42,461 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.maskvarcope_second".
# 230611-12:35:42,489 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_second" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:35:43,169 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_second", elapsed time 2.837929s.
# 230611-12:35:43,256 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_second", elapsed time 2.929678s.
# 230611-12:35:43,277 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_second", elapsed time 2.867863s.
# 230611-12:35:43,457 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_second", elapsed time 3.140736s.
# 230611-12:35:43,508 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_second", elapsed time 3.108677s.
# 230611-12:35:43,562 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_second", elapsed time 3.15491s.
# 230611-12:35:43,693 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_second", elapsed time 3.29442s.
# 230611-12:35:44,172 nipype.workflow INFO:
# 	 [Job 28] Completed (level2.maskcope_second).
# 230611-12:35:44,174 nipype.workflow INFO:
# 	 [Job 29] Completed (level2.maskvarcope_second).
# 230611-12:35:44,175 nipype.workflow INFO:
# 	 [Job 30] Completed (level2.maskcope_second).
# 230611-12:35:44,177 nipype.workflow INFO:
# 	 [Job 31] Completed (level2.maskvarcope_second).
# 230611-12:35:44,179 nipype.workflow INFO:
# 	 [Job 32] Completed (level2.maskcope_second).
# 230611-12:35:44,180 nipype.workflow INFO:
# 	 [Job 33] Completed (level2.maskvarcope_second).
# 230611-12:35:44,182 nipype.workflow INFO:
# 	 [Job 34] Completed (level2.maskcope_second).
# 230611-12:35:44,186 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 17.20/17.40, Free processors: 7/8.
#                      Currently running:
#                        * level2.maskvarcope_second
# 230611-12:35:44,292 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:44,295 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/level2estimate".
# 230611-12:35:44,296 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:44,300 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:44,302 nipype.workflow INFO:
# 	 [Node] Executing "level2estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:35:44,305 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/level2estimate".
# 230611-12:35:44,309 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:44,308 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:44,312 nipype.workflow INFO:
# 	 [Node] Executing "level2estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:35:44,312 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/level2estimate".
# 230611-12:35:44,313 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:44,320 nipype.workflow INFO:
# 	 [Node] Executing "level2estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:35:44,747 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_second", elapsed time 2.228074s.
# 230611-12:35:46,175 nipype.workflow INFO:
# 	 [Job 35] Completed (level2.maskvarcope_second).
# 230611-12:35:46,177 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 16.80/17.40, Free processors: 5/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 230611-12:35:46,304 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:46,307 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/level2estimate".
# 230611-12:35:46,309 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 230611-12:35:46,315 nipype.workflow INFO:
# 	 [Node] Executing "level2estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:35:48,177 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 230611-12:36:17,459 nipype.workflow INFO:
# 	 [Node] Finished "level2estimate", elapsed time 33.137151s.
# 230611-12:36:17,486 nipype.workflow INFO:
# 	 [Node] Finished "level2estimate", elapsed time 33.180868s.
# 230611-12:36:18,11 nipype.workflow INFO:
# 	 [Node] Finished "level2estimate", elapsed time 33.696387s.
# 230611-12:36:18,206 nipype.workflow INFO:
# 	 [Job 36] Completed (level2.level2estimate).
# 230611-12:36:18,208 nipype.workflow INFO:
# 	 [Job 37] Completed (level2.level2estimate).
# 230611-12:36:18,209 nipype.workflow INFO:
# 	 [Job 38] Completed (level2.level2estimate).
# 230611-12:36:18,211 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 17.20/17.40, Free processors: 7/8.
#                      Currently running:
#                        * level2.level2estimate
# 230611-12:36:18,303 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/sinker".
# 230611-12:36:18,307 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:36:18,307 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/sinker".
# 230611-12:36:18,311 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:36:18,311 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/sinker".
# 230611-12:36:18,316 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:36:18,952 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.627547s.
# 230611-12:36:18,976 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.667521s.
# 230611-12:36:18,975 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.662016s.
# 230611-12:36:20,63 nipype.workflow INFO:
# 	 [Node] Finished "level2estimate", elapsed time 33.742955s.
# 230611-12:36:20,208 nipype.workflow INFO:
# 	 [Job 39] Completed (level2.level2estimate).
# 230611-12:36:20,210 nipype.workflow INFO:
# 	 [Job 40] Completed (level2.sinker).
# 230611-12:36:20,211 nipype.workflow INFO:
# 	 [Job 41] Completed (level2.sinker).
# 230611-12:36:20,213 nipype.workflow INFO:
# 	 [Job 42] Completed (level2.sinker).
# 230611-12:36:20,216 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:36:20,316 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/sinker".
# 230611-12:36:20,323 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:36:20,844 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.518546s.
# 230611-12:36:22,210 nipype.workflow INFO:
# 	 [Job 43] Completed (level2.sinker).
# 230611-12:36:22,213 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.

# %% [markdown]
# ## The second-level GLM
#
# Here we choose the four copes from subject-22
#
# ### Regapply
#
# This happens before the second-level GLM, all results from the first level are needed to be registered into the standard space
#
# copes from subject-01

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope1_flirt.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope2_flirt.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope3_flirt.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope4_flirt.nii.gz'

# %%
plotting.plot_stat_map(nipype_cope1, bg_img=nipype_cope1, title = 'Nipype - COPE1', cmap = 'bwr', colorbar = False)
plotting.plot_stat_map(nipype_cope2, bg_img=nipype_cope2, title = 'Nipype - COPE2', cmap = 'bwr', colorbar = False)
plotting.plot_stat_map(nipype_cope3, bg_img=nipype_cope3, title = 'Nipype - COPE3', cmap = 'bwr', colorbar = False)
plotting.plot_stat_map(nipype_cope4, bg_img=nipype_cope4, title = 'Nipype - COPE4', cmap = 'bwr', colorbar = False)
plt.show()

# %% [markdown]
# ### Copes from the second-level GLM
#
# copes from subject-22

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_1/stats_dir/_contr_id_1/stats/cope1.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_2/stats_dir/_contr_id_2/stats/cope1.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_3/stats_dir/_contr_id_3/stats/cope1.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_4/stats_dir/_contr_id_4/stats/cope1.nii.gz'

# %%
plotting.plot_glass_brain(nipype_cope1, bg_img=nipype_cope1, title = 'Nipype - COPE1')
plotting.plot_glass_brain(nipype_cope2, bg_img=nipype_cope2, title = 'Nipype - COPE2')
plotting.plot_glass_brain(nipype_cope3, bg_img=nipype_cope3, title = 'Nipype - COPE3')
plotting.plot_glass_brain(nipype_cope4, bg_img=nipype_cope4, title = 'Nipype - COPE4')
plt.show()

# %% [markdown]
# # Third-level GLM using Nipype FSL

# %% [markdown]
# Start the workflow

# %%
wf_third = pe.Workflow(name='level3', base_dir=exp_dir_third)
wf_third.config["execution"]["crashfile_format"] = "txt"

# %% [markdown]
# The following two nodes (`infosource` & `dg`) together define all inputs required for the preprocessing workflow

# %%
# we want to group the outcome by contrast not subject
contr_list = [1,2,3,4]
infosource_third = pe.Node(util.IdentityInterface(fields=["contr_id"]),
                  name="infosource_third")
infosource_third.iterables = [("contr_id", contr_list)]

# %%
# here we use SelectFiles, instead of DataGrabber, because the former is more flexible with formatting syntax
templates_third = {
    "copes":"contrast_{contr_id}/*/_contr_id_{contr_id}/*/cope*.nii.gz",
    "varcopes":"contrast_{contr_id}/*/_contr_id_{contr_id}/*/varcope*.nii.gz",
    "masks":"contrast_{contr_id}/*/_contr_id_{contr_id}/*/mask.nii.gz"
}
templates = {
    "reg_copes":"*/reg_copes/*/*/cope{contr_id}_flirt.nii.gz",
    "reg_varcopes":"*/reg_varcopes/*/*/varcope{contr_id}_flirt.nii.gz",
    "reg_masks":"*/reg_masks/*/*/*.nii.gz"
}

dg_third = pe.Node(interface=nio.SelectFiles(templates_third),
             name="selectfiles_third")
dg_third.inputs.base_directory = data_dir_third

wf_third.connect([
        (infosource_third, dg_third, [("contr_id", "contr_id")])
])

# %% [markdown]
# ## Third-level GLM
#
# Combining results from multiple runs of one subject into one
#
# ### Higher-level input files preparation
# #### Step 1: Merge registered copes & varcopes & masks
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmerge -t mask (masks from all 26 inputs)
# /usr/local/fsl/bin/fslmerge -t cope (copes from all 26 inputs)
# /usr/local/fsl/bin/fslmerge -t varcop (varcopes from all 26 inputs)
# ```

# %%
copemerge_third = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge_third")

varcopemerge_third = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge_third")

maskmerge_third = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="maskmerge_third")

def repeat_mask(file):
    import numpy as np
    import glob
    n_sub = len(glob.glob('/neurodesktop-storage/Data/Flanker/ds000102/'+"sub-0*"))    
    # n_sub = 26 
    mask_lst = [file]
    repeated = np.repeat(mask_lst,n_sub)
    return list(repeated)

wf_third.connect(dg_third, 'copes', copemerge_third, 'in_files')
wf_third.connect(dg_third, 'varcopes', varcopemerge_third, 'in_files')
wf_third.connect(dg_third, ('masks', repeat_mask), maskmerge_third, 'in_files')

# %% [markdown]
# #### Step 2: Making mask
#
# In FSL, there are many commands about `maskunique`, which is unless for the second level. We can ignore it.
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
# ```

# %%
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
minmask_third = pe.Node(
    interface=fsl.ImageMaths(op_string='-Tmin'),
    iterfield=['in_file'],
    name='minmask_third')

wf_third.connect(maskmerge_third, 'merged_file', minmask_third, 'in_file')

# %% [markdown]
# #### Step 3: Masking copes & varcopes
#
# **Corresponding FSL command:**
#
# we have four contrasts so the following commands repeat four times
#
# ```
# /usr/local/fsl/bin/fslmaths cope1 -mas mask cope1
# /usr/local/fsl/bin/fslmaths varcope1 -mas mask varcope1
# ```

# %%
maskcope_third = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskcope_third')

maskvarcope_third = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskvarcope_third')

wf_third.connect(copemerge_third, 'merged_file', maskcope_third, 'in_file')
wf_third.connect(minmask_third, 'out_file', maskcope_third, 'in_file2')
wf_third.connect(varcopemerge_third, 'merged_file', maskvarcope_third, 'in_file')
wf_third.connect(minmask_third, 'out_file', maskvarcope_third, 'in_file2')

# %% [markdown]
# ### Set up third-level contrasts
# Since we only have a single-group set-up, we can actually use [L2Model](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#l2model).
# If we have an ANOVA-like design, using [MultipleRegressDesign](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#multipleregressdesign) would be a better option.

# %%
def num_copes(files):
    return len(files)

level3model = pe.Node(interface=fsl.L2Model(), name='l3model')
wf_third.connect(dg_third, ('copes',num_copes), level3model, 'num_copes')

# %%
level3estimate = pe.Node(
    interface=fsl.FLAMEO(run_mode='flame1'),
    name="level3estimate",
    iterfield=['cope_file', 'var_cope_file'])

wf_third.connect([
    (maskcope_third, level3estimate, [('out_file', 'cope_file')]),
    (maskvarcope_third, level3estimate, [('out_file', 'var_cope_file')]),
    (minmask_third, level3estimate, [('out_file', 'mask_file')]),
    (level3model, level3estimate, [('design_mat', 'design_file'),
                                   ('design_con', 't_con_file'), 
                                   ('design_grp', 'cov_split_file')]),
])

# %% [markdown]
# ### Post-Stats
# #### Smoothness estimation
# to get `dlh` and `volume` for thresholding
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/smoothest -d 25 -m mask -r stats/res4d > stats/smoothness
# ```

# %%
smoothest = pe.Node(
    interface=fsl.SmoothEstimate(dof=25),
    name="smoothest",
    iterfield=['residual_fit_file', 'mask_file'])

wf_third.connect(minmask_third, 'out_file', smoothest, 'mask_file')
wf_third.connect(level3estimate, 'res4d', smoothest, 'residual_fit_file')

# %% [markdown]
# #### Mask zstats file
#
# preparation for thresholding
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/fslmaths stats/zstat1 -mas mask thresh_zstat1
# ```

# %%
level3mask = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file','in_file2'],
    name='level3mask')

wf_third.connect([
    (level3estimate,level3mask,[('zstats', 'in_file')]),
    (minmask_third, level3mask, [('out_file', 'in_file2')]),
])

# %% [markdown]
# #### Cluster-wise thresholding
#
# **Corresponding FSL command:**
#
# ```
# /usr/local/fsl/bin/cluster -i thresh_zstat1 -t 3.1 --othresh=thresh_zstat1 -o cluster_mask_zstat1 --connectivity=26 --mm --olmax=lmax_zstat1_std.txt --scalarname=Z -p 0.05 -d 0.0595781 --volume=254734 -c stats/cope1 > cluster_zstat1_std.txt
# ```

# %%
level3threshold = pe.Node(
        interface=fsl.Cluster(threshold = 3.1,
                              pthreshold = 0.05,
                              use_mm = True,
                              out_threshold_file =True,
                              out_index_file = True,
                              out_localmax_txt_file = True),
    iterfield=['in_file','cope_file'],
    name='level3threshold')

wf_third.connect([
    (level3mask, level3threshold, [('out_file', 'in_file')]),
    (level3estimate, level3threshold, [('copes', 'cope_file')]),
    (smoothest, level3threshold, [('dlh', 'dlh'),
                                   ('volume', 'volume')]),
])

# %% [markdown]
# ## Save the output

# %%
datasink_third = pe.Node(nio.DataSink(), name='sinker')
datasink_third.inputs.base_directory=os.path.join(exp_dir_third, "level3_results")

int2string = lambda x: 'contrast_'+str(x)
    
wf_third.connect(infosource_third, ('contr_id',int2string), datasink_third, 'container')
wf_third.connect([
    (level3estimate, datasink_third, [('stats_dir', 'stats_dir')]),
    (level3threshold, datasink_third, [('threshold_file', 'thresholded'),
                                ('localmax_txt_file', 'localmax_txt'),
                                ('index_file', 'index')]),
           ])

# %%
# Create 1st-level analysis output graph
wf_third.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=os.path.join(wf_third.base_dir, wf_third.name, 'graph.png'))
# Out:
# 230611-12:36:41,619 nipype.workflow INFO:
# 	 Generated workflow graph: /neurodesktop-storage/Data/Flanker/output_level3/level3/graph.png (graph2use=colored, simple_form=True).

# %%
# Run Workflow
wf_third.run(plugin="MultiProc", plugin_args={"n_procs": 8})
# Out:
# 230611-12:36:41,632 nipype.workflow INFO:
# 	 Workflow level3 settings: ['check', 'execution', 'logging', 'monitoring']
# 230611-12:36:41,661 nipype.workflow INFO:
# 	 Running in parallel.
# 230611-12:36:41,664 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:36:41,831 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.selectfiles_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/selectfiles_third".
# 230611-12:36:41,839 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_third" <nipype.interfaces.io.SelectFiles>
# 230611-12:36:41,838 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.selectfiles_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/selectfiles_third".
# 230611-12:36:41,841 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.selectfiles_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/selectfiles_third".
# 230611-12:36:41,843 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.selectfiles_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/selectfiles_third".
# 230611-12:36:41,845 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_third", elapsed time 0.003116s.
# 230611-12:36:41,847 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_third" <nipype.interfaces.io.SelectFiles>
# 230611-12:36:41,849 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_third" <nipype.interfaces.io.SelectFiles>
# 230611-12:36:41,845 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles_third" <nipype.interfaces.io.SelectFiles>
# 230611-12:36:41,853 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_third", elapsed time 0.003463s.
# 230611-12:36:41,858 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_third", elapsed time 0.002346s.
# 230611-12:36:41,859 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles_third", elapsed time 0.0031s.
# 230611-12:36:43,666 nipype.workflow INFO:
# 	 [Job 0] Completed (level3.selectfiles_third).
# 230611-12:36:43,671 nipype.workflow INFO:
# 	 [Job 1] Completed (level3.selectfiles_third).
# 230611-12:36:43,673 nipype.workflow INFO:
# 	 [Job 2] Completed (level3.selectfiles_third).
# 230611-12:36:43,674 nipype.workflow INFO:
# 	 [Job 3] Completed (level3.selectfiles_third).
# 230611-12:36:43,676 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:36:43,810 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:43,813 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:43,814 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.copemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/copemerge_third".
# 230611-12:36:43,817 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:43,818 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:43,817 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.varcopemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/varcopemerge_third".
# 230611-12:36:43,821 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:43,824 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:43,825 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskmerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/maskmerge_third".
# 230611-12:36:43,825 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:43,828 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:43,827 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.l3model" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/l3model".
# 230611-12:36:43,829 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:43,831 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:43,836 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:43,843 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.L2Model>
# 230611-12:36:43,829 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:43,839 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.copemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/copemerge_third".
# 230611-12:36:43,843 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.varcopemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/varcopemerge_third".
# 230611-12:36:43,847 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:43,846 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:43,846 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:43,847 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.00087s.
# 230611-12:36:43,854 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:43,854 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskmerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/maskmerge_third".
# 230611-12:36:43,855 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:43,855 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:43,858 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:43,856 nipype.workflow INFO:
# 	 [Node] Executing "maskmerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:43,858 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.l3model" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/l3model".
# 230611-12:36:43,862 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:43,863 nipype.workflow INFO:
# 	 [Node] Executing "maskmerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:43,866 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.L2Model>
# 230611-12:36:43,873 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.00089s.
# 230611-12:36:44,627 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_third", elapsed time 0.761749s.
# 230611-12:36:44,676 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_third", elapsed time 0.814849s.
# 230611-12:36:44,995 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_third", elapsed time 1.163867s.
# 230611-12:36:45,76 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_third", elapsed time 1.215649s.
# 230611-12:36:45,108 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_third", elapsed time 1.278012s.
# 230611-12:36:45,119 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_third", elapsed time 1.250424s.
# 230611-12:36:45,666 nipype.workflow INFO:
# 	 [Job 4] Completed (level3.copemerge_third).
# 230611-12:36:45,670 nipype.workflow INFO:
# 	 [Job 5] Completed (level3.varcopemerge_third).
# 230611-12:36:45,671 nipype.workflow INFO:
# 	 [Job 6] Completed (level3.maskmerge_third).
# 230611-12:36:45,673 nipype.workflow INFO:
# 	 [Job 7] Completed (level3.l3model).
# 230611-12:36:45,675 nipype.workflow INFO:
# 	 [Job 8] Completed (level3.copemerge_third).
# 230611-12:36:45,676 nipype.workflow INFO:
# 	 [Job 9] Completed (level3.varcopemerge_third).
# 230611-12:36:45,677 nipype.workflow INFO:
# 	 [Job 10] Completed (level3.maskmerge_third).
# 230611-12:36:45,678 nipype.workflow INFO:
# 	 [Job 11] Completed (level3.l3model).
# 230611-12:36:45,681 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:36:45,782 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:45,790 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.copemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/copemerge_third".
# 230611-12:36:45,794 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:45,792 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:45,800 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:45,800 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.varcopemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/varcopemerge_third".
# 230611-12:36:45,798 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:45,806 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:45,814 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:45,814 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:45,821 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:45,822 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.l3model" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/l3model".
# 230611-12:36:45,826 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:45,829 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.copemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/copemerge_third".
# 230611-12:36:45,830 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.L2Model>
# 230611-12:36:45,831 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:45,807 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskmerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/maskmerge_third".
# 230611-12:36:45,831 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.copemerge_third".
# 230611-12:36:45,841 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:45,841 nipype.workflow INFO:
# 	 [Node] Executing "copemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:45,834 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:45,832 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.000629s.
# 230611-12:36:45,845 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.varcopemerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/varcopemerge_third".
# 230611-12:36:45,851 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:45,854 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.varcopemerge_third".
# 230611-12:36:45,860 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.l3model" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/l3model".
# 230611-12:36:45,861 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.l3model".
# 230611-12:36:45,860 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskmerge_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/maskmerge_third".
# 230611-12:36:45,847 nipype.workflow INFO:
# 	 [Node] Executing "maskmerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:45,864 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:45,890 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskmerge_third".
# 230611-12:36:45,895 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.L2Model>
# 230611-12:36:45,909 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.001157s.
# 230611-12:36:45,914 nipype.workflow INFO:
# 	 [Node] Executing "maskmerge_third" <nipype.interfaces.fsl.utils.Merge>
# 230611-12:36:46,699 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_third", elapsed time 0.772929s.
# 230611-12:36:46,719 nipype.workflow INFO:
# 	 [Node] Finished "maskmerge_third", elapsed time 0.828082s.
# 230611-12:36:47,35 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_third", elapsed time 1.190758s.
# 230611-12:36:47,139 nipype.workflow INFO:
# 	 [Node] Finished "copemerge_third", elapsed time 1.326321s.
# 230611-12:36:47,139 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_third", elapsed time 1.321335s.
# 230611-12:36:47,230 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge_third", elapsed time 1.330892s.
# 230611-12:36:47,671 nipype.workflow INFO:
# 	 [Job 12] Completed (level3.copemerge_third).
# 230611-12:36:47,672 nipype.workflow INFO:
# 	 [Job 13] Completed (level3.varcopemerge_third).
# 230611-12:36:47,674 nipype.workflow INFO:
# 	 [Job 14] Completed (level3.maskmerge_third).
# 230611-12:36:47,675 nipype.workflow INFO:
# 	 [Job 15] Completed (level3.l3model).
# 230611-12:36:47,676 nipype.workflow INFO:
# 	 [Job 16] Completed (level3.copemerge_third).
# 230611-12:36:47,677 nipype.workflow INFO:
# 	 [Job 17] Completed (level3.varcopemerge_third).
# 230611-12:36:47,679 nipype.workflow INFO:
# 	 [Job 18] Completed (level3.maskmerge_third).
# 230611-12:36:47,681 nipype.workflow INFO:
# 	 [Job 19] Completed (level3.l3model).
# 230611-12:36:47,685 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:36:47,800 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,805 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,805 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.minmask_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/minmask_third".
# 230611-12:36:47,806 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,809 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,809 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.minmask_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/minmask_third".
# 230611-12:36:47,809 nipype.workflow INFO:
# 	 [Node] Executing "minmask_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:47,811 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,812 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.minmask_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/minmask_third".
# 230611-12:36:47,813 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,814 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,815 nipype.workflow INFO:
# 	 [Node] Executing "minmask_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:47,817 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.minmask_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/minmask_third".
# 230611-12:36:47,819 nipype.workflow INFO:
# 	 [Node] Executing "minmask_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:47,819 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.minmask_third".
# 230611-12:36:47,827 nipype.workflow INFO:
# 	 [Node] Executing "minmask_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,110 nipype.workflow INFO:
# 	 [Node] Finished "minmask_third", elapsed time 1.288561s.
# 230611-12:36:49,227 nipype.workflow INFO:
# 	 [Node] Finished "minmask_third", elapsed time 1.396408s.
# 230611-12:36:49,252 nipype.workflow INFO:
# 	 [Node] Finished "minmask_third", elapsed time 1.435186s.
# 230611-12:36:49,398 nipype.workflow INFO:
# 	 [Node] Finished "minmask_third", elapsed time 1.586186s.
# 230611-12:36:49,671 nipype.workflow INFO:
# 	 [Job 20] Completed (level3.minmask_third).
# 230611-12:36:49,672 nipype.workflow INFO:
# 	 [Job 21] Completed (level3.minmask_third).
# 230611-12:36:49,674 nipype.workflow INFO:
# 	 [Job 22] Completed (level3.minmask_third).
# 230611-12:36:49,675 nipype.workflow INFO:
# 	 [Job 23] Completed (level3.minmask_third).
# 230611-12:36:49,676 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:36:49,761 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,763 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/maskcope_third".
# 230611-12:36:49,764 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,765 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,767 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,770 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskvarcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/maskvarcope_third".
# 230611-12:36:49,772 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,774 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,775 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,777 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/maskcope_third".
# 230611-12:36:49,778 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,780 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,781 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,782 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskvarcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/maskvarcope_third".
# 230611-12:36:49,787 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,788 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,792 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/maskcope_third".
# 230611-12:36:49,794 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,794 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,798 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,797 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskvarcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/maskvarcope_third".
# 230611-12:36:49,799 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,792 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,800 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,808 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/maskcope_third".
# 230611-12:36:49,814 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,823 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,842 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.maskvarcope_third" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/maskvarcope_third".
# 230611-12:36:49,842 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskcope_third".
# 230611-12:36:49,861 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.maskvarcope_third".
# 230611-12:36:49,873 nipype.workflow INFO:
# 	 [Node] Executing "maskvarcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:49,876 nipype.workflow INFO:
# 	 [Node] Executing "maskcope_third" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:36:51,148 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_third", elapsed time 1.377757s.
# 230611-12:36:51,172 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_third", elapsed time 1.296483s.
# 230611-12:36:51,308 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_third", elapsed time 1.4765570000000001s.
# 230611-12:36:51,384 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_third", elapsed time 1.582978s.
# 230611-12:36:51,414 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_third", elapsed time 1.6360890000000001s.
# 230611-12:36:51,425 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_third", elapsed time 1.641281s.
# 230611-12:36:51,460 nipype.workflow INFO:
# 	 [Node] Finished "maskvarcope_third", elapsed time 1.6534659999999999s.
# 230611-12:36:51,672 nipype.workflow INFO:
# 	 [Job 24] Completed (level3.maskcope_third).
# 230611-12:36:51,674 nipype.workflow INFO:
# 	 [Job 25] Completed (level3.maskvarcope_third).
# 230611-12:36:51,676 nipype.workflow INFO:
# 	 [Job 26] Completed (level3.maskcope_third).
# 230611-12:36:51,678 nipype.workflow INFO:
# 	 [Job 27] Completed (level3.maskvarcope_third).
# 230611-12:36:51,679 nipype.workflow INFO:
# 	 [Job 28] Completed (level3.maskcope_third).
# 230611-12:36:51,681 nipype.workflow INFO:
# 	 [Job 29] Completed (level3.maskvarcope_third).
# 230611-12:36:51,682 nipype.workflow INFO:
# 	 [Job 31] Completed (level3.maskvarcope_third).
# 230611-12:36:51,688 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 17.20/17.40, Free processors: 7/8.
#                      Currently running:
#                        * level3.maskcope_third
# 230611-12:36:51,696 nipype.workflow INFO:
# 	 [Node] Finished "maskcope_third", elapsed time 1.814603s.
# 230611-12:36:51,782 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:51,787 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3estimate" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/level3estimate".
# 230611-12:36:51,789 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:51,792 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:51,792 nipype.workflow INFO:
# 	 [Node] Executing "level3estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:36:51,795 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3estimate" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/level3estimate".
# 230611-12:36:51,796 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:51,799 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:51,801 nipype.workflow INFO:
# 	 [Node] Executing "level3estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:36:51,805 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3estimate" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/level3estimate".
# 230611-12:36:51,807 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:51,813 nipype.workflow INFO:
# 	 [Node] Executing "level3estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:36:53,675 nipype.workflow INFO:
# 	 [Job 30] Completed (level3.maskcope_third).
# 230611-12:36:53,688 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 16.80/17.40, Free processors: 5/8.
#                      Currently running:
#                        * level3.level3estimate
#                        * level3.level3estimate
#                        * level3.level3estimate
# 230611-12:36:53,816 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:53,821 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3estimate" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/level3estimate".
# 230611-12:36:53,823 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3estimate".
# 230611-12:36:53,828 nipype.workflow INFO:
# 	 [Node] Executing "level3estimate" <nipype.interfaces.fsl.model.FLAMEO>
# 230611-12:36:55,678 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 16.60/17.40, Free processors: 4/8.
#                      Currently running:
#                        * level3.level3estimate
#                        * level3.level3estimate
#                        * level3.level3estimate
#                        * level3.level3estimate
# 230611-12:37:23,885 nipype.workflow INFO:
# 	 [Node] Finished "level3estimate", elapsed time 32.090891s.
# 230611-12:37:25,340 nipype.workflow INFO:
# 	 [Node] Finished "level3estimate", elapsed time 33.535725s.
# 230611-12:37:25,708 nipype.workflow INFO:
# 	 [Job 32] Completed (level3.level3estimate).
# 230611-12:37:25,710 nipype.workflow INFO:
# 	 [Job 33] Completed (level3.level3estimate).
# 230611-12:37:25,713 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * level3.level3estimate
#                        * level3.level3estimate
# 230611-12:37:25,811 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:25,814 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.smoothest" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/smoothest".
# 230611-12:37:25,815 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:25,817 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:25,820 nipype.workflow INFO:
# 	 [Node] Executing "smoothest" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230611-12:37:25,821 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3mask" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/level3mask".
# 230611-12:37:25,822 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:25,827 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:25,826 nipype.workflow INFO:
# 	 [Node] Executing "level3mask" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:37:25,833 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:25,836 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3mask" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/level3mask".
# 230611-12:37:25,830 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.smoothest" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/smoothest".
# 230611-12:37:25,838 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:25,840 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:25,844 nipype.workflow INFO:
# 	 [Node] Executing "smoothest" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230611-12:37:25,843 nipype.workflow INFO:
# 	 [Node] Executing "level3mask" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:37:26,360 nipype.workflow INFO:
# 	 [Node] Finished "level3mask", elapsed time 0.532084s.
# 230611-12:37:26,377 nipype.workflow INFO:
# 	 [Node] Finished "level3mask", elapsed time 0.527458s.
# 230611-12:37:26,649 nipype.workflow INFO:
# 	 [Node] Finished "smoothest", elapsed time 0.82755s.
# 230611-12:37:26,840 nipype.workflow INFO:
# 	 [Node] Finished "smoothest", elapsed time 0.993703s.
# 230611-12:37:27,710 nipype.workflow INFO:
# 	 [Job 36] Completed (level3.smoothest).
# 230611-12:37:27,711 nipype.workflow INFO:
# 	 [Job 37] Completed (level3.level3mask).
# 230611-12:37:27,713 nipype.workflow INFO:
# 	 [Job 38] Completed (level3.smoothest).
# 230611-12:37:27,714 nipype.workflow INFO:
# 	 [Job 39] Completed (level3.level3mask).
# 230611-12:37:27,716 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 17.00/17.40, Free processors: 6/8.
#                      Currently running:
#                        * level3.level3estimate
#                        * level3.level3estimate
# 230611-12:37:27,827 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:27,839 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:27,839 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3threshold" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/level3threshold".
# 230611-12:37:27,842 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3threshold" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/level3threshold".
# 230611-12:37:27,843 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:27,844 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:27,847 nipype.workflow INFO:
# 	 [Node] Executing "level3threshold" <nipype.interfaces.fsl.model.Cluster>
# 230611-12:37:27,850 nipype.workflow INFO:
# 	 [Node] Executing "level3threshold" <nipype.interfaces.fsl.model.Cluster>
# 230611-12:37:28,22 nipype.workflow INFO:
# 	 [Node] Finished "level3estimate", elapsed time 34.191596s.
# 230611-12:37:28,309 nipype.workflow INFO:
# 	 [Node] Finished "level3threshold", elapsed time 0.453836s.
# 230611-12:37:28,385 nipype.workflow INFO:
# 	 [Node] Finished "level3threshold", elapsed time 0.529664s.
# 230611-12:37:28,752 nipype.workflow INFO:
# 	 [Node] Finished "level3estimate", elapsed time 36.936564s.
# 230611-12:37:29,710 nipype.workflow INFO:
# 	 [Job 34] Completed (level3.level3estimate).
# 230611-12:37:29,712 nipype.workflow INFO:
# 	 [Job 35] Completed (level3.level3estimate).
# 230611-12:37:29,713 nipype.workflow INFO:
# 	 [Job 44] Completed (level3.level3threshold).
# 230611-12:37:29,714 nipype.workflow INFO:
# 	 [Job 45] Completed (level3.level3threshold).
# 230611-12:37:29,717 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:37:29,808 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:29,810 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.smoothest" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/smoothest".
# 230611-12:37:29,811 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:29,812 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:29,814 nipype.workflow INFO:
# 	 [Node] Executing "smoothest" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230611-12:37:29,814 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3mask" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/level3mask".
# 230611-12:37:29,816 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:29,820 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:29,821 nipype.workflow INFO:
# 	 [Node] Executing "level3mask" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:37:29,827 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:29,826 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.smoothest" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/smoothest".
# 230611-12:37:29,827 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.smoothest".
# 230611-12:37:29,830 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3mask" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/level3mask".
# 230611-12:37:29,836 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:29,831 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3mask".
# 230611-12:37:29,831 nipype.workflow INFO:
# 	 [Node] Executing "smoothest" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230611-12:37:29,858 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:29,858 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.sinker" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_1/sinker".
# 230611-12:37:29,851 nipype.workflow INFO:
# 	 [Node] Executing "level3mask" <nipype.interfaces.fsl.utils.ImageMaths>
# 230611-12:37:29,860 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:29,866 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:37:29,871 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.sinker" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_2/sinker".
# 230611-12:37:29,875 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:29,880 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:37:30,194 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.325675s.
# 230611-12:37:30,188 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.305419s.
# 230611-12:37:30,297 nipype.workflow INFO:
# 	 [Node] Finished "level3mask", elapsed time 0.474489s.
# 230611-12:37:30,334 nipype.workflow INFO:
# 	 [Node] Finished "level3mask", elapsed time 0.47101s.
# 230611-12:37:30,634 nipype.workflow INFO:
# 	 [Node] Finished "smoothest", elapsed time 0.818463s.
# 230611-12:37:30,714 nipype.workflow INFO:
# 	 [Node] Finished "smoothest", elapsed time 0.861542s.
# 230611-12:37:31,712 nipype.workflow INFO:
# 	 [Job 40] Completed (level3.smoothest).
# 230611-12:37:31,714 nipype.workflow INFO:
# 	 [Job 41] Completed (level3.level3mask).
# 230611-12:37:31,717 nipype.workflow INFO:
# 	 [Job 42] Completed (level3.smoothest).
# 230611-12:37:31,719 nipype.workflow INFO:
# 	 [Job 43] Completed (level3.level3mask).
# 230611-12:37:31,721 nipype.workflow INFO:
# 	 [Job 48] Completed (level3.sinker).
# 230611-12:37:31,723 nipype.workflow INFO:
# 	 [Job 49] Completed (level3.sinker).
# 230611-12:37:31,725 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:37:31,812 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:31,814 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3threshold" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/level3threshold".
# 230611-12:37:31,815 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:31,816 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:31,819 nipype.workflow INFO:
# 	 [Node] Executing "level3threshold" <nipype.interfaces.fsl.model.Cluster>
# 230611-12:37:31,820 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.level3threshold" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/level3threshold".
# 230611-12:37:31,822 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.level3threshold".
# 230611-12:37:31,824 nipype.workflow INFO:
# 	 [Node] Executing "level3threshold" <nipype.interfaces.fsl.model.Cluster>
# 230611-12:37:32,207 nipype.workflow INFO:
# 	 [Node] Finished "level3threshold", elapsed time 0.38596s.
# 230611-12:37:32,220 nipype.workflow INFO:
# 	 [Node] Finished "level3threshold", elapsed time 0.394656s.
# 230611-12:37:33,714 nipype.workflow INFO:
# 	 [Job 46] Completed (level3.level3threshold).
# 230611-12:37:33,716 nipype.workflow INFO:
# 	 [Job 47] Completed (level3.level3threshold).
# 230611-12:37:33,719 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.
# 230611-12:37:33,826 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:33,829 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.sinker" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_3/sinker".
# 230611-12:37:33,830 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:33,833 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:37:33,836 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:33,839 nipype.workflow INFO:
# 	 [Node] Setting-up "level3.sinker" in "/neurodesktop-storage/Data/Flanker/output_level3/level3/_contr_id_4/sinker".
# 230611-12:37:33,840 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level3.sinker".
# 230611-12:37:33,844 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230611-12:37:34,73 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.237712s.
# 230611-12:37:34,95 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.249265s.
# 230611-12:37:35,714 nipype.workflow INFO:
# 	 [Job 50] Completed (level3.sinker).
# 230611-12:37:35,716 nipype.workflow INFO:
# 	 [Job 51] Completed (level3.sinker).
# 230611-12:37:35,720 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 17.40/17.40, Free processors: 8/8.

# %% [markdown]
# ## Unthresholded COPEs

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_1/stats_dir/_contr_id_1/stats/cope1.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_2/stats_dir/_contr_id_2/stats/cope1.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_3/stats_dir/_contr_id_3/stats/cope1.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_4/stats_dir/_contr_id_4/stats/cope1.nii.gz'

# %%
t_nipype_cope1 = surface.vol_to_surf(nipype_cope1, fsaverage.pial_right)
plotting.plot_surf_stat_map(
        fsaverage.infl_right, t_nipype_cope1, hemi='right',
        title="Nipype - COPE1", colorbar=False,
        cmap = 'bwr', bg_map=fsaverage.sulc_right)
plt.show()


t_nipype_cope2 = surface.vol_to_surf(nipype_cope2, fsaverage.pial_right)
plotting.plot_surf_stat_map(
        fsaverage.infl_right, t_nipype_cope2, hemi='right',
        title="Nipype - COPE2", colorbar=False,
        cmap = 'bwr', bg_map=fsaverage.sulc_right)
plt.show()


t_nipype_cope3 = surface.vol_to_surf(nipype_cope3, fsaverage.pial_right)
plotting.plot_surf_stat_map(
        fsaverage.infl_right, t_nipype_cope3, hemi='right',
        title="Nipype - COPE3", colorbar=False,
        cmap = 'bwr', bg_map=fsaverage.sulc_right)
plt.show()


t_nipype_cope4 = surface.vol_to_surf(nipype_cope4, fsaverage.pial_right)
plotting.plot_surf_stat_map(
        fsaverage.infl_right, t_nipype_cope4, hemi='right',
        title="Nipype - COPE4", colorbar=False,
        cmap = 'bwr', bg_map=fsaverage.sulc_right)
plt.show()

# %% [markdown]
# ### Thresholded (p < 0.05) zstats

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_1/thresholded/_contr_id_1/zstat1_maths_threshold.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_2/thresholded/_contr_id_2/zstat1_maths_threshold.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_3/thresholded/_contr_id_3/zstat1_maths_threshold.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level3/level3_results/contrast_4/thresholded/_contr_id_4/zstat1_maths_threshold.nii.gz'

# %%
plotting.plot_img_on_surf(nipype_cope1,
                          views=['lateral'],
                          hemispheres=['right'],
                          title="Nipype - Thresholded-zstats1",
                          cmap = 'hot', colorbar=True)
plotting.show()

plotting.plot_img_on_surf(nipype_cope2,
                          views=['lateral'],
                          hemispheres=['right'],
                          title="Nipype - Thresholded-zstats2",
                          cmap = 'hot', colorbar=True)
plotting.show()

plotting.plot_img_on_surf(nipype_cope3,
                          views=['lateral'],
                          hemispheres=['right'],
                          title="Nipype - Thresholded-zstats3",
                          cmap = 'hot', colorbar=True)
plotting.show()

plotting.plot_img_on_surf(nipype_cope4,
                          views=['lateral'],
                          hemispheres=['right'],
                          title="Nipype - Thresholded-zstats4",
                          cmap = 'hot', colorbar=True)
plotting.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/nilearn/plotting/surf_plotting.py:508: RuntimeWarning: invalid value encountered in divide
#   data_copy /= (vmax - vmin)
# /opt/conda/lib/python3.10/site-packages/nilearn/plotting/surf_plotting.py:508: RuntimeWarning: invalid value encountered in divide
#   data_copy /= (vmax - vmin)
