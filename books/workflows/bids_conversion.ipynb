# %% [markdown]
# <a href="https://colab.research.google.com/github/NeuroDesk/example-notebooks/blob/main/books/workflows/bids_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Google Colab"/>   </a>

# %% [markdown]
# # BIDS conversion
#
# Author: Thuy Dao
#
# Citation:
# - dcm2niix: https://doi.org/10.1016/j.jneumeth.2016.03.001
# - bidscoin: https://doi.org/10.3389/fninf.2021.770608
# - heudiconv: https://doi.org/10.5281/zenodo.1012598
# - FSL: https://doi.org/10.1016/j.neuroimage.2011.09.015
# - OSF: https://doi.org/10.5195/jmla.2017.88
# - NiiVue: https://github.com/niivue/niivue

# %% [markdown]
# ## Setup Neurodesk

# %%
# %%capture
import os
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  os.environ["LD_PRELOAD"] = "";
  os.environ["APPTAINER_BINDPATH"] = "/content,/tmp,/cvmfs"
  os.environ["MPLCONFIGDIR"] = "/content/matplotlib-mpldir"
  os.environ["LMOD_CMD"] = "/usr/share/lmod/lmod/libexec/lmod"

  # !curl -J -O https://raw.githubusercontent.com/NeuroDesk/neurocommand/main/googlecolab_setup.sh
  # !chmod +x googlecolab_setup.sh
  # !./googlecolab_setup.sh

  os.environ["MODULEPATH"] = ':'.join(map(str, list(map(lambda x: os.path.join(os.path.abspath('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/'), x),os.listdir('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/')))))

# %%
# Output CPU information:
# !cat /proc/cpuinfo | grep 'vendor' | uniq
# !cat /proc/cpuinfo | grep 'model name' | uniq
# Out:
# vendor_id	: AuthenticAMD
# model name	: AMD EPYC 7742 64-Core Processor

# %% [markdown]
# ## BIDS conversion and Open data sharing
#
# 1. In this interactive example notebook, we first download DICOM data using `datalad`.
#
# 2. Next we will convert DICOMS into the BIDS data structure using:
#     - 2.1. `dcm2niix` which convert data to NIfTi and then manually organize the folder.
#     - 2.2. `heudiconv` to automate the conversion and organization with a provided heuristic file.
#     - 2.3. `bidscoin` to automate the conversion and organization with bideditor interface.
#
# 3. We will then run skull stripping using FSL BET.
#
# 4. Finally, we will upload output from FSL BET to share in OSF project.

# %% [markdown]
# ## 1. Data preparation
#
# Download DICOM data from OSF

# %%
# %%bash
# datalad install https://datasets.datalad.org/repronim/heudiconv-reproin-example
# cd heudiconv-reproin-example/REPROIN/dicom && datalad get 001
# Out:
# Cloning: 100%|██████████████████████| 2.00/2.00 [00:01<00:00, 1.22 candidates/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Counting:   0%|                              | 0.00/12.4k [00:00<?, ? Objects/s]
# Counting:   5%|█▏                     | 619/12.4k [00:00<00:02, 4.09k Objects/s]
#
# Compressing:   0%|                           | 0.00/6.00k [00:00<?, ? Objects/s]
#
# Receiving:   0%|                             | 0.00/12.4k [00:00<?, ? Objects/s]
# Receiving:   1%|▏                       | 124/12.4k [00:00<00:15, 786 Objects/s]
# Receiving:   6%|█▎                    | 743/12.4k [00:00<00:05, 2.05k Objects/s]
# Receiving:  18%|███▌                | 2.23k/12.4k [00:00<00:01, 5.79k Objects/s]
# Receiving:  25%|█████               | 3.09k/12.4k [00:00<00:01, 5.53k Objects/s]
# Receiving:  44%|████████▊           | 5.44k/12.4k [00:00<00:00, 7.82k Objects/s]
# Receiving:  75%|███████████████     | 9.28k/12.4k [00:00<00:00, 14.5k Objects/s]
#
# Resolving:   0%|                              | 0.00/3.17k [00:00<?, ? Deltas/s]
# Resolving:  72%|███████████████      | 2.29k/3.17k [00:00<00:00, 22.8k Deltas/s]
# [INFO   ] scanning for unlocked files (this may take some time)
# install(ok): /data/books/workflows/heudiconv-reproin-example (dataset)
# Total:   0%|                                    | 0.00/188M [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0001.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0001.dcm:  51%|██▌  | 87.9k/174k [00:00<00:00, 175k Bytes/s]
# Total:   0%|                          | 174k/188M [00:07<2:15:20, 23.1k Bytes/s]
# Get REPROIN/ .. 001-0002.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Total:   0%|                          | 348k/188M [00:10<1:31:04, 34.3k Bytes/s]
# Get REPROIN/ .. 001-0003.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Total:   0%|                          | 522k/188M [00:12<1:12:04, 43.2k Bytes/s]
# Get REPROIN/ .. 001-0005.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   0%|▏                           | 863k/188M [00:15<57:33, 54.0k Bytes/s]
# Get REPROIN/ .. 002-0001.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 002-0002.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Total:   1%|▏                          | 1.21M/188M [00:19<49:48, 62.3k Bytes/s]
# Get REPROIN/ .. 002-0003.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 002-0004.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   1%|▏                          | 1.73M/188M [00:29<53:28, 57.9k Bytes/s]
# Get REPROIN/ .. 003-0001.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Total:   1%|▎                          | 1.90M/188M [00:31<51:27, 60.1k Bytes/s]
# Get REPROIN/ .. 003-0002.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Total:   1%|▎                          | 2.07M/188M [00:33<49:42, 62.2k Bytes/s]
# Get REPROIN/ .. 003-0003.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
# Total:   1%|▎                          | 2.25M/188M [00:35<49:05, 62.9k Bytes/s]
# Get REPROIN/ .. 003-0005.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   1%|▎                          | 2.59M/188M [00:40<47:42, 64.6k Bytes/s]
# Get REPROIN/ .. 004-0001.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 004-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   2%|▍                          | 2.93M/188M [00:43<45:41, 67.3k Bytes/s]
# Get REPROIN/ .. 004-0003.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 005-0001.dcm:   0%|             | 0.00/174k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 005-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   2%|▍                          | 3.45M/188M [00:50<44:49, 68.4k Bytes/s]
# Get REPROIN/ .. 005-0003.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 006-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 006-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 007-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   2%|▌                          | 4.12M/188M [00:58<43:18, 70.6k Bytes/s]
# Get REPROIN/ .. 007-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 008-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 008-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 009-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   3%|▋                          | 4.81M/188M [01:06<42:01, 72.4k Bytes/s]
# Get REPROIN/ .. 009-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 010-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 010-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 011-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   3%|▊                          | 5.66M/188M [01:16<41:06, 73.7k Bytes/s]
# Get REPROIN/ .. 012-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   3%|▉                          | 6.17M/188M [01:24<41:14, 73.3k Bytes/s]
# Get REPROIN/ .. 013-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 014-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   3%|▉                          | 6.51M/188M [01:29<41:23, 72.9k Bytes/s]
# Get REPROIN/ .. 014-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   4%|▉                          | 6.85M/188M [01:32<40:49, 73.8k Bytes/s]
# Get REPROIN/ .. 016-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 016-0001.dcm:  79%|████▋ | 136k/173k [00:00<00:00, 272k Bytes/s]
# Total:   4%|█                          | 7.19M/188M [01:42<42:57, 70.0k Bytes/s]
# Get REPROIN/ .. 017-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   4%|█                          | 7.70M/188M [01:50<42:53, 69.9k Bytes/s]
# Get REPROIN/ .. 018-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 018-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   4%|█▏                         | 8.21M/188M [01:56<42:17, 70.6k Bytes/s]
# Get REPROIN/ .. 019-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 020-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 020-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 021-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   5%|█▎                         | 8.89M/188M [02:04<41:35, 71.6k Bytes/s]
# Get REPROIN/ .. 021-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 022-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 022-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 023-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   5%|█▍                         | 9.58M/188M [02:11<40:43, 72.8k Bytes/s]
# Get REPROIN/ .. 023-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 024-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 024-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 025-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 025-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   6%|█▌                         | 10.4M/188M [02:20<39:44, 74.3k Bytes/s]
# Get REPROIN/ .. 026-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 026-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 027-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 027-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 028-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   6%|█▌                         | 11.3M/188M [02:30<39:15, 74.8k Bytes/s]
# Get REPROIN/ .. 028-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   6%|█▋                         | 11.4M/188M [02:32<39:05, 75.1k Bytes/s]
# Get REPROIN/ .. 029-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   6%|█▋                         | 11.6M/188M [02:34<38:54, 75.3k Bytes/s]
# Get REPROIN/ .. 029-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 030-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   6%|█▋                         | 12.0M/188M [02:37<38:37, 75.7k Bytes/s]
# Get REPROIN/ .. 030-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 031-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   7%|█▊                         | 12.3M/188M [02:41<38:18, 76.2k Bytes/s]
# Get REPROIN/ .. 031-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 032-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   7%|█▊                         | 12.6M/188M [02:44<38:01, 76.6k Bytes/s]
# Get REPROIN/ .. 032-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 033-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 033-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:   7%|█▉                         | 13.1M/188M [02:51<37:49, 76.8k Bytes/s]
# Get REPROIN/ .. 034-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 034-0001.dcm:  67%|███▉  | 112k/168k [00:00<00:00, 223k Bytes/s]
#
# Get REPROIN/ .. 034-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 035-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   7%|█▉                         | 13.7M/188M [03:00<38:14, 75.7k Bytes/s]
# Get REPROIN/ .. 035-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 036-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 036-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 037-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   8%|██                         | 14.3M/188M [03:07<37:42, 76.5k Bytes/s]
# Get REPROIN/ .. 037-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 038-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 038-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 039-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   8%|██▏                        | 15.0M/188M [03:14<37:13, 77.2k Bytes/s]
# Get REPROIN/ .. 039-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 040-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 040-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 041-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   8%|██▎                        | 15.7M/188M [03:21<36:46, 77.9k Bytes/s]
# Get REPROIN/ .. 042-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 042-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 043-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   9%|██▎                        | 16.4M/188M [03:29<36:28, 78.2k Bytes/s]
# Get REPROIN/ .. 043-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 044-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 044-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 045-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   9%|██▍                        | 17.1M/188M [03:36<36:04, 78.8k Bytes/s]
# Get REPROIN/ .. 045-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 046-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 046-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 047-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:   9%|██▌                        | 17.7M/188M [03:43<35:41, 79.3k Bytes/s]
# Get REPROIN/ .. 047-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 048-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 048-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 049-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 049-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  10%|██▋                        | 18.6M/188M [03:52<35:13, 79.9k Bytes/s]
# Get REPROIN/ .. 050-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 050-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 051-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 051-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 052-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  10%|██▊                        | 19.4M/188M [04:01<34:48, 80.5k Bytes/s]
# Get REPROIN/ .. 052-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 053-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 054-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  11%|██▉                        | 20.3M/188M [04:12<34:36, 80.5k Bytes/s]
# Get REPROIN/ .. 055-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  11%|██▉                        | 20.5M/188M [04:14<34:36, 80.4k Bytes/s]
# Get REPROIN/ .. 055-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 056-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  11%|██▉                        | 20.8M/188M [04:18<34:34, 80.4k Bytes/s]
# Get REPROIN/ .. 056-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 057-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  11%|███                        | 21.2M/188M [04:23<34:35, 80.1k Bytes/s]
# Get REPROIN/ .. 057-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 058-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  12%|███                        | 21.7M/188M [04:29<34:21, 80.4k Bytes/s]
# Get REPROIN/ .. 059-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  12%|███▏                       | 22.2M/188M [04:36<34:23, 80.1k Bytes/s]
# Get REPROIN/ .. 060-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 061-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  12%|███▎                       | 22.8M/188M [04:46<34:25, 79.7k Bytes/s]
# Get REPROIN/ .. 062-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 063-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 063-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 064-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  13%|███▍                       | 23.5M/188M [04:53<34:08, 80.0k Bytes/s]
# Get REPROIN/ .. 064-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 065-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 065-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  13%|███▍                       | 24.2M/188M [05:01<33:54, 80.2k Bytes/s]
# Get REPROIN/ .. 066-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 067-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 067-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 068-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  13%|███▋                       | 25.2M/188M [05:19<34:13, 79.0k Bytes/s]
# Get REPROIN/ .. 069-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  14%|███▋                       | 25.4M/188M [05:21<34:08, 79.1k Bytes/s]
# Get REPROIN/ .. 070-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  14%|███▋                       | 25.7M/188M [05:24<34:00, 79.3k Bytes/s]
# Get REPROIN/ .. 071-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 071-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  14%|███▊                       | 26.1M/188M [05:28<33:51, 79.5k Bytes/s]
# Get REPROIN/ .. 072-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 072-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  14%|███▊                       | 26.4M/188M [05:31<33:42, 79.7k Bytes/s]
# Get REPROIN/ .. 073-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 073-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  14%|███▊                       | 26.8M/188M [05:35<33:33, 79.8k Bytes/s]
# Get REPROIN/ .. 074-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 074-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  14%|███▉                       | 27.1M/188M [05:38<33:25, 80.0k Bytes/s]
# Get REPROIN/ .. 075-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 075-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  15%|███▉                       | 27.4M/188M [05:43<33:21, 80.0k Bytes/s]
# Get REPROIN/ .. 076-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 076-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  15%|████                       | 27.8M/188M [05:46<33:13, 80.1k Bytes/s]
# Get REPROIN/ .. 077-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  15%|████                       | 28.1M/188M [05:50<33:08, 80.1k Bytes/s]
# Get REPROIN/ .. 078-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 078-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  15%|████                       | 28.5M/188M [05:54<33:00, 80.3k Bytes/s]
# Get REPROIN/ .. 079-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 079-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 079-0002.dcm:  83%|█████ | 144k/173k [00:00<00:00, 287k Bytes/s]
# Total:  15%|████▏                      | 29.0M/188M [06:06<33:27, 79.0k Bytes/s]
# Get REPROIN/ .. 080-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  16%|████▏                      | 29.1M/188M [06:08<33:23, 79.0k Bytes/s]
# Get REPROIN/ .. 081-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 081-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  16%|████▏                      | 29.5M/188M [06:12<33:14, 79.2k Bytes/s]
# Get REPROIN/ .. 082-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 082-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  16%|████▎                      | 29.8M/188M [06:16<33:10, 79.2k Bytes/s]
# Get REPROIN/ .. 083-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 083-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  16%|████▎                      | 30.2M/188M [06:20<33:06, 79.2k Bytes/s]
# Get REPROIN/ .. 084-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 084-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  16%|████▍                      | 30.5M/188M [06:25<33:01, 79.2k Bytes/s]
# Get REPROIN/ .. 085-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 085-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  16%|████▍                      | 30.8M/188M [06:28<32:53, 79.4k Bytes/s]
# Get REPROIN/ .. 086-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 086-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  17%|████▍                      | 31.2M/188M [06:32<32:45, 79.5k Bytes/s]
# Get REPROIN/ .. 087-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 087-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  17%|████▌                      | 31.5M/188M [06:35<32:38, 79.7k Bytes/s]
# Get REPROIN/ .. 088-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  17%|████▌                      | 31.9M/188M [06:39<32:30, 79.8k Bytes/s]
# Get REPROIN/ .. 089-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 089-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  17%|████▋                      | 32.2M/188M [06:43<32:22, 79.9k Bytes/s]
# Get REPROIN/ .. 090-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  17%|████▋                      | 32.6M/188M [06:47<32:18, 79.9k Bytes/s]
# Get REPROIN/ .. 091-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 091-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  18%|████▋                      | 32.9M/188M [06:50<32:11, 80.1k Bytes/s]
# Get REPROIN/ .. 092-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 092-0001.dcm:  86%|█████▏| 144k/168k [00:00<00:00, 287k Bytes/s]
#
# Get REPROIN/ .. 092-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  18%|████▊                      | 33.2M/188M [06:58<32:21, 79.5k Bytes/s]
# Get REPROIN/ .. 093-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 093-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  18%|████▊                      | 33.6M/188M [07:02<32:17, 79.5k Bytes/s]
# Get REPROIN/ .. 094-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 094-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  18%|████▉                      | 33.9M/188M [07:06<32:09, 79.6k Bytes/s]
# Get REPROIN/ .. 095-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 095-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  18%|████▉                      | 34.6M/188M [07:19<32:20, 78.8k Bytes/s]
# Get REPROIN/ .. 097-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 097-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  19%|█████                      | 34.9M/188M [07:23<32:16, 78.8k Bytes/s]
# Get REPROIN/ .. 098-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  19%|█████                      | 35.3M/188M [07:27<32:11, 78.8k Bytes/s]
# Get REPROIN/ .. 099-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 099-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  19%|█████▏                     | 35.6M/188M [07:31<32:07, 78.8k Bytes/s]
# Get REPROIN/ .. 100-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  19%|█████▏                     | 36.0M/188M [07:35<31:59, 78.9k Bytes/s]
# Get REPROIN/ .. 101-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 101-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  19%|█████▏                     | 36.3M/188M [07:38<31:51, 79.1k Bytes/s]
# Get REPROIN/ .. 102-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  20%|█████▎                     | 36.6M/188M [07:45<31:58, 78.6k Bytes/s]
# Get REPROIN/ .. 103-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 103-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  20%|█████▎                     | 37.0M/188M [07:49<31:50, 78.8k Bytes/s]
# Get REPROIN/ .. 104-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  20%|█████▎                     | 37.3M/188M [07:52<31:43, 78.9k Bytes/s]
# Get REPROIN/ .. 105-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  20%|█████▍                     | 37.7M/188M [07:57<31:38, 78.9k Bytes/s]
# Get REPROIN/ .. 106-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 106-0002.dcm:  46%|██▎  | 79.9k/173k [00:00<00:00, 159k Bytes/s]
# Total:  20%|█████▍                     | 38.0M/188M [08:02<31:37, 78.8k Bytes/s]
# Get REPROIN/ .. 107-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  20%|█████▌                     | 38.3M/188M [08:05<31:29, 78.9k Bytes/s]
# Get REPROIN/ .. 108-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 108-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  21%|█████▌                     | 38.7M/188M [08:17<31:54, 77.7k Bytes/s]
# Get REPROIN/ .. 109-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  21%|█████▌                     | 38.8M/188M [08:19<31:51, 77.8k Bytes/s]
# Get REPROIN/ .. 109-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  21%|█████▌                     | 39.0M/188M [08:21<31:50, 77.7k Bytes/s]
# Get REPROIN/ .. 110-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  21%|█████▋                     | 39.2M/188M [08:23<31:46, 77.8k Bytes/s]
# Get REPROIN/ .. 110-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 111-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  21%|█████▋                     | 39.5M/188M [08:27<31:39, 77.9k Bytes/s]
# Get REPROIN/ .. 111-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 112-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  21%|█████▋                     | 39.9M/188M [08:32<31:37, 77.8k Bytes/s]
# Get REPROIN/ .. 113-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  22%|█████▊                     | 40.4M/188M [08:38<31:29, 77.9k Bytes/s]
# Get REPROIN/ .. 114-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 115-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  22%|█████▉                     | 40.9M/188M [08:44<31:18, 78.0k Bytes/s]
# Get REPROIN/ .. 115-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 116-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 116-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 117-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  22%|█████▉                     | 41.6M/188M [08:51<31:05, 78.2k Bytes/s]
# Get REPROIN/ .. 117-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 118-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 118-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 119-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  23%|██████                     | 42.3M/188M [08:59<30:54, 78.3k Bytes/s]
# Get REPROIN/ .. 119-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 120-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 120-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 121-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  23%|██████▏                    | 42.9M/188M [09:06<30:39, 78.6k Bytes/s]
# Get REPROIN/ .. 121-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 122-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 122-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 123-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 123-0001.dcm:  42%|██   | 71.9k/173k [00:00<00:00, 144k Bytes/s]
#
# Get REPROIN/ .. 123-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  23%|██████▎                    | 43.8M/188M [09:16<30:26, 78.7k Bytes/s]
# Get REPROIN/ .. 124-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 124-0001.dcm:  51%|██  | 87.9k/173k [00:03<00:03, 25.1k Bytes/s]
#
# Get REPROIN/ .. 124-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 125-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
#
# Get REPROIN/ .. 126-0001.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  24%|██████▍                    | 44.6M/188M [09:28<30:21, 78.5k Bytes/s]
# Get REPROIN/ .. 126-0002.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  24%|██████▍                    | 44.8M/188M [09:30<30:17, 78.5k Bytes/s]
# Get REPROIN/ .. 127-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  24%|██████▍                    | 45.0M/188M [09:32<30:14, 78.6k Bytes/s]
# Get REPROIN/ .. 127-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 127-0002.dcm:  48%|██▍  | 79.9k/168k [00:00<00:00, 159k Bytes/s]
# Total:  24%|██████▌                    | 45.1M/188M [09:50<31:00, 76.5k Bytes/s]
# Get REPROIN/ .. 128-0001.dcm:   0%|             | 0.00/173k [00:00<?, ? Bytes/s]
# Total:  24%|██████▌                    | 45.3M/188M [09:51<30:54, 76.7k Bytes/s]
# Get REPROIN/ .. 128-0002.dcm:   0%|             | 0.00/168k [00:00<?, ? Bytes/s]
# Total:  24%|██████▌                    | 45.5M/188M [09:52<30:51, 76.7k Bytes/s]
# Get REPROIN/ .. 001-0001.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0001.dcm:  83%|████▉ | 184k/223k [00:00<00:00, 368k Bytes/s]
# Total:  24%|██████▌                    | 45.7M/188M [09:55<30:48, 76.7k Bytes/s]
# Get REPROIN/ .. 001-0002.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  24%|██████▌                    | 45.9M/188M [09:58<30:43, 76.8k Bytes/s]
# Get REPROIN/ .. 001-0003.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  25%|██████▋                    | 46.2M/188M [10:00<30:38, 76.9k Bytes/s]
# Get REPROIN/ .. 001-0004.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  25%|██████▋                    | 46.4M/188M [10:02<30:34, 76.9k Bytes/s]
# Get REPROIN/ .. 001-0005.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  25%|██████▋                    | 46.6M/188M [10:04<30:28, 77.1k Bytes/s]
# Get REPROIN/ .. 001-0006.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  25%|██████▋                    | 46.8M/188M [10:06<30:22, 77.2k Bytes/s]
# Get REPROIN/ .. 001-0007.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  25%|██████▊                    | 47.3M/188M [10:30<31:09, 75.0k Bytes/s]
# Get REPROIN/ .. 001-0009.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  25%|██████▊                    | 47.5M/188M [10:32<31:03, 75.1k Bytes/s]
# Get REPROIN/ .. 001-0010.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0010.dcm:  93%|█████▌| 208k/223k [00:00<00:00, 413k Bytes/s]
# Total:  25%|██████▊                    | 47.7M/188M [10:34<30:58, 75.2k Bytes/s]
# Get REPROIN/ .. 001-0011.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  26%|██████▉                    | 47.9M/188M [10:36<30:52, 75.4k Bytes/s]
# Get REPROIN/ .. 001-0012.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  26%|██████▉                    | 48.2M/188M [10:38<30:46, 75.5k Bytes/s]
# Get REPROIN/ .. 001-0013.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0013.dcm:  79%|████▋ | 176k/223k [00:00<00:00, 351k Bytes/s]
# Total:  26%|███████                    | 48.8M/188M [10:50<30:46, 75.1k Bytes/s]
# Get REPROIN/ .. 001-0016.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  26%|███████                    | 49.3M/188M [10:54<30:36, 75.3k Bytes/s]
# Get REPROIN/ .. 001-0018.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▏                   | 49.7M/188M [10:59<30:26, 75.4k Bytes/s]
# Get REPROIN/ .. 001-0020.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▏                   | 49.9M/188M [11:01<30:22, 75.5k Bytes/s]
# Get REPROIN/ .. 001-0021.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0021.dcm:  68%|████  | 152k/223k [00:00<00:00, 303k Bytes/s]
# Total:  27%|███████▏                   | 50.2M/188M [11:04<30:19, 75.5k Bytes/s]
# Get REPROIN/ .. 001-0022.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▎                   | 50.4M/188M [11:06<30:13, 75.6k Bytes/s]
# Get REPROIN/ .. 001-0023.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▎                   | 50.6M/188M [11:08<30:08, 75.7k Bytes/s]
# Get REPROIN/ .. 001-0024.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0024.dcm:  86%|█████▏| 192k/223k [00:00<00:00, 384k Bytes/s]
# Total:  27%|███████▎                   | 50.8M/188M [11:11<30:05, 75.7k Bytes/s]
# Get REPROIN/ .. 001-0025.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▎                   | 51.1M/188M [11:13<30:00, 75.8k Bytes/s]
# Get REPROIN/ .. 001-0026.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▍                   | 51.3M/188M [11:15<29:55, 75.9k Bytes/s]
# Get REPROIN/ .. 001-0027.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  27%|███████▍                   | 51.5M/188M [11:17<29:49, 76.0k Bytes/s]
# Get REPROIN/ .. 001-0028.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0028.dcm:  86%|█████▏| 192k/223k [00:00<00:00, 383k Bytes/s]
# Total:  28%|███████▍                   | 51.7M/188M [11:20<29:46, 76.0k Bytes/s]
# Get REPROIN/ .. 001-0029.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  28%|███████▍                   | 51.9M/188M [11:22<29:42, 76.1k Bytes/s]
# Get REPROIN/ .. 001-0030.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  28%|███████▌                   | 52.2M/188M [11:24<29:36, 76.2k Bytes/s]
# Get REPROIN/ .. 001-0031.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  28%|███████▌                   | 52.4M/188M [11:26<29:31, 76.3k Bytes/s]
# Get REPROIN/ .. 001-0032.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  28%|███████▌                   | 52.6M/188M [11:28<29:26, 76.4k Bytes/s]
# Get REPROIN/ .. 001-0033.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  28%|███████▌                   | 52.8M/188M [11:30<29:21, 76.5k Bytes/s]
# Get REPROIN/ .. 001-0034.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  28%|███████▋                   | 53.1M/188M [11:32<29:15, 76.6k Bytes/s]
# Get REPROIN/ .. 001-0035.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0035.dcm:  86%|█████▏| 192k/223k [00:00<00:00, 383k Bytes/s]
# Total:  28%|███████▋                   | 53.3M/188M [11:35<29:12, 76.6k Bytes/s]
# Get REPROIN/ .. 001-0036.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  29%|███████▋                   | 53.5M/188M [11:37<29:07, 76.7k Bytes/s]
# Get REPROIN/ .. 001-0037.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  29%|███████▋                   | 53.7M/188M [11:39<29:02, 76.8k Bytes/s]
# Get REPROIN/ .. 001-0038.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  29%|███████▊                   | 54.2M/188M [11:44<28:53, 76.9k Bytes/s]
# Get REPROIN/ .. 001-0040.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  29%|███████▊                   | 54.4M/188M [11:46<28:47, 77.0k Bytes/s]
# Get REPROIN/ .. 001-0041.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  29%|███████▊                   | 54.6M/188M [11:48<28:42, 77.1k Bytes/s]
# Get REPROIN/ .. 001-0042.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  29%|███████▉                   | 55.1M/188M [11:52<28:32, 77.3k Bytes/s]
# Get REPROIN/ .. 001-0044.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0044.dcm:  86%|█████▏| 192k/223k [00:00<00:00, 384k Bytes/s]
# Total:  29%|███████▉                   | 55.3M/188M [11:55<28:30, 77.3k Bytes/s]
# Get REPROIN/ .. 001-0045.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|███████▉                   | 55.5M/188M [11:57<28:26, 77.4k Bytes/s]
# Get REPROIN/ .. 001-0046.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████                   | 55.7M/188M [11:59<28:21, 77.4k Bytes/s]
# Get REPROIN/ .. 001-0047.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████                   | 56.0M/188M [12:01<28:16, 77.5k Bytes/s]
# Get REPROIN/ .. 001-0048.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████                   | 56.2M/188M [12:03<28:11, 77.6k Bytes/s]
# Get REPROIN/ .. 001-0049.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████                   | 56.4M/188M [12:05<28:06, 77.7k Bytes/s]
# Get REPROIN/ .. 001-0050.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████▏                  | 56.6M/188M [12:07<28:02, 77.8k Bytes/s]
# Get REPROIN/ .. 001-0051.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████▏                  | 56.8M/188M [12:09<27:57, 77.9k Bytes/s]
# Get REPROIN/ .. 001-0052.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  30%|████████▏                  | 57.1M/188M [12:11<27:52, 78.0k Bytes/s]
# Get REPROIN/ .. 001-0053.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0053.dcm:  79%|████▋ | 176k/223k [00:00<00:00, 351k Bytes/s]
# Total:  31%|████████▏                  | 57.3M/188M [12:14<27:49, 78.0k Bytes/s]
# Get REPROIN/ .. 001-0054.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 001-0054.dcm:  86%|█████▏| 192k/223k [00:00<00:00, 383k Bytes/s]
# Total:  31%|████████▎                  | 57.5M/188M [12:17<27:46, 78.0k Bytes/s]
# Get REPROIN/ .. 001-0055.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  31%|████████▎                  | 58.0M/188M [12:21<27:37, 78.2k Bytes/s]
# Get REPROIN/ .. 001-0057.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# Total:  31%|████████▍                  | 58.2M/188M [12:23<27:32, 78.3k Bytes/s]
# Get REPROIN/ .. 001-0058.dcm:   0%|             | 0.00/223k [00:00<?, ? Bytes/s]
# ...
# Get REPROIN/ .. 010-0039.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  89%|█████████████████████████▉   | 167M/188M [27:28<03:17, 102k Bytes/s]
# Get REPROIN/ .. 010-0040.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  89%|█████████████████████████▉   | 168M/188M [27:30<03:15, 102k Bytes/s]
# Get REPROIN/ .. 010-0041.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  89%|█████████████████████████▉   | 168M/188M [27:32<03:13, 102k Bytes/s]
# Get REPROIN/ .. 010-0042.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|█████████████████████████▉   | 168M/188M [27:34<03:11, 102k Bytes/s]
# Get REPROIN/ .. 010-0043.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|██████████████████████████   | 168M/188M [27:36<03:10, 102k Bytes/s]
# Get REPROIN/ .. 010-0044.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|██████████████████████████   | 168M/188M [27:38<03:08, 102k Bytes/s]
# Get REPROIN/ .. 010-0045.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|██████████████████████████   | 169M/188M [27:40<03:06, 102k Bytes/s]
# Get REPROIN/ .. 010-0046.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|██████████████████████████   | 169M/188M [27:42<03:04, 102k Bytes/s]
# Get REPROIN/ .. 010-0047.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|██████████████████████████▏  | 169M/188M [27:44<03:02, 102k Bytes/s]
# Get REPROIN/ .. 010-0048.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 010-0048.dcm:  75%|████▍ | 144k/192k [00:00<00:00, 287k Bytes/s]
# Total:  90%|██████████████████████████▏  | 169M/188M [27:49<02:58, 101k Bytes/s]
# Get REPROIN/ .. 010-0050.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  90%|██████████████████████████▏  | 170M/188M [27:51<02:57, 101k Bytes/s]
# Get REPROIN/ .. 010-0051.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▎  | 170M/188M [27:53<02:55, 101k Bytes/s]
# Get REPROIN/ .. 010-0052.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▎  | 170M/188M [27:57<02:51, 101k Bytes/s]
# Get REPROIN/ .. 010-0054.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▎  | 170M/188M [27:59<02:49, 101k Bytes/s]
# Get REPROIN/ .. 010-0055.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▎  | 171M/188M [28:01<02:47, 101k Bytes/s]
# Get REPROIN/ .. 010-0056.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▍  | 171M/188M [28:03<02:45, 101k Bytes/s]
# Get REPROIN/ .. 010-0057.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▍  | 171M/188M [28:06<02:43, 101k Bytes/s]
# Get REPROIN/ .. 010-0058.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▍  | 171M/188M [28:07<02:42, 101k Bytes/s]
# Get REPROIN/ .. 010-0059.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▍  | 171M/188M [28:09<02:40, 101k Bytes/s]
# Get REPROIN/ .. 010-0060.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  91%|██████████████████████████▌  | 171M/188M [28:11<02:38, 101k Bytes/s]
# Get REPROIN/ .. 010-0061.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▌  | 172M/188M [28:15<02:34, 101k Bytes/s]
# Get REPROIN/ .. 010-0063.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▌  | 172M/188M [28:18<02:32, 101k Bytes/s]
# Get REPROIN/ .. 010-0064.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▋  | 172M/188M [28:21<02:30, 101k Bytes/s]
# Get REPROIN/ .. 010-0065.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▋  | 172M/188M [28:23<02:29, 101k Bytes/s]
# Get REPROIN/ .. 010-0066.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▋  | 173M/188M [28:25<02:27, 101k Bytes/s]
# Get REPROIN/ .. 010-0067.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▋  | 173M/188M [28:27<02:25, 101k Bytes/s]
# Get REPROIN/ .. 010-0068.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▊  | 173M/188M [28:30<02:23, 101k Bytes/s]
# Get REPROIN/ .. 010-0069.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▊  | 173M/188M [28:32<02:21, 101k Bytes/s]
# Get REPROIN/ .. 010-0070.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  92%|██████████████████████████▊  | 173M/188M [28:34<02:19, 101k Bytes/s]
# Get REPROIN/ .. 010-0071.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|██████████████████████████▊  | 174M/188M [28:36<02:17, 101k Bytes/s]
# Get REPROIN/ .. 010-0072.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|██████████████████████████▉  | 174M/188M [28:38<02:15, 101k Bytes/s]
# Get REPROIN/ .. 010-0073.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|██████████████████████████▉  | 174M/188M [28:40<02:14, 101k Bytes/s]
# Get REPROIN/ .. 010-0074.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|██████████████████████████▉  | 174M/188M [28:47<02:12, 101k Bytes/s]
# Get REPROIN/ .. 010-0075.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|██████████████████████████▉  | 174M/188M [28:49<02:10, 101k Bytes/s]
# Get REPROIN/ .. 010-0076.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|██████████████████████████▉  | 175M/188M [28:51<02:08, 101k Bytes/s]
# Get REPROIN/ .. 010-0077.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 010-0077.dcm:  92%|█████▍| 176k/192k [00:00<00:00, 352k Bytes/s]
# Total:  93%|███████████████████████████  | 175M/188M [28:54<02:06, 101k Bytes/s]
# Get REPROIN/ .. 010-0078.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|███████████████████████████  | 175M/188M [28:58<02:03, 101k Bytes/s]
# Get REPROIN/ .. 010-0080.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  93%|███████████████████████████  | 175M/188M [29:00<02:01, 101k Bytes/s]
# Get REPROIN/ .. 010-0081.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▏ | 175M/188M [29:01<01:59, 101k Bytes/s]
# Get REPROIN/ .. 010-0082.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▏ | 176M/188M [29:06<01:55, 101k Bytes/s]
# Get REPROIN/ .. 010-0084.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▏ | 176M/188M [29:07<01:53, 101k Bytes/s]
# Get REPROIN/ .. 010-0085.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▎ | 176M/188M [29:09<01:51, 101k Bytes/s]
# Get REPROIN/ .. 010-0086.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▎ | 176M/188M [29:11<01:49, 101k Bytes/s]
# Get REPROIN/ .. 010-0087.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▎ | 177M/188M [29:13<01:47, 101k Bytes/s]
# Get REPROIN/ .. 010-0088.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▎ | 177M/188M [29:15<01:45, 101k Bytes/s]
# Get REPROIN/ .. 010-0089.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  94%|███████████████████████████▍ | 177M/188M [29:17<01:44, 101k Bytes/s]
# Get REPROIN/ .. 010-0090.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▍ | 177M/188M [29:22<01:40, 101k Bytes/s]
# Get REPROIN/ .. 010-0092.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▍ | 178M/188M [29:24<01:38, 101k Bytes/s]
# Get REPROIN/ .. 010-0093.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▍ | 178M/188M [29:25<01:36, 101k Bytes/s]
# Get REPROIN/ .. 010-0094.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▌ | 178M/188M [29:30<01:32, 101k Bytes/s]
# Get REPROIN/ .. 010-0096.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▌ | 179M/188M [29:33<01:28, 101k Bytes/s]
# Get REPROIN/ .. 010-0098.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▋ | 179M/188M [29:41<01:27, 100k Bytes/s]
# Get REPROIN/ .. 010-0099.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  95%|███████████████████████████▋ | 179M/188M [29:42<01:25, 100k Bytes/s]
# Get REPROIN/ .. 010-0100.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▋ | 179M/188M [29:44<01:23, 100k Bytes/s]
# Get REPROIN/ .. 010-0101.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▊ | 180M/188M [29:48<01:19, 100k Bytes/s]
# Get REPROIN/ .. 010-0103.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▊ | 180M/188M [29:50<01:17, 100k Bytes/s]
# Get REPROIN/ .. 010-0104.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▊ | 180M/188M [29:58<01:15, 100k Bytes/s]
# Get REPROIN/ .. 010-0105.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▊ | 180M/188M [30:00<01:14, 100k Bytes/s]
# Get REPROIN/ .. 010-0106.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▉ | 180M/188M [30:02<01:12, 100k Bytes/s]
# Get REPROIN/ .. 010-0107.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▉ | 180M/188M [30:04<01:10, 100k Bytes/s]
# Get REPROIN/ .. 010-0108.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▉ | 181M/188M [30:06<01:08, 100k Bytes/s]
# Get REPROIN/ .. 010-0109.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  96%|███████████████████████████▉ | 181M/188M [30:08<01:06, 100k Bytes/s]
# Get REPROIN/ .. 010-0110.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|████████████████████████████ | 181M/188M [30:10<01:04, 100k Bytes/s]
# Get REPROIN/ .. 010-0111.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|████████████████████████████ | 181M/188M [30:12<01:02, 100k Bytes/s]
# Get REPROIN/ .. 010-0112.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|████████████████████████████ | 181M/188M [30:14<01:00, 100k Bytes/s]
# Get REPROIN/ .. 010-0113.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|████████████████████████████ | 182M/188M [30:16<00:58, 100k Bytes/s]
# Get REPROIN/ .. 010-0114.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|████████████████████████████ | 182M/188M [30:18<00:56, 100k Bytes/s]
# Get REPROIN/ .. 010-0115.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|████████████████████████████▏| 182M/188M [30:20<00:54, 100k Bytes/s]
# Get REPROIN/ .. 010-0116.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|███████████████████████████▏| 182M/188M [30:23<00:52, 99.9k Bytes/s]
# Get REPROIN/ .. 010-0117.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|███████████████████████████▏| 182M/188M [30:25<00:51, 99.9k Bytes/s]
# Get REPROIN/ .. 010-0118.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|███████████████████████████▎| 183M/188M [30:27<00:49, 99.9k Bytes/s]
# Get REPROIN/ .. 010-0119.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  97%|███████████████████████████▎| 183M/188M [30:30<00:47, 99.9k Bytes/s]
# Get REPROIN/ .. 010-0120.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▎| 183M/188M [30:32<00:45, 99.8k Bytes/s]
# Get REPROIN/ .. 010-0121.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▎| 183M/188M [30:38<00:43, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0122.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▍| 183M/188M [30:39<00:41, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0123.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▍| 184M/188M [30:41<00:39, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0124.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▍| 184M/188M [30:43<00:37, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0125.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▍| 184M/188M [30:45<00:35, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0126.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▍| 184M/188M [30:47<00:33, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0127.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▌| 184M/188M [30:49<00:31, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0128.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  98%|███████████████████████████▌| 185M/188M [30:51<00:29, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0129.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  99%|███████████████████████████▌| 185M/188M [30:53<00:28, 99.6k Bytes/s]
# Get REPROIN/ .. 010-0130.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  99%|███████████████████████████▌| 185M/188M [30:55<00:26, 99.6k Bytes/s]
# Get REPROIN/ .. 010-0131.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  99%|███████████████████████████▋| 185M/188M [30:57<00:24, 99.7k Bytes/s]
# Get REPROIN/ .. 010-0132.dcm:   0%|             | 0.00/192k [00:00<?, ? Bytes/s]
# Total:  99%|███████████████████████████▋| 185M/188M [30:59<00:22, 99.7k Bytes/s]
# Get REPROIN/ .. 011-0001.dcm:   0%|             | 0.00/555k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 011-0001.dcm:  75%|████▍ | 416k/555k [00:00<00:00, 831k Bytes/s]
# Total:  99%|███████████████████████████▊| 186M/188M [31:01<00:16, 99.8k Bytes/s]
# Get REPROIN/ .. 011-0002.dcm:   0%|             | 0.00/555k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 011-0002.dcm:  75%|████▍ | 416k/555k [00:00<00:00, 832k Bytes/s]
# Total:  99%|████████████████████████████▊| 186M/188M [31:03<00:11, 100k Bytes/s]
# Get REPROIN/ .. 011-0003.dcm:   0%|             | 0.00/555k [00:00<?, ? Bytes/s]
# Get REPROIN/ .. 011-0003.dcm:  32%|█▉    | 176k/555k [00:00<00:01, 351k Bytes/s]
# Total: 100%|████████████████████████████▉| 187M/188M [31:07<00:05, 100k Bytes/s]
# Get REPROIN/ .. 011-0004.dcm:   0%|             | 0.00/555k [00:00<?, ? Bytes/s]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0005.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0005.dcm (file) [from origin...]
#   [781 similar messages have been suppressed; disable with datalad.ui.suppress-similar-results=off]
# get(ok): REPROIN/dicom/001 (directory)
# action summary:
#   get (ok: 792)

# %% [markdown]
# We will be working from a directory called `REPROIN`. Under the REPROIN directory is the `dicom` subdirectory: Under the subject number `001` the session `Patterson_Coben - 1` is nested. Each dicom sequence folder is nested under the session:

# %%
# !tree heudiconv-reproin-example/REPROIN/dicom

# %% [markdown]
# ## 2. Convert DICOMS to BIDS-formatted NIFTI
#
# ### 2.1. Using dcm2niix (manual workflow)
#
# `dcm2niix` converts neuroimaging data from the DICOM format to the NIfTI format and generates a BIDS JSON format sidecar which includes relevant information. However, users need to manually organize these files into a bids-compliant subject directory.

# %%
import lmod
await lmod.load('dcm2niix/v1.0.20240202')

# %%
# !dcm2niix -h
# Out:
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC12.2.0 x86-64 (64-bit Linux)
# usage: dcm2niix [options] <in_folder>
#  Options :
#   -1..-9 : gz compression level (1=fastest..9=smallest, default 6)
#   -a : adjacent DICOMs (images from same series always in same folder) for faster conversion (n/y, default n)
#   -b : BIDS sidecar (y/n/o [o=only: no NIfTI], default y)
#    -ba : anonymize BIDS (y/n, default y)
#   -c : comment stored in NIfTI aux_file (up to 24 characters e.g. '-c VIP', empty to anonymize e.g. 0020,4000 e.g. '-c ""')
#   -d : directory search depth. Convert DICOMs in sub-folders of in_folder? (0..9, default 5)
#   -e : export as NRRD (y) or MGH (o) or JSON/JNIfTI (j) or BJNIfTI (b) instead of NIfTI (y/n/o/j/b, default n)
#   -f : filename (%a=antenna (coil) name, %b=basename, %c=comments, %d=description, %e=echo number, %f=folder name, %g=accession number, %i=ID of patient, %j=seriesInstanceUID, %k=studyInstanceUID, %m=manufacturer, %n=name of patient, %o=mediaObjectInstanceUID, %p=protocol, %r=instance number, %s=series number, %t=time, %u=acquisition number, %v=vendor, %x=study ID; %z=sequence name; default '%f_%p_%t_%s')
#   -g : generate defaults file (y/n/o/i [o=only: reset and write defaults; i=ignore: reset defaults], default n)
#   -h : show help
#   -i : ignore derived, localizer and 2D images (y/n, default n)
#   -l : losslessly scale 16-bit integers to use dynamic range (y/n/o [yes=scale, no=no, but uint16->int16, o=original], default o)
#   -m : merge 2D slices from same series regardless of echo, exposure, etc. (n/y or 0/1/2, default 2) [no, yes, auto]
#   -n : only convert this series CRC number - can be used up to 16 times (default convert all)
#   -o : output directory (omit to save to input folder)
#   -p : Philips precise float (not display) scaling (y/n, default y)
#   -q : only search directory for DICOMs (y/l/n, default y) [y=show number of DICOMs found, l=additionally list DICOMs found, n=no]
#   -r : rename instead of convert DICOMs (y/n, default n)
#   -s : single file mode, do not convert other images in folder (y/n, default n)
#   -u : up-to-date check
#   -v : verbose (n/y or 0/1/2, default 0) [no, yes, logorrheic]
#   -w : write behavior for name conflicts (0,1,2, default 2: 0=skip duplicates, 1=overwrite, 2=add suffix)
#   -x : crop 3D acquisitions (y/n/i, default n, use 'i'gnore to neither crop nor rotate 3D acquistions)
#   -z : gz compress images (y/o/i/n/3, default n) [y=pigz, o=optimal pigz, i=internal:miniz, n=no, 3=no,3D]
#   --big-endian : byte order (y/n/o, default o) [y=big-end, n=little-end, o=optimal/native]
#   --progress : Slicer format progress information (y/n, default n)
#   --ignore_trigger_times : disregard values in 0018,1060 and 0020,9153
#   --terse : omit filename post-fixes (can cause overwrites)
#   --version : report version
#   --xml : Slicer format features
#  Defaults file : /home/jovyan/.dcm2nii.ini
#  Examples :
#   dcm2niix /Users/chris/dir
#   dcm2niix -c "my comment" /Users/chris/dir
#   dcm2niix -o /users/cr/outdir/ -z y ~/dicomdir
#   dcm2niix -f %p_%s -b y -ba n ~/dicomdir
#   dcm2niix -f mystudy%s ~/dicomdir
#   dcm2niix -o "~/dir with spaces/dir" ~/dicomdir
# Example output filename: 'myFolder_MPRAGE_19770703150928_1.nii'

# %%
# !mkdir dcm2niix_bids
# !dcm2niix n -o ./dcm2niix_bids ./heudiconv-reproin-example/REPROIN/dicom
# Out:
# Chris Rorden's dcm2niiX version v1.0.20230411  GCC12.2.0 x86-64 (64-bit Linux)
# Found 791 DICOM file(s)
# Slices not stacked: orientation varies (vNav or localizer?) [0.0964069 0.780133 0.618141 0.0553476 0.615871 -0.7859] != [0.718684 0.55589 0.417708 0.0695744 0.540223 -0.838641]
# Convert 2 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00001 (162x162x2x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00002 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00003 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00004 (162x162x1x1)
# Convert 128 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_1 (160x160x128x1)
# Convert 128 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_2 (160x160x128x1)
# Convert 4 DICOM as ./dcm2niix_bids/dicom_func_task-rest_20190208142838_16 (64x64x44x4)
# Convert 132 DICOM as ./dcm2niix_bids/dicom_fmap_dir-PA_20190208142838_15 (122x122x66x2)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_4_i00001 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_4_i00002 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_4_i00003 (162x162x1x1)
# Convert 16 DICOM as ./dcm2niix_bids/dicom_dwi_dir-AP_20190208142838_9 (122x122x66x16)
# Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# Convert 44 DICOM as ./dcm2niix_bids/dicom_fmap_acq-4mm_20190208142838_7_e1 (64x64x44x1)
# Convert 44 DICOM as ./dcm2niix_bids/dicom_fmap_acq-4mm_20190208142838_7_e2 (64x64x44x1)
# Convert 240 DICOM as ./dcm2niix_bids/dicom_anat-T1w_acq-MPRAGE_20190208142838_6 (224x224x240x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_5_i00001 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_5_i00002 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_5_i00003 (162x162x1x1)
# Convert 44 DICOM as ./dcm2niix_bids/dicom_fmap_acq-4mm_20190208142838_8_e2_ph (64x64x44x1)
# Conversion required 24.665354 seconds (1.680269 for core code).

# %% [markdown]
# ### 2.2. Using HeuDiConv (automated workflow)
# Typical use of heudiconv will require the creation and editing of your heuristics file.
#
# But heudiconv also comes with existing heuristics which can be used as is, like `convertall` or `ReproIn` could be immediately reused and represent two ends of the spectrum in heuristics:
# - `convertall` is very simple and does not automate anything – it is for a user to modify filenames in the prepared conversion table, and then rerun with `-c dcm2niix`
# - `reproin` can be used fully automated, if original sequences were named according to its ReproIn convention.

# %%
await lmod.load('heudiconv/1.3.1')

# %%
# !heudiconv -f reproin -s 001 -c dcm2niix -b -o ./heudiconv_bids --files ./heudiconv-reproin-example/REPROIN/dicom
# Out:
# INFO: Running heudiconv version 1.3.1 latest 1.3.2
# INFO: Analyzing 791 dicoms
# INFO: Filtering out 0 dicoms based on their filename
# INFO: Generated sequence info for 1 studies with 11 entries total
# INFO: Processing sequence infos to deduce study/session
# INFO: Study session for StudySessionInfo(locator='Patterson/Coben', session=None, subject='001')
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': '001', 'outdir': '/data/books/workflows/heudiconv_bids/Patterson/Coben', 'session': None}
# INFO: Processing 11 pre-sorted seqinfo entries
# INFO: Processing 11 seqinfo entries
# WARNING: Deduced datatype to be dwi from DICOM, but got fmap out of fmap_dir-PA
# WARNING: Detected 4 duplicated run(s) for template {bids_subject_session_dir}/anat/{bids_subject_session_prefix}_scout: ['1-anat-scout', '2-anat-scout', '3-anat-scout', '4-anat-scout']
# INFO: Doing conversion using dcm2niix
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_scout (3 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w (240 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 241122-04:02:02,995 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix0h2z11q3/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix0h2z11q3/convert".
# 241122-04:02:17,979 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 241122-04:02:25,297 nipype.interface INFO:
# 	 stdout 2024-11-22T04:02:25.297866:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2024-11-22T04:02:25.297866:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 241122-04:02:25,298 nipype.interface INFO:
# 	 stdout 2024-11-22T04:02:25.297866:Found 240 DICOM file(s)
# INFO: stdout 2024-11-22T04:02:25.297866:Found 240 DICOM file(s)
# 241122-04:02:25,298 nipype.interface INFO:
# 	 stdout 2024-11-22T04:02:25.297866:Convert 240 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv958 (224x224x240x1)
# INFO: stdout 2024-11-22T04:02:25.297866:Convert 240 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv958 (224x224x240x1)
# 241122-04:02:26,143 nipype.interface INFO:
# 	 stdout 2024-11-22T04:02:26.143329:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv958.nii"
# INFO: stdout 2024-11-22T04:02:26.143329:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv958.nii"
# 241122-04:02:26,143 nipype.interface INFO:
# 	 stdout 2024-11-22T04:02:26.143329:Conversion required 7.049799 seconds (0.446253 for core code).
# INFO: stdout 2024-11-22T04:02:26.143329:Conversion required 7.049799 seconds (0.446253 for core code).
# 241122-04:02:26,185 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 7.114825s.
# INFO: [Node] Finished "convert", elapsed time 7.114825s.
# 241122-04:02:53,989 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetalugd09f6/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetalugd09f6/embedder".
# 241122-04:02:59,522 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 241122-04:03:07,513 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 7.990338s.
# INFO: [Node] Finished "embedder", elapsed time 7.990338s.
# INFO: Post-treating /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w.json file
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude (88 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 241122-04:03:08,260 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixxwwl49xs/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixxwwl49xs/convert".
# 241122-04:03:14,774 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 241122-04:03:17,717 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:17.717306:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2024-11-22T04:03:17.717306:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 241122-04:03:17,717 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:17.717306:Found 88 DICOM file(s)
# INFO: stdout 2024-11-22T04:03:17.717306:Found 88 DICOM file(s)
# 241122-04:03:17,717 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:17.717306:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# INFO: stdout 2024-11-22T04:03:17.717306:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 241122-04:03:17,717 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:17.717306:Convert 44 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e1 (64x64x44x1)
# INFO: stdout 2024-11-22T04:03:17.717306:Convert 44 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e1 (64x64x44x1)
# 241122-04:03:17,971 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:17.971516:Compress: "/usr/bin/pigz" -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e1.nii"
# INFO: stdout 2024-11-22T04:03:17.971516:Compress: "/usr/bin/pigz" -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e1.nii"
# 241122-04:03:17,971 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:17.971516:Convert 44 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e2 (64x64x44x1)
# INFO: stdout 2024-11-22T04:03:17.971516:Convert 44 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e2 (64x64x44x1)
# 241122-04:03:18,33 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:18.033281:Compress: "/usr/bin/pigz" -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e2.nii"
# INFO: stdout 2024-11-22T04:03:18.033281:Compress: "/usr/bin/pigz" -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv264_e2.nii"
# 241122-04:03:18,33 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:18.033281:Conversion required 3.220071 seconds (0.216709 for core code).
# INFO: stdout 2024-11-22T04:03:18.033281:Conversion required 3.220071 seconds (0.216709 for core code).
# 241122-04:03:18,115 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 3.34015s.
# INFO: [Node] Finished "convert", elapsed time 3.34015s.
# WARNING: For now not embedding BIDS and info generated .nii.gz itself since sequence produced multiple files
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff (44 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 241122-04:03:21,816 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixw3iwovuf/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixw3iwovuf/convert".
# 241122-04:03:24,348 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 241122-04:03:25,407 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:25.406935:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2024-11-22T04:03:25.406935:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 241122-04:03:25,407 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:25.406935:Found 44 DICOM file(s)
# INFO: stdout 2024-11-22T04:03:25.406935:Found 44 DICOM file(s)
# 241122-04:03:25,407 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:25.406935:Convert 44 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv655_e2_ph (64x64x44x1)
# INFO: stdout 2024-11-22T04:03:25.406935:Convert 44 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv655_e2_ph (64x64x44x1)
# 241122-04:03:25,456 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:25.456289:Compress: "/usr/bin/pigz" -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv655_e2_ph.nii"
# INFO: stdout 2024-11-22T04:03:25.456289:Compress: "/usr/bin/pigz" -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv655_e2_ph.nii"
# 241122-04:03:25,456 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:25.456289:Conversion required 1.073804 seconds (0.066612 for core code).
# INFO: stdout 2024-11-22T04:03:25.456289:Conversion required 1.073804 seconds (0.066612 for core code).
# 241122-04:03:25,516 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 1.167272s.
# INFO: [Node] Finished "convert", elapsed time 1.167272s.
# 241122-04:03:27,294 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta4gp_z55p/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta4gp_z55p/embedder".
# 241122-04:03:28,219 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 241122-04:03:29,770 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 1.550624s.
# INFO: [Node] Finished "embedder", elapsed time 1.550624s.
# INFO: Post-treating /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff.json file
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi (16 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 241122-04:03:29,959 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixdvcqjyya/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixdvcqjyya/convert".
# 241122-04:03:30,994 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 241122-04:03:31,820 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:31.820230:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2024-11-22T04:03:31.820230:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 241122-04:03:31,820 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:31.820230:Found 16 DICOM file(s)
# INFO: stdout 2024-11-22T04:03:31.820230:Found 16 DICOM file(s)
# 241122-04:03:31,820 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:31.820230:Convert 16 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv646 (122x122x66x16)
# INFO: stdout 2024-11-22T04:03:31.820230:Convert 16 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv646 (122x122x66x16)
# 241122-04:03:32,628 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:32.628946:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv646.nii"
# INFO: stdout 2024-11-22T04:03:32.628946:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv646.nii"
# 241122-04:03:32,629 nipype.interface INFO:
# 	 stdout 2024-11-22T04:03:32.628946:Conversion required 1.612301 seconds (0.062838 for core code).
# INFO: stdout 2024-11-22T04:03:32.628946:Conversion required 1.612301 seconds (0.062838 for core code).
# 241122-04:03:32,676 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 1.68175s.
# INFO: [Node] Finished "convert", elapsed time 1.68175s.
# 241122-04:03:50,731 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta1fykhgkp/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta1fykhgkp/embedder".
# 241122-04:03:51,94 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 241122-04:03:52,93 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 0.998392s.
# INFO: [Node] Finished "embedder", elapsed time 0.998392s.
# INFO: Post-treating /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi.json file
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi (132 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 241122-04:03:53,21 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix9jkw7pix/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix9jkw7pix/convert".
# 241122-04:04:02,442 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 241122-04:04:06,163 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:06.163715:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2024-11-22T04:04:06.163715:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 241122-04:04:06,164 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:06.163715:Found 132 DICOM file(s)
# INFO: stdout 2024-11-22T04:04:06.163715:Found 132 DICOM file(s)
# 241122-04:04:06,164 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:06.163715:Convert 132 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv855 (122x122x66x2)
# INFO: stdout 2024-11-22T04:04:06.163715:Convert 132 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv855 (122x122x66x2)
# 241122-04:04:06,333 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:06.333453:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv855.nii"
# INFO: stdout 2024-11-22T04:04:06.333453:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv855.nii"
# 241122-04:04:06,333 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:06.333453:Conversion required 3.864426 seconds (0.250404 for core code).
# INFO: stdout 2024-11-22T04:04:06.333453:Conversion required 3.864426 seconds (0.250404 for core code).
# 241122-04:04:06,378 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 3.935271s.
# INFO: [Node] Finished "convert", elapsed time 3.935271s.
# 241122-04:04:12,785 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaxej_p1uv/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaxej_p1uv/embedder".
# 241122-04:04:15,260 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 241122-04:04:20,5 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 4.744428s.
# INFO: [Node] Finished "embedder", elapsed time 4.744428s.
# INFO: Post-treating /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi.json file
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold (4 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 241122-04:04:20,109 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixasddlg7r/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixasddlg7r/convert".
# 241122-04:04:20,375 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 241122-04:04:20,594 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:20.594628:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2024-11-22T04:04:20.594628:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 241122-04:04:20,594 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:20.594628:Found 4 DICOM file(s)
# INFO: stdout 2024-11-22T04:04:20.594628:Found 4 DICOM file(s)
# 241122-04:04:20,594 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:20.594628:Convert 4 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv463 (64x64x44x4)
# INFO: stdout 2024-11-22T04:04:20.594628:Convert 4 DICOM as /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv463 (64x64x44x4)
# 241122-04:04:20,709 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:20.709918:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv463.nii"
# INFO: stdout 2024-11-22T04:04:20.709918:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv463.nii"
# 241122-04:04:20,710 nipype.interface INFO:
# 	 stdout 2024-11-22T04:04:20.709918:Conversion required 0.305368 seconds (0.014303 for core code).
# INFO: stdout 2024-11-22T04:04:20.709918:Conversion required 0.305368 seconds (0.014303 for core code).
# 241122-04:04:20,756 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.380392s.
# INFO: [Node] Finished "convert", elapsed time 0.380392s.
# 241122-04:04:21,252 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta0a9r5h8l/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta0a9r5h8l/embedder".
# 241122-04:04:21,373 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 241122-04:04:21,576 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 0.202799s.
# INFO: [Node] Finished "embedder", elapsed time 0.202799s.
# INFO: Post-treating /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold.json file
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-01 (128 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-02 (128 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-03 (5 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-04 (3 DICOMs) -> /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Adding "IntendedFor" to the fieldmaps in /data/books/workflows/heudiconv_bids/Patterson/Coben/sub-001.
# INFO: Populating template files under /data/books/workflows/heudiconv_bids/Patterson/Coben
# INFO: PROCESSING DONE: {'subject': '001', 'outdir': '/data/books/workflows/heudiconv_bids/Patterson/Coben', 'session': None}

# %% [markdown]
# ### 1.3. Using bidscoin (automated workflow)
#
# BIDScoin requires the source data repository to be organized according to a `subject/[session]/data` structure where `data` folder can be structured in DICOM series layout, DICOMDIR layout, flat DICOM layout. Refer to [this doc](https://bidscoin.readthedocs.io/en/stable/preparation.html) for more details.
#
# To perform BIDS conversion, running:
#
# - (1a) `bidsmapper` command
# - once `bidsmapper` finishes, it automatically launches (1b) the bidseditor
# - (2) `bidscoiner` command
#
# ![image.png](https://bidscoin.readthedocs.io/en/stable/_images/bidsmap_flow.png)

# %%
await lmod.load('bidscoin/4.3.3')

# %%
# %%bash
# mkdir bidscoin_bidsmap
# bidsmapper ./heudiconv-reproin-example/REPROIN/dicom ./bidscoin_bidsmap --subprefix '00' --sesprefix 'Patterson_Coben'   # Scans your data and creates a study bidsmap
# bidscoiner ./heudiconv-reproin-example/REPROIN/dicom ./bidscoin_bids    # Converts your data to BIDS using the study bidsmap
# Out:
# INFO |
# INFO | -------------- START BIDSmapper ------------
# INFO | >>> bidsmapper sourcefolder=/data/books/workflows/heudiconv-reproin-example/REPROIN/dicom bidsfolder=/data/books/workflows/bidscoin_bidsmap bidsmap=bidsmap.yaml template=/home/jovyan/.bidscoin/4.3.3+qt5/templates/bidsmap_dccn.yaml plugins=[] subprefix=00 sesprefix=Patterson_Coben store=False force=False
# INFO | No existing bidsmap file found: /data/books/workflows/bidscoin_bidsmap/code/bidscoin/bidsmap.yaml
# INFO | Reading: /home/jovyan/.bidscoin/4.3.3+qt5/templates/bidsmap_dccn.yaml
# INFO | Checking the bidsmap run-items:
# SUCCESS | All datatypes and options in the template bidsmap are valid
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1 (subject 1/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001-anat-scout_ND (subject 2/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001-anat-scout_ND
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/002-anat-scout (subject 3/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/002-anat-scout
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/003-anat-scout_MPR_sag (subject 4/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/003-anat-scout_MPR_sag
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/004-anat-scout_MPR_cor (subject 5/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/004-anat-scout_MPR_cor
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/005-anat-scout_MPR_tra (subject 6/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/005-anat-scout_MPR_tra
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/006-anat-T1w_acq-MPRAGE (subject 7/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/006-anat-T1w_acq-MPRAGE
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/007-fmap_acq-4mm (subject 8/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/007-fmap_acq-4mm
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/008-fmap_acq-4mm (subject 9/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/008-fmap_acq-4mm
# INFO | Mapping: /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/009-dwi_dir-AP (subject 10/10)
# VERBOSE | Executing plugin: dcm2niix2bids -> /data/books/workflows/heudiconv-reproin-example/REPROIN/dicom/009-dwi_dir-AP
# INFO | Opening the bidseditor                      ubject/s]
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.
#
# /cvmfs/neurodesk.ardc.edu.au/containers/bidscoin_4.3.3_20240716/bidsmapper: line 3:  8094 Aborted                 (core dumped) singularity --silent exec --cleanenv --env DISPLAY=$DISPLAY $neurodesk_singularity_opts --pwd "$PWD" /cvmfs/neurodesk.ardc.edu.au/containers/bidscoin_4.3.3_20240716/bidscoin_4.3.3_20240716.simg bidsmapper "$@"
# INFO |
# INFO | -------------- START BIDScoiner 4.3.3+qt5: BIDS 1.9.0 ------------
# INFO | >>> bidscoiner sourcefolder=/data/books/workflows/bidscoin_bidsmap bidsfolder=/data/books/workflows/bidscoin_bids participant=None force=False bidsmap=bidsmap.yaml
# INFO | Creating dataset description file: /data/books/workflows/bidscoin_bids/dataset_description.json
# INFO | Creating a template README file (adjust it to your needs): /data/books/workflows/bidscoin_bids/README
# INFO | No existing bidsmap file found: /data/books/workflows/bidscoin_bids/code/bidscoin/bidsmap.yaml
# ERROR | No bidsmap file found in /data/books/workflows/bidscoin_bids. Please run the bidsmapper first and/or use the correct bidsfolder

# %% [markdown]
# ## Process data
#
# ### Brain extraction using FSL BET

# %%
await lmod.load('fsl/6.0.7.4')
await lmod.list()
# Out:
# ['dcm2niix/v1.0.20240202', 'fsl/6.0.7.4']

# %%
# %%bash
# mkdir -p segmentation
# declare -a niifile=($(find ./heudiconv_bids/Patterson/Coben/sub-001/anat/ -type f -iname "*.nii.gz"));
#
# for filepath in "${niifile[@]}"; do
#     # Extract the base filename without the path
#     filename=$(basename "$filepath")
#
#     # Extract the name without the extension
#     name="${filename%.*}"
#
#     # Output the current file
#     echo "Processing file: $filepath"
#
#     # Run BET and save the result
#     output="./segmentation/${name%.*}_brain"
#     echo "Saving output to: $output"
#     bet "$filepath" "$output"
# done
# Out:
# Processing file: ./heudiconv_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w.nii.gz
# Saving output to: ./segmentation/sub-001_acq-MPRAGE_T1w_brain

# %% [markdown]
# ### Visualize the brain segmentation

# %%
from ipyniivue import AnyNiivue
nv = AnyNiivue()
nv.load_volumes([{"path": "/data/books/workflows/bidscoin_bids/sub-1/ses-1/anat/sub-1_ses-1_acq-anatT1wacqMPRAGE_T1w.nii.gz"}])
nv
# Out:
# AnyNiivue()

# %% [markdown]
# ## Share your data to OSF
#
# To set the username, project ID and token by using a configuration file, create `.osfcli.config` in the current directory:
# ```markdown
# [osf]
# username = yourOSFaccount@example.com
# project = 9zpcy
# token = kej2R9IU6Gr2uThsswSNdP1cd0cu9eaCerVXjVf7zNwfXHyT0QzMZtX0PGTYmp9Fzaixwq
# ```
#
# To upload file to the project set in configuration file, run `osf upload source destination`.

# %%
# !osf upload -r ./segmentation segmentation
