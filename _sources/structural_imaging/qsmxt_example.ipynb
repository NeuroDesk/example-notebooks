# %% [markdown]
# <a href="https://play-ashburn.neurodesk.org/v2/gh/neurodesk/example-notebooks/main?labpath=/home/jovyan/examples/example-notebooks/books/structural_imaging/qsmxt_example.ipynb" target="_parent"><img src="https://img.shields.io/badge/launch-binder-579aca.svg?logo=data:image/png;base64,..." alt="Open In Binder"/>  </a>
# <a href="https://colab.research.google.com/github/NeuroDesk/example-notebooks/blob/main/books/structural_imaging/qsmxt_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>   </a>

# %% [markdown]
# ## QSMxT Example
#
# Author: Ashley Stewart
#
# Original paper: https://onlinelibrary.wiley.com/doi/10.1002/mrm.29048

# %% [markdown]
# ## Setup Neurodesk

# %%
# %%capture
import os
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  os.environ["LD_PRELOAD"] = "";
  os.environ["APPTAINER_BINDPATH"] = "/content,/tmp,/cvmfs"
  os.environ["MPLCONFIGDIR"] = "/content/matplotlib-mpldir"
  os.environ["LMOD_CMD"] = "/usr/share/lmod/lmod/libexec/lmod"

  # !curl -J -O https://raw.githubusercontent.com/NeuroDesk/neurocommand/main/googlecolab_setup.sh
  # !chmod +x googlecolab_setup.sh
  # !./googlecolab_setup.sh

  os.environ["MODULEPATH"] = ':'.join(map(str, list(map(lambda x: os.path.join(os.path.abspath('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/'), x),os.listdir('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/')))))

# %%
# Output CPU information:
# !cat /proc/cpuinfo | grep 'vendor' | uniq
# !cat /proc/cpuinfo | grep 'model name' | uniq
# Out:
# vendor_id	: AuthenticAMD
# model name	: AMD EPYC 7742 64-Core Processor

# %% [markdown]
# # QSMxT Interactive Notebook
#
# This interactive notebook estimates Quantitative Susceptibility Maps (QSMs) for two gradient-echo (GRE) MRI acquisitions using [QSMxT](https://github.com/QSMxT/QSMxT) provided by the [Neurodesk](https://neurodesk.org) project.

# %% [markdown]
# ## What is QSM?
#
# QSM is a form of quantitative MRI (qMRI) that estimates the magnetic susceptibility distribution across an imaged object. Magnetic susceptibility is the degree to which a material becomes magnetised by an external magnetic field. Major contributors to susceptibility include iron, calcium, and myelin, with the susceptibility of water typically approximating a zero-reference, though it is slightly diamagnetic. Read more about QSM [here](https://onlinelibrary.wiley.com/doi/10.1002/mrm.25358).

# %% [markdown]
# ## What is QSMxT?
#
# [QSMxT](https://github.com/QSMxT/QSMxT) is a suite of tools for building and running automated pipelines for QSM that:
#
# - is available open-source without any licensing required;
# - is distributed as a software container making it straightforward to access and install (Neurodesk!)
# - scales its processing to execute across many acquisitions through jobs parallelisation (using multiple processors or HPCs) provided by [Nipype](https://nipype.readthedocs.io);
# - automates steps that usually require manual intervention and scripting, including:
#   - DICOM to [BIDS](https://bids-specification.readthedocs.io/en/stable/index.html) conversion;
#   - QSM reconstruction using a range of algorithms;
#   - segmentation using [FastSurfer](https://github.com/Deep-MI/FastSurfer);
#   - group space generation using [ANTs](https://github.com/ANTsX/ANTs);
#   - export of susceptibility statistics by subject and region of interest (ROI) to CSV.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How do I access QSMxT?
#
# There are a few ways you can access QSMxT:
#
#  - **This notebook**: You can access QSMxT in this notebook right now!
#    - If you are running this on a Neurodesk Play instance, you can upload your own data into the sidebar via drag-and-drop.
#  - **Neurodesktop**: QSMxT is in the applications menu of Neurodesktop.
#    - On Neurodesk Play, upload your own data into the desktop via drag-and-drop.
#    - On a local install of Neurodesk, bring any necessary files into the shared `~/neurodesktop-storage` directory
#  - **Local install**: QSMxT can also be installed via the [Docker container](https://github.com/QSMxT/QSMxT#installation)
#  - **HPC install**: QSMxT can also be installed via the [Singularity container](https://github.com/QSMxT/QSMxT#installation) for use on HPCs

# %% [markdown]
# # Download example DICOMs
#
# Here, we download some example DICOMs from our OSF repository for QSMxT.
#
# These data include GRE and T1-weighted acquisitions for one subject (duplicated to act as two subjects).

# %%
# !pip install osfclient
# !osf -p ru43c clone . > /dev/null 2>&1
# !tar xf osfstorage/dicoms-unsorted.tar
# !rm -rf osfstorage/
# !tree dicoms-unsorted | head
# !echo -e "...\nThere are `ls dicoms-unsorted | wc -l` unsorted DICOMs in ./dicoms-unsorted/"
# Out:
# Requirement already satisfied: osfclient in /opt/conda/lib/python3.10/site-packages (0.0.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from osfclient) (4.64.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from osfclient) (2.28.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from osfclient) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->osfclient) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->osfclient) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->osfclient) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->osfclient) (2.1.1)
# dicoms-unsorted
# ├── MR.1.1.dcm
# ├── MR.1.10.dcm
# ├── MR.1.100.dcm
# ├── MR.1.101.dcm
# ├── MR.1.102.dcm
# ├── MR.1.103.dcm
# ├── MR.1.104.dcm
# ├── MR.1.105.dcm
# ├── MR.1.106.dcm
# ...
# There are 1216 unsorted DICOMs in ./dicoms-unsorted/

# %% [markdown]
# # Load QSMxT
#
# To load QSMxT inside a notebook, we can use the available module system:

# %%
import lmod
await lmod.load('qsmxt/1.3.5')
# !qsmxt_version.py
# Out:
# v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000) (container version qsmxt_1.3.5_20230227.simg (singularity))

# %% [markdown]
# # Data standardisation
#
# QSMxT requires input data to conform to the [Brain Imaging Data Structure (BIDS)](https://bids.neuroimaging.io/).
#
# Luckily, QSMxT also provides scripts that can convert unorganised NIfTI or DICOM images to BIDS.

# %% [markdown]
# ## Sort DICOMs
#
# Before we can convert DICOMs to BIDS cleanly, we need to sort the DICOMs by subject, session and series.
#
# We can sort the DICOMs using `run_0_dicomSort.py`.
#
# Note that this script relies on accurate DICOM header information. If your data is sorted incorrectly, you may need to manually correct the sorting, or sort the files yourself. Be sure to follow the folder structure shown below.

# %%
# !run_0_dicomSort.py dicoms-unsorted dicoms-sorted
# Out:
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Command: /opt/QSMxT/run_0_dicomSort.py dicoms-unsorted dicoms-sorted
# INFO: Python interpreter: /opt/miniconda-4.7.12.1/bin/python3
# INFO: Reading file list...
# WARNING: No .IMA or .dcm files found! Checking all files for valid DICOM headers...
# INFO: 1216 DICOM files found.
# INFO: Sorting DICOMs in /home/jovyan/example-notebooks/structural_imaging/dicoms-sorted...
# INFO: Identified subject: 1
# INFO: Identified session: 1 #1 20170705
# INFO: Identified series: sub-1/ses-1/6_qsm_p2_1mmiso_te20
# INFO: Identified series: sub-1/ses-1/6_mp2rage_highres_0p5iso_slab
# INFO: Identified session: 2 #1 20170705
# INFO: Identified series: sub-2/ses-1/6_qsm_p2_1mmiso_te20
# INFO: Identified series: sub-2/ses-1/6_mp2rage_highres_0p5iso_slab
# INFO: Identified series: sub-1/ses-1/5_qsm_p2_1mmiso_te20
# INFO: Identified series: sub-2/ses-1/5_qsm_p2_1mmiso_te20
# INFO: Warnings occurred!
# INFO: Finished

# %% [markdown]
# Now we can see clearly that there are two subjects, each with one session, each with three DICOM series:

# %%
# !tree dicoms-sorted -L 3
# Out:
# dicoms-sorted
# ├── log_2023-06-22_02-39-43784921.txt
# ├── references.txt
# ├── sub-1
# │   └── ses-1
# │       ├── 5_qsm_p2_1mmiso_te20
# │       ├── 6_mp2rage_highres_0p5iso_slab
# │       └── 6_qsm_p2_1mmiso_te20
# └── sub-2
#     └── ses-1
#         ├── 5_qsm_p2_1mmiso_te20
#         ├── 6_mp2rage_highres_0p5iso_slab
#         └── 6_qsm_p2_1mmiso_te20
#
# 10 directories, 2 files

# %% [markdown]
# ## Convert to BIDS
#
# Now that the DICOMs are sorted, we can convert to BIDS using `run_1_dicomConvert.py`.
#
# The DICOM to BIDS conversion must identify which series should be used for QSM reconstruction (T2*-weighted), and which series should be used for segmentation (T1-weighted). Because this information is not stored in the DICOM header, the user must provide it, or QSMxT can make a guess based on the `ProtocolName` field. By default, QSMxT assumes series matching any of the patterns in `['*qsm*', '*t2starw*']` are to be used for QSM, and series matching the pattern `['*t1w*']` are to be used for segmentation. If series cannot be identified, the user must do so. At minimum, at least one QSM series must be identified.
#
# If QSMxT is run interactively, the user will be prompted to identify the relevant series'. However, because we are running QSMxT in a notebook, we disable the interactivity using `--auto_yes` and provide the missing information using command-line arguments (`--t1w_protocol_patterns` and `--t2starw_protocol_patterns`). In this case, the T1-weighted scan requires identification, so we pass `--t2starw_protocol_patterns "*mp2rage*"`:

# %%
# !run_1_dicomConvert.py dicoms-sorted bids \
    --t1w_protocol_patterns "*mp2rage*" \
    --auto_yes
# Out:
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Command: /opt/QSMxT/run_1_dicomConvert.py dicoms-sorted bids --t1w_protocol_patterns *mp2rage* --auto_yes
# INFO: Python interpreter: /opt/miniconda-4.7.12.1/bin/python3
# INFO: Converting all DICOMs to NIfTI...
# INFO: Running command: 'dcm2niix -z n -o "/home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data" "/home/jovyan/example-notebooks/structural_imaging/dicoms-sorted/sub-1/ses-1/5_qsm_p2_1mmiso_te20" >> "/home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/dcm2niix_output.txt"'
# INFO: Running command: 'dcm2niix -z n -o "/home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data" "/home/jovyan/example-notebooks/structural_imaging/dicoms-sorted/sub-1/ses-1/6_qsm_p2_1mmiso_te20" >> "/home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/dcm2niix_output.txt"'
# INFO: Running command: 'dcm2niix -z n -o "/home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data" "/home/jovyan/example-notebooks/structural_imaging/dicoms-sorted/sub-1/ses-1/6_mp2rage_highres_0p5iso_slab" >> "/home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/dcm2niix_output.txt"'
# INFO: Running command: 'dcm2niix -z n -o "/home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data" "/home/jovyan/example-notebooks/structural_imaging/dicoms-sorted/sub-2/ses-1/5_qsm_p2_1mmiso_te20" >> "/home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/dcm2niix_output.txt"'
# INFO: Running command: 'dcm2niix -z n -o "/home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data" "/home/jovyan/example-notebooks/structural_imaging/dicoms-sorted/sub-2/ses-1/6_qsm_p2_1mmiso_te20" >> "/home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/dcm2niix_output.txt"'
# INFO: Running command: 'dcm2niix -z n -o "/home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data" "/home/jovyan/example-notebooks/structural_imaging/dicoms-sorted/sub-2/ses-1/6_mp2rage_highres_0p5iso_slab" >> "/home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/dcm2niix_output.txt"'
# INFO: Loading JSON headers from '/home/jovyan/example-notebooks/structural_imaging/bids/.../extra_data' folders...
# INFO: Checking for GE data requiring correction...
# INFO: Loading updated JSON headers from '/home/jovyan/example-notebooks/structural_imaging/bids/.../extra_data' folders...
# INFO: Enumerating protocol names from JSON headers...
# INFO: All protocol names identified: ['mp2rage_highres_0p5iso_slab', 'qsm_p2_1mmiso_te20']
# INFO: Enumerating t2starw protocol names using match patterns ['*t2starw*', '*qsm*']...
# INFO: Identified the following protocols as t2starw: ['qsm_p2_1mmiso_te20']
# INFO: Enumerating t1w protocol names using match patterns ['*mp2rage*']...
# INFO: Identified the following protocols as t1w: ['mp2rage_highres_0p5iso_slab']
# INFO: Parsing relevant details from JSON headers...
# INFO: Parsing relevant JSON data from sub-1/ses-1...
# INFO: Parsing relevant JSON data from sub-1/ses-1...
# INFO: Parsing relevant JSON data from sub-2/ses-1...
# INFO: Parsing relevant JSON data from sub-2/ses-1...
# INFO: Renaming files...
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/6_mp2rage_highres_0p5iso_slab_mp2rage_highRes_0p5iso_slab_20170705150219_6.json -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/anat/sub-1_ses-1_run-01_T1w.json
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/6_mp2rage_highres_0p5iso_slab_mp2rage_highRes_0p5iso_slab_20170705150219_6.nii -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/anat/sub-1_ses-1_run-01_T1w.nii
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/5_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_5.json -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/anat/sub-1_ses-1_run-01_part-mag_T2starw.json
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/5_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_5.nii -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/anat/sub-1_ses-1_run-01_part-mag_T2starw.nii
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/6_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_6_ph.json -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/anat/sub-1_ses-1_run-01_part-phase_T2starw.json
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/extra_data/6_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_6_ph.nii -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-1/ses-1/anat/sub-1_ses-1_run-01_part-phase_T2starw.nii
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/6_mp2rage_highres_0p5iso_slab_mp2rage_highRes_0p5iso_slab_20170705150219_6.json -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/anat/sub-2_ses-1_run-01_T1w.json
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/6_mp2rage_highres_0p5iso_slab_mp2rage_highRes_0p5iso_slab_20170705150219_6.nii -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/anat/sub-2_ses-1_run-01_T1w.nii
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/5_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_5.json -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/anat/sub-2_ses-1_run-01_part-mag_T2starw.json
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/5_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_5.nii -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/anat/sub-2_ses-1_run-01_part-mag_T2starw.nii
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/6_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_6_ph.json -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/anat/sub-2_ses-1_run-01_part-phase_T2starw.json
# INFO: Renaming /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/extra_data/6_qsm_p2_1mmiso_te20_QSM_p2_1mmIso_TE20_20170705134507_6_ph.nii -> /home/jovyan/example-notebooks/structural_imaging/bids/sub-2/ses-1/anat/sub-2_ses-1_run-01_part-phase_T2starw.nii
# INFO: Generating details for BIDS datset_description.json...
# INFO: Writing BIDS dataset_description.json...
# INFO: Writing BIDS .bidsignore file...
# INFO: Writing BIDS dataset README...
# INFO: Finished

# %%
# !tree bids
# Out:
# bids
# ├── README
# ├── dataset_description.json
# ├── log_2023-06-22_02-39-53695902.txt
# ├── references.txt
# ├── sub-1
# │   └── ses-1
# │       ├── anat
# │       │   ├── sub-1_ses-1_run-01_T1w.json
# │       │   ├── sub-1_ses-1_run-01_T1w.nii
# │       │   ├── sub-1_ses-1_run-01_part-mag_T2starw.json
# │       │   ├── sub-1_ses-1_run-01_part-mag_T2starw.nii
# │       │   ├── sub-1_ses-1_run-01_part-phase_T2starw.json
# │       │   └── sub-1_ses-1_run-01_part-phase_T2starw.nii
# │       └── extra_data
# │           └── dcm2niix_output.txt
# └── sub-2
#     └── ses-1
#         ├── anat
#         │   ├── sub-2_ses-1_run-01_T1w.json
#         │   ├── sub-2_ses-1_run-01_T1w.nii
#         │   ├── sub-2_ses-1_run-01_part-mag_T2starw.json
#         │   ├── sub-2_ses-1_run-01_part-mag_T2starw.nii
#         │   ├── sub-2_ses-1_run-01_part-phase_T2starw.json
#         │   └── sub-2_ses-1_run-01_part-phase_T2starw.nii
#         └── extra_data
#             └── dcm2niix_output.txt
#
# 8 directories, 18 files

# %% [markdown]
# # Inspect input data

# %% [markdown]
# Here we define a function we will use to visualise NIfTI images so we can view some of the input data:

# %%
def show_nii(nii_path, title=None, cmap='gray', **imshow_args):
    from matplotlib import pyplot as plt
    import numpy as np
    import nibabel as nib
    import glob

    # load data
    data_1 = nib.load(nii_path).get_fdata()

    # get middle slices
    slc_data1 = np.rot90(data_1[np.shape(data_1)[0]//2,:,:])
    slc_data2 = np.rot90(data_1[:,np.shape(data_1)[1]//2,:])
    slc_data3 = np.rot90(data_1[:,:,np.shape(data_1)[2]//2])

    # show slices
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(8,10))
    if title: plt.suptitle(title)

    axes[0].imshow(slc_data1, cmap=cmap, **imshow_args)
    axes[1].imshow(slc_data2, cmap=cmap, **imshow_args)
    axes[2].imshow(slc_data3, cmap=cmap, **imshow_args)

    axes[0].axis('off')
    axes[1].axis('off')
    axes[2].axis('off')

    fig.tight_layout()
    fig.subplots_adjust(top=1.55)
    plt.show()

# %%
from glob import glob

# %%
show_nii(glob("bids/sub-*/ses-*/anat/*mag*T2starw*nii*")[0], title="Magnitude", vmax=500)
show_nii(glob("bids/sub-*/ses-*/anat/*phase*T2starw*nii*")[0], title="Phase")
show_nii(glob("bids/sub-*/ses-*/anat/*T1w*nii*")[0], title="T1-weighted")

# %% [markdown]
# # Run QSM pipeline

# %% [markdown]
# We are now ready to reconstruct QSM!
#
# QSMxT automates all QSM reconstruction steps from masking, phase combination, phase unwrapping, background field correction, dipole-inversion, and QSM averaging, if necessary.
#
# The pipeline can be fine-tuned using a wide range of algorithms and parameters that are exposed, and this is easiest to do via the CLI interface.
#
# However, QSMxT also provides a range of sensible defaults fit for different purposes. We can list the premade pipelines using `--list_premades`. For the full pipeline details used for each premade pipeline, see [qsm_pipelines.json](https://github.com/QSMxT/QSMxT/blob/master/qsm_pipelines.json).

# %%
# !run_2_qsm.py --list_premades
# Out:
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Parsing arguments...
# === Premade pipelines ===
# default: Default QSMxT settings (GRE)
# gre: Applies suggested settings for 3D-GRE images
# epi: Applies suggested settings for 3D-EPI images (assumes human brain)
# bet: Applies a traditional BET-masking approach (artefact reduction unavailable)
# fast: Applies a set of fast algorithms
# body: Applies suggested settings for non-brain applications
# nextqsm: Applies suggested settings for running the NeXtQSM algorithm (assumes human brain)
# INFO: Finished

# %% [markdown]
# For this demonstration, we will go with the `fast` pipeline. We also include `--auto_yes` to avoid the interactive CLI interface.

# %%
# !run_2_qsm.py bids qsm --premade fast --auto_yes
# Out:
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Parsing arguments...
# INFO: Starting log file: /home/jovyan/example-notebooks/structural_imaging/qsm/qsmxt_log.log
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Python interpreter: /opt/miniconda-4.7.12.1/bin/python3
# INFO: Command: run_2_qsm.py /home/jovyan/example-notebooks/structural_imaging/bids /home/jovyan/example-notebooks/structural_imaging/qsm --premade 'fast' --auto_yes
# INFO: Creating nipype workflow for sub-1/ses-1/run-01...
# INFO: Creating nipype workflow for sub-2/ses-1/run-01...
# 230622-02:40:06,496 nipype.workflow INFO:
# 	 Workflow workflow_qsm settings: ['check', 'execution', 'logging', 'monitoring']
# 230622-02:40:06,519 nipype.workflow INFO:
# 	 Running in parallel.
# 230622-02:40:06,522 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:40:06,656 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-1.ses-1.run-01.nibabel_read-nii" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/nibabel_read-nii".
# 230622-02:40:06,659 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-2.ses-1.run-01.func_read-json-se" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/func_read-json-se".
# 230622-02:40:06,662 nipype.workflow INFO:
# 	 [Node] Setting-up "_func_read-json-me0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/func_read-json-me/mapflow/_func_read-json-me0".
# 230622-02:40:06,663 nipype.workflow INFO:
# 	 [Node] Executing "nibabel_read-nii" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:06,667 nipype.workflow INFO:
# 	 [Node] Setting-up "_nibabel_numpy_scale-phase0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/nibabel_numpy_scale-phase/mapflow/_nibabel_numpy_scale-phase0".
# 230622-02:40:06,666 nipype.workflow INFO:
# 	 [Node] Executing "_func_read-json-me0" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:06,666 nipype.workflow INFO:
# 	 [Node] Setting-up "_nibabel_numpy_scale-phase0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/nibabel_numpy_scale-phase/mapflow/_nibabel_numpy_scale-phase0".
# 230622-02:40:06,670 nipype.workflow INFO:
# 	 [Node] Executing "_nibabel_numpy_scale-phase0" <interfaces.nipype_interface_scalephase.ScalePhaseInterface>
# 230622-02:40:06,673 nipype.workflow INFO:
# 	 [Node] Executing "_nibabel_numpy_scale-phase0" <interfaces.nipype_interface_scalephase.ScalePhaseInterface>
# 230622-02:40:06,655 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-1.ses-1.run-01.func_read-json-se" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/func_read-json-se".
# 230622-02:40:06,659 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-2.ses-1.run-01.nibabel_read-nii" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/nibabel_read-nii".
# 230622-02:40:06,713 nipype.workflow INFO:
# 	 [Node] Executing "nibabel_read-nii" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:06,714 nipype.workflow INFO:
# 	 [Node] Executing "func_read-json-se" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:06,665 nipype.workflow INFO:
# 	 [Node] Executing "func_read-json-se" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:06,668 nipype.workflow INFO:
# 	 [Node] Setting-up "_func_read-json-me0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/func_read-json-me/mapflow/_func_read-json-me0".
# 230622-02:40:06,720 nipype.workflow INFO:
# 	 [Node] Executing "_func_read-json-me0" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:06,722 nipype.workflow INFO:
# 	 [Node] Finished "_func_read-json-me0", elapsed time 0.001104s.
# 230622-02:40:06,749 nipype.workflow INFO:
# 	 [Node] Finished "nibabel_read-nii", elapsed time 0.003047s.
# 230622-02:40:06,771 nipype.workflow INFO:
# 	 [Node] Finished "func_read-json-se", elapsed time 0.006048s.
# 230622-02:40:06,775 nipype.workflow INFO:
# 	 [Node] Finished "_func_read-json-me0", elapsed time 0.000657s.
# 230622-02:40:06,782 nipype.workflow INFO:
# 	 [Node] Finished "nibabel_read-nii", elapsed time 0.012482s.
# 230622-02:40:06,778 nipype.workflow INFO:
# 	 [Node] Finished "func_read-json-se", elapsed time 0.000763s.
# 230622-02:40:07,93 nipype.workflow INFO:
# 	 [Node] Finished "_nibabel_numpy_scale-phase0", elapsed time 0.367889s.
# 230622-02:40:07,126 nipype.workflow INFO:
# 	 [Node] Finished "_nibabel_numpy_scale-phase0", elapsed time 0.398366s.
# 230622-02:40:08,523 nipype.workflow INFO:
# 	 [Job 0] Completed (workflow_qsm.sub-1.ses-1.run-01.func_read-json-me).
# 230622-02:40:08,524 nipype.workflow INFO:
# 	 [Job 1] Completed (workflow_qsm.sub-1.ses-1.run-01.func_read-json-se).
# 230622-02:40:08,525 nipype.workflow INFO:
# 	 [Job 2] Completed (workflow_qsm.sub-1.ses-1.run-01.nibabel_read-nii).
# 230622-02:40:08,526 nipype.workflow INFO:
# 	 [Job 3] Completed (workflow_qsm.sub-1.ses-1.run-01.nibabel_numpy_scale-phase).
# 230622-02:40:08,526 nipype.workflow INFO:
# 	 [Job 4] Completed (workflow_qsm.sub-2.ses-1.run-01.func_read-json-me).
# 230622-02:40:08,527 nipype.workflow INFO:
# 	 [Job 5] Completed (workflow_qsm.sub-2.ses-1.run-01.func_read-json-se).
# 230622-02:40:08,528 nipype.workflow INFO:
# 	 [Job 6] Completed (workflow_qsm.sub-2.ses-1.run-01.nibabel_read-nii).
# 230622-02:40:08,528 nipype.workflow INFO:
# 	 [Job 7] Completed (workflow_qsm.sub-2.ses-1.run-01.nibabel_numpy_scale-phase).
# 230622-02:40:08,529 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:40:08,600 nipype.workflow INFO:
# 	 [Node] Setting-up "_nibabel_as-canonical0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/nibabel_as-canonical/mapflow/_nibabel_as-canonical0".
# 230622-02:40:08,601 nipype.workflow INFO:
# 	 [Node] Setting-up "_nibabel_as-canonical0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/nibabel_as-canonical/mapflow/_nibabel_as-canonical0".
# 230622-02:40:08,603 nipype.workflow INFO:
# 	 [Node] Executing "_nibabel_as-canonical0" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:08,640 nipype.workflow INFO:
# 	 [Node] Finished "_nibabel_as-canonical0", elapsed time 0.005527s.
# 230622-02:40:08,602 nipype.workflow INFO:
# 	 [Node] Executing "_nibabel_as-canonical0" <nipype.interfaces.utility.wrappers.Function>
# 230622-02:40:08,680 nipype.workflow INFO:
# 	 [Node] Finished "_nibabel_as-canonical0", elapsed time 0.003704s.
# 230622-02:40:10,524 nipype.workflow INFO:
# 	 [Job 8] Completed (workflow_qsm.sub-1.ses-1.run-01.nibabel_as-canonical).
# 230622-02:40:10,525 nipype.workflow INFO:
# 	 [Job 9] Completed (workflow_qsm.sub-2.ses-1.run-01.nibabel_as-canonical).
# 230622-02:40:10,527 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:40:10,588 nipype.workflow INFO:
# 	 [Node] Setting-up "_nibabel_numpy_nilearn_axial-resampling0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/nibabel_numpy_nilearn_axial-resampling/mapflow/_nibabel_numpy_nilearn_axial-resampling0".
# 230622-02:40:10,589 nipype.workflow INFO:
# 	 [Node] Setting-up "_nibabel_numpy_nilearn_axial-resampling0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/nibabel_numpy_nilearn_axial-resampling/mapflow/_nibabel_numpy_nilearn_axial-resampling0".
# 230622-02:40:10,591 nipype.workflow INFO:
# 	 [Node] Executing "_nibabel_numpy_nilearn_axial-resampling0" <interfaces.nipype_interface_axialsampling.AxialSamplingInterface>
# Loading mag=sub-2_ses-1_run-01_part-mag_T2starw.nii...
# Loading pha=sub-2_ses-1_run-01_part-phase_T2starw_scaled.nii...
# Obliquity = [2.09768775 2.2770863  1.90738745]; norm = 3.6364189473319284 < 10.0; no resampling needed.
# 230622-02:40:10,619 nipype.workflow INFO:
# 	 [Node] Finished "_nibabel_numpy_nilearn_axial-resampling0", elapsed time 0.002978s.
# 230622-02:40:10,589 nipype.workflow INFO:
# 	 [Node] Executing "_nibabel_numpy_nilearn_axial-resampling0" <interfaces.nipype_interface_axialsampling.AxialSamplingInterface>
# Loading mag=sub-1_ses-1_run-01_part-mag_T2starw.nii...
# Loading pha=sub-1_ses-1_run-01_part-phase_T2starw_scaled.nii...
# Obliquity = [2.09768775 2.2770863  1.90738745]; norm = 3.6364189473319284 < 10.0; no resampling needed.
# 230622-02:40:10,669 nipype.workflow INFO:
# 	 [Node] Finished "_nibabel_numpy_nilearn_axial-resampling0", elapsed time 0.00339s.
# 230622-02:40:12,526 nipype.workflow INFO:
# 	 [Job 10] Completed (workflow_qsm.sub-1.ses-1.run-01.nibabel_numpy_nilearn_axial-resampling).
# 230622-02:40:12,527 nipype.workflow INFO:
# 	 [Job 11] Completed (workflow_qsm.sub-2.ses-1.run-01.nibabel_numpy_nilearn_axial-resampling).
# 230622-02:40:12,529 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:40:12,582 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-1.ses-1.run-01.mrt_romeo_combine" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/mrt_romeo_combine".
# 230622-02:40:12,587 nipype.workflow INFO:
# 	 [Node] Executing "mrt_romeo_combine" <interfaces.nipype_interface_romeo.RomeoB0Interface>
# 230622-02:40:12,583 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-2.ses-1.run-01.mrt_romeo_combine" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/mrt_romeo_combine".
# 230622-02:40:12,638 nipype.workflow INFO:
# 	 [Node] Executing "mrt_romeo_combine" <interfaces.nipype_interface_romeo.RomeoB0Interface>
# 230622-02:40:14,530 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 223.91/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.mrt_romeo_combine
#                        * workflow_qsm.sub-1.ses-1.run-01.mrt_romeo_combine
# 230622-02:41:19,511 nipype.workflow INFO:
# 	 [Node] Finished "mrt_romeo_combine", elapsed time 66.847214s.
# 230622-02:41:20,610 nipype.workflow INFO:
# 	 [Job 13] Completed (workflow_qsm.sub-2.ses-1.run-01.mrt_romeo_combine).
# 230622-02:41:20,612 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 224.11/224.31, Free processors: 15/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.mrt_romeo_combine
# 230622-02:41:20,696 nipype.workflow INFO:
# 	 [Node] Setting-up "_fsl-bet0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/mask_workflow/fsl-bet/mapflow/_fsl-bet0".
# 230622-02:41:20,699 nipype.workflow INFO:
# 	 [Node] Executing "_fsl-bet0" <interfaces.nipype_interface_bet2.Bet2Interface>
# 230622-02:41:22,613 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 223.91/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.mask_workflow.fsl-bet
#                        * workflow_qsm.sub-1.ses-1.run-01.mrt_romeo_combine
# 230622-02:41:25,924 nipype.workflow INFO:
# 	 [Node] Finished "mrt_romeo_combine", elapsed time 73.305981s.
# 230622-02:41:26,616 nipype.workflow INFO:
# 	 [Job 12] Completed (workflow_qsm.sub-1.ses-1.run-01.mrt_romeo_combine).
# 230622-02:41:26,618 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 224.11/224.31, Free processors: 15/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.mask_workflow.fsl-bet
# 230622-02:41:26,681 nipype.workflow INFO:
# 	 [Node] Setting-up "_fsl-bet0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/mask_workflow/fsl-bet/mapflow/_fsl-bet0".
# 230622-02:41:26,682 nipype.workflow INFO:
# 	 [Node] Executing "_fsl-bet0" <interfaces.nipype_interface_bet2.Bet2Interface>
# 230622-02:41:28,619 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 223.91/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.mask_workflow.fsl-bet
#                        * workflow_qsm.sub-2.ses-1.run-01.mask_workflow.fsl-bet
# 230622-02:41:35,693 nipype.workflow INFO:
# 	 [Node] Finished "_fsl-bet0", elapsed time 14.942209s.
# 230622-02:41:36,628 nipype.workflow INFO:
# 	 [Job 15] Completed (workflow_qsm.sub-2.ses-1.run-01.mask_workflow.fsl-bet).
# 230622-02:41:36,630 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 224.11/224.31, Free processors: 15/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.mask_workflow.fsl-bet
# 230622-02:41:36,695 nipype.workflow INFO:
# 	 [Node] Setting-up "_scipy_numpy_nibabel_bet_erode0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/mask_workflow/scipy_numpy_nibabel_bet_erode/mapflow/_scipy_numpy_nibabel_bet_erode0".
# 230622-02:41:36,697 nipype.workflow INFO:
# 	 [Node] Executing "_scipy_numpy_nibabel_bet_erode0" <interfaces.nipype_interface_erode.ErosionInterface>
# 230622-02:41:37,248 nipype.workflow INFO:
# 	 [Node] Finished "_scipy_numpy_nibabel_bet_erode0", elapsed time 0.550155s.
# 230622-02:41:38,630 nipype.workflow INFO:
# 	 [Job 17] Completed (workflow_qsm.sub-2.ses-1.run-01.mask_workflow.scipy_numpy_nibabel_bet_erode).
# 230622-02:41:38,632 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 224.11/224.31, Free processors: 15/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.mask_workflow.fsl-bet
# 230622-02:41:38,707 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_laplacian-unwrapping0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/qsm_workflow/qsmjl_laplacian-unwrapping/mapflow/_qsmjl_laplacian-unwrapping0".
# 230622-02:41:38,709 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_laplacian-unwrapping0" <interfaces.nipype_interface_qsmjl.LaplacianUnwrappingInterface>
# 230622-02:41:40,633 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 221.11/224.31, Free processors: 13/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
#                        * workflow_qsm.sub-1.ses-1.run-01.mask_workflow.fsl-bet
# 230622-02:41:44,214 nipype.workflow INFO:
# 	 [Node] Finished "_fsl-bet0", elapsed time 17.504243s.
# 230622-02:41:44,636 nipype.workflow INFO:
# 	 [Job 14] Completed (workflow_qsm.sub-1.ses-1.run-01.mask_workflow.fsl-bet).
# 230622-02:41:44,637 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
# 230622-02:41:44,692 nipype.workflow INFO:
# 	 [Node] Setting-up "_scipy_numpy_nibabel_bet_erode0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/mask_workflow/scipy_numpy_nibabel_bet_erode/mapflow/_scipy_numpy_nibabel_bet_erode0".
# 230622-02:41:44,693 nipype.workflow INFO:
# 	 [Node] Executing "_scipy_numpy_nibabel_bet_erode0" <interfaces.nipype_interface_erode.ErosionInterface>
# 230622-02:41:45,194 nipype.workflow INFO:
# 	 [Node] Finished "_scipy_numpy_nibabel_bet_erode0", elapsed time 0.499374s.
# 230622-02:41:46,638 nipype.workflow INFO:
# 	 [Job 16] Completed (workflow_qsm.sub-1.ses-1.run-01.mask_workflow.scipy_numpy_nibabel_bet_erode).
# 230622-02:41:46,641 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
# 230622-02:41:46,700 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_laplacian-unwrapping0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/qsm_workflow/qsmjl_laplacian-unwrapping/mapflow/_qsmjl_laplacian-unwrapping0".
# 230622-02:41:46,702 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_laplacian-unwrapping0" <interfaces.nipype_interface_qsmjl.LaplacianUnwrappingInterface>
# 230622-02:41:48,641 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 218.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
# 230622-02:42:24,395 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_laplacian-unwrapping0", elapsed time 45.684248s.
# 230622-02:42:24,678 nipype.workflow INFO:
# 	 [Job 19] Completed (workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping).
# 230622-02:42:24,680 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
# 230622-02:42:24,747 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_phase-to-freq0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/qsm_workflow/qsmjl_phase-to-freq/mapflow/_qsmjl_phase-to-freq0".
# 230622-02:42:24,748 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_phase-to-freq0" <interfaces.nipype_interface_qsmjl.PhaseToFreqInterface>
# 230622-02:42:26,680 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 218.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping
# 230622-02:42:35,15 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_laplacian-unwrapping0", elapsed time 48.311518s.
# 230622-02:42:36,690 nipype.workflow INFO:
# 	 [Job 18] Completed (workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_laplacian-unwrapping).
# 230622-02:42:36,692 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq
# 230622-02:42:36,759 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_phase-to-freq0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/qsm_workflow/qsmjl_phase-to-freq/mapflow/_qsmjl_phase-to-freq0".
# 230622-02:42:36,760 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_phase-to-freq0" <interfaces.nipype_interface_qsmjl.PhaseToFreqInterface>
# 230622-02:42:38,692 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 218.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq
# 230622-02:42:38,889 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_phase-to-freq0", elapsed time 14.138878s.
# 230622-02:42:40,694 nipype.workflow INFO:
# 	 [Job 21] Completed (workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq).
# 230622-02:42:40,696 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq
# 230622-02:42:40,764 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_vsharp0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/qsm_workflow/qsmjl_vsharp/mapflow/_qsmjl_vsharp0".
# 230622-02:42:40,766 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_vsharp0" <interfaces.nipype_interface_qsmjl.VsharpInterface>
# 230622-02:42:42,697 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 218.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_vsharp
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq
# 230622-02:42:50,767 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_phase-to-freq0", elapsed time 14.004897s.
# 230622-02:42:52,706 nipype.workflow INFO:
# 	 [Job 20] Completed (workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_phase-to-freq).
# 230622-02:42:52,709 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_vsharp
# 230622-02:42:52,776 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_vsharp0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/qsm_workflow/qsmjl_vsharp/mapflow/_qsmjl_vsharp0".
# 230622-02:42:52,778 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_vsharp0" <interfaces.nipype_interface_qsmjl.VsharpInterface>
# 230622-02:42:54,709 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 218.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_vsharp
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_vsharp
# 230622-02:43:07,792 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_vsharp0", elapsed time 27.025278s.
# 230622-02:43:08,721 nipype.workflow INFO:
# 	 [Job 23] Completed (workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_vsharp).
# 230622-02:43:08,723 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 221.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_vsharp
# 230622-02:43:08,780 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_rts0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/qsm_workflow/qsmjl_rts/mapflow/_qsmjl_rts0".
# 230622-02:43:08,781 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_rts0" <interfaces.nipype_interface_qsmjl.RtsQsmInterface>
# 230622-02:43:10,724 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 216.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_rts
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_vsharp
# 230622-02:43:19,986 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_vsharp0", elapsed time 27.207347s.
# 230622-02:43:20,735 nipype.workflow INFO:
# 	 [Job 22] Completed (workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_vsharp).
# 230622-02:43:20,737 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 219.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_rts
# 230622-02:43:20,798 nipype.workflow INFO:
# 	 [Node] Setting-up "_qsmjl_rts0" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/qsm_workflow/qsmjl_rts/mapflow/_qsmjl_rts0".
# 230622-02:43:20,799 nipype.workflow INFO:
# 	 [Node] Executing "_qsmjl_rts0" <interfaces.nipype_interface_qsmjl.RtsQsmInterface>
# 230622-02:43:22,739 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 214.31/224.31, Free processors: 12/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_rts
#                        * workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_rts
# 230622-02:43:40,875 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_rts0", elapsed time 32.092241s.
# 230622-02:43:42,758 nipype.workflow INFO:
# 	 [Job 25] Completed (workflow_qsm.sub-2.ses-1.run-01.qsm_workflow.qsmjl_rts).
# 230622-02:43:42,760 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 219.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_rts
# 230622-02:43:42,811 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-2.ses-1.run-01.nibabel_numpy_qsm-average" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/nibabel_numpy_qsm-average".
# 230622-02:43:42,815 nipype.workflow INFO:
# 	 [Node] Executing "nibabel_numpy_qsm-average" <interfaces.nipype_interface_nonzeroaverage.NonzeroAverageInterface>
# 230622-02:43:42,816 nipype.workflow INFO:
# 	 [Node] Finished "nibabel_numpy_qsm-average", elapsed time 0.000169s.
# 230622-02:43:44,760 nipype.workflow INFO:
# 	 [Job 27] Completed (workflow_qsm.sub-2.ses-1.run-01.nibabel_numpy_qsm-average).
# 230622-02:43:44,762 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 219.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_rts
# 230622-02:43:44,834 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-2.ses-1.run-01.nipype_datasink" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-2/ses-1/run-01/nipype_datasink".
# 230622-02:43:44,840 nipype.workflow INFO:
# 	 [Node] Executing "nipype_datasink" <nipype.interfaces.io.DataSink>
# 230622-02:43:44,842 nipype.workflow INFO:
# 	 [Node] Finished "nipype_datasink", elapsed time 0.00122s.
# 230622-02:43:46,761 nipype.workflow INFO:
# 	 [Job 29] Completed (workflow_qsm.sub-2.ses-1.run-01.nipype_datasink).
# 230622-02:43:46,763 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 219.31/224.31, Free processors: 14/16.
#                      Currently running:
#                        * workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_rts
# 230622-02:43:56,604 nipype.workflow INFO:
# 	 [Node] Finished "_qsmjl_rts0", elapsed time 35.803583s.
# 230622-02:43:56,771 nipype.workflow INFO:
# 	 [Job 24] Completed (workflow_qsm.sub-1.ses-1.run-01.qsm_workflow.qsmjl_rts).
# 230622-02:43:56,773 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:43:56,833 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-1.ses-1.run-01.nibabel_numpy_qsm-average" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/nibabel_numpy_qsm-average".
# 230622-02:43:56,836 nipype.workflow INFO:
# 	 [Node] Executing "nibabel_numpy_qsm-average" <interfaces.nipype_interface_nonzeroaverage.NonzeroAverageInterface>
# 230622-02:43:56,838 nipype.workflow INFO:
# 	 [Node] Finished "nibabel_numpy_qsm-average", elapsed time 0.000209s.
# 230622-02:43:58,773 nipype.workflow INFO:
# 	 [Job 26] Completed (workflow_qsm.sub-1.ses-1.run-01.nibabel_numpy_qsm-average).
# 230622-02:43:58,775 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:43:58,833 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_qsm.sub-1.ses-1.run-01.nipype_datasink" in "/home/jovyan/example-notebooks/structural_imaging/qsm/workflow_qsm/sub-1/ses-1/run-01/nipype_datasink".
# 230622-02:43:58,838 nipype.workflow INFO:
# 	 [Node] Executing "nipype_datasink" <nipype.interfaces.io.DataSink>
# 230622-02:43:58,840 nipype.workflow INFO:
# 	 [Node] Finished "nipype_datasink", elapsed time 0.000674s.
# 230622-02:44:00,775 nipype.workflow INFO:
# 	 [Job 28] Completed (workflow_qsm.sub-1.ses-1.run-01.nipype_datasink).
# 230622-02:44:00,779 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# INFO: Finished

# %% [markdown]
# ## View QSM results

# %% [markdown]
# Let's have a look at the generated `qsm` folder:

# %%
# !tree qsm/ -L 1 --dirsfirst
# Out:
# qsm/
# ├── mask
# ├── qsm_final
# ├── workflow_qsm
# ├── command.txt
# ├── pypeline.log
# ├── qsmxt_log.log
# ├── references.txt
# └── settings.json
#
# 3 directories, 5 files

# %% [markdown]
# The `references.txt` file contains a list of all the algorithms used and relevant citations:

# %%
# !cat qsm/references.txt
# Out:
# == Citations ==
#
#  - QSMxT: Stewart AW, Robinson SD, O'Brien K, et al. QSMxT: Robust masking and artifact reduction for quantitative susceptibility mapping. Magnetic Resonance in Medicine. 2022;87(3):1289-1300. doi:10.1002/mrm.29048
#
#  - QSMxT: Stewart AW, Bollman S, et al. QSMxT/QSMxT. GitHub; 2022. https://github.com/QSMxT/QSMxT
#
#  - Brain extraction: Smith SM. Fast robust automated brain extraction. Human Brain Mapping. 2002;17(3):143-155. doi:10.1002/hbm.10062
#
#  - Brain extraction: Liangfu Chen. liangfu/bet2 - Standalone Brain Extraction Tool. GitHub; 2015. https://github.com/liangfu/bet2
#
#  - Unwrapping algorithm - Laplacian: Schofield MA, Zhu Y. Fast phase unwrapping algorithm for interferometric applications. Optics letters. 2003 Jul 15;28(14):1194-6. doi:10.1364/OL.28.001194
#
#  - Unwrapping algorithm - Laplacian: Zhou D, Liu T, Spincemaille P, Wang Y. Background field removal by solving the Laplacian boundary value problem. NMR in Biomedicine. 2014 Mar;27(3):312-9. doi:10.1002/nbm.3064
#
#  - Unwrapping algorithm - ROMEO: Dymerska B, Eckstein K, Bachrata B, et al. Phase unwrapping with a rapid opensource minimum spanning tree algorithm (ROMEO). Magnetic Resonance in Medicine. 2021;85(4):2294-2308. doi:10.1002/mrm.28563
#
#  - Background field removal - V-SHARP: Wu B, Li W, Guidon A et al. Whole brain susceptibility mapping using compressed sensing. Magnetic resonance in medicine. 2012 Jan;67(1):137-47. doi:10.1002/mrm.23000
#
#  - QSM algorithm - RTS: Kames C, Wiggermann V, Rauscher A. Rapid two-step dipole inversion for susceptibility mapping with sparsity priors. Neuroimage. 2018 Feb 15;167:276-83. doi:10.1016/j.neuroimage.2017.11.018
#
#  - Julia package - QSM.jl: kamesy. GitHub; 2022. https://github.com/kamesy/QSM.jl
#
#  - Julia package - MriResearchTools: Eckstein K. korbinian90/MriResearchTools.jl. GitHub; 2022. https://github.com/korbinian90/MriResearchTools.jl
#
#  - Python package - nibabel: Brett M, Markiewicz CJ, Hanke M, et al. nipy/nibabel. GitHub; 2019. https://github.com/nipy/nibabel
#
#  - Python package - scipy: Virtanen P, Gommers R, Oliphant TE, et al. SciPy 1.0: fundamental algorithms for scientific computing in Python. Nat Methods. 2020;17(3):261-272. doi:10.1038/s41592-019-0686-2
#
#  - Python package - numpy: Harris CR, Millman KJ, van der Walt SJ, et al. Array programming with NumPy. Nature. 2020;585(7825):357-362. doi:10.1038/s41586-020-2649-2
#
#  - Python package - Nipype: Gorgolewski K, Burns C, Madison C, et al. Nipype: A Flexible, Lightweight and Extensible Neuroimaging Data Processing Framework in Python. Frontiers in Neuroinformatics. 2011;5. Accessed April 20, 2022. doi:10.3389/fninf.2011.00013

# %% [markdown]
# Let's view one of the QSM results:

# %%
show_nii(glob("qsm/qsm_final/*/*.nii*")[0], cmap='gray', vmin=-0.15, vmax=+0.15, interpolation='nearest')

# %% [markdown]
# # Segment T1-weighted images

# %% [markdown]
# QSMxT doesn't just reconstruct QSM - it also assists with segmentation and quantitative analysis!
#
# QSMxT uses FastSurfer to segment our T1-weighted images and automatically registers them to the T2*-weighted/QSM space:

# %%
# !run_3_segment.py bids segmentations
# Out:
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Command: /opt/QSMxT/run_3_segment.py bids segmentations
# INFO: Python interpreter: /opt/miniconda-4.7.12.1/bin/python3
# INFO: Running with 16 processors.
# 230622-02:44:06,448 nipype.workflow INFO:
# 	 Workflow workflow_segmentation settings: ['check', 'execution', 'logging', 'monitoring']
# 230622-02:44:06,460 nipype.workflow INFO:
# 	 Running in parallel.
# 230622-02:44:06,487 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:44:06,559 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-1.ses-1.run-01.fastsurfer_segment-t1" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-1/ses-1/run-01/fastsurfer_segment-t1".
# 230622-02:44:06,560 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-1.ses-1.run-01.ants_register-t1-to-qsm" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-1/ses-1/run-01/ants_register-t1-to-qsm".
# 230622-02:44:06,562 nipype.workflow INFO:
# 	 [Node] Executing "fastsurfer_segment-t1" <interfaces.nipype_interface_fastsurfer.FastSurferInterface>
# 230622-02:44:06,564 nipype.workflow INFO:
# 	 [Node] Executing "ants_register-t1-to-qsm" <nipype.interfaces.ants.registration.RegistrationSynQuick>
# 230622-02:44:08,491 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 209.31/224.31, Free processors: 2/16.
#                      Currently running:
#                        * workflow_segmentation.sub-1.ses-1.run-01.ants_register-t1-to-qsm
#                        * workflow_segmentation.sub-1.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:47:32,592 nipype.workflow INFO:
# 	 [Node] Finished "ants_register-t1-to-qsm", elapsed time 206.025929s.
# 230622-02:47:32,747 nipype.workflow INFO:
# 	 [Job 1] Completed (workflow_segmentation.sub-1.ses-1.run-01.ants_register-t1-to-qsm).
# 230622-02:47:32,748 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 213.31/224.31, Free processors: 8/16.
#                      Currently running:
#                        * workflow_segmentation.sub-1.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:47:32,806 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-2/ses-1/run-01/fastsurfer_segment-t1".
# 230622-02:47:32,822 nipype.workflow INFO:
# 	 [Node] Executing "fastsurfer_segment-t1" <interfaces.nipype_interface_fastsurfer.FastSurferInterface>
# 230622-02:47:34,750 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 202.31/224.31, Free processors: 0/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1
#                        * workflow_segmentation.sub-1.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:54:17,776 nipype.workflow INFO:
# 	 [Node] Finished "fastsurfer_segment-t1", elapsed time 611.212382s.
# 230622-02:54:19,311 nipype.workflow INFO:
# 	 [Job 0] Completed (workflow_segmentation.sub-1.ses-1.run-01.fastsurfer_segment-t1).
# 230622-02:54:19,314 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 213.31/224.31, Free processors: 8/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:54:19,388 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-1.ses-1.run-01.numpy_numpy_nibabel_mgz2nii" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-1/ses-1/run-01/numpy_numpy_nibabel_mgz2nii".
# 230622-02:54:19,388 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-2/ses-1/run-01/ants_register-t1-to-qsm".
# 230622-02:54:19,392 nipype.workflow INFO:
# 	 [Node] Executing "numpy_numpy_nibabel_mgz2nii" <interfaces.nipype_interface_mgz2nii.Mgz2NiiInterface>
# 230622-02:54:19,393 nipype.workflow INFO:
# 	 [Node] Executing "ants_register-t1-to-qsm" <nipype.interfaces.ants.registration.RegistrationSynQuick>
# 230622-02:54:19,612 nipype.workflow INFO:
# 	 [Node] Finished "numpy_numpy_nibabel_mgz2nii", elapsed time 0.217788s.
# 230622-02:54:21,309 nipype.workflow INFO:
# 	 [Job 4] Completed (workflow_segmentation.sub-1.ses-1.run-01.numpy_numpy_nibabel_mgz2nii).
# 230622-02:54:21,311 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 209.31/224.31, Free processors: 2/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm
#                        * workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:54:21,429 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-1.ses-1.run-01.ants_transform-segmentation-to-qsm" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-1/ses-1/run-01/ants_transform-segmentation-to-qsm".
# 230622-02:54:21,436 nipype.workflow INFO:
# 	 [Node] Executing "ants_transform-segmentation-to-qsm" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 230622-02:54:22,351 nipype.workflow INFO:
# 	 [Node] Finished "ants_transform-segmentation-to-qsm", elapsed time 0.913392s.
# 230622-02:54:23,312 nipype.workflow INFO:
# 	 [Job 6] Completed (workflow_segmentation.sub-1.ses-1.run-01.ants_transform-segmentation-to-qsm).
# 230622-02:54:23,320 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 209.31/224.31, Free processors: 2/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm
#                        * workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:54:23,392 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-1.ses-1.run-01.nipype_datasink" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-1/ses-1/run-01/nipype_datasink".
# 230622-02:54:23,399 nipype.workflow INFO:
# 	 [Node] Executing "nipype_datasink" <nipype.interfaces.io.DataSink>
# 230622-02:54:23,406 nipype.workflow INFO:
# 	 [Node] Finished "nipype_datasink", elapsed time 0.001076s.
# 230622-02:54:25,314 nipype.workflow INFO:
# 	 [Job 8] Completed (workflow_segmentation.sub-1.ses-1.run-01.nipype_datasink).
# 230622-02:54:25,316 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 209.31/224.31, Free processors: 2/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm
#                        * workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1
# 230622-02:57:39,286 nipype.workflow INFO:
# 	 [Node] Finished "fastsurfer_segment-t1", elapsed time 606.460533s.
# 230622-02:57:39,546 nipype.workflow INFO:
# 	 [Job 2] Completed (workflow_segmentation.sub-2.ses-1.run-01.fastsurfer_segment-t1).
# 230622-02:57:39,547 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 220.31/224.31, Free processors: 10/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm
# 230622-02:57:39,578 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-2.ses-1.run-01.numpy_numpy_nibabel_mgz2nii" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-2/ses-1/run-01/numpy_numpy_nibabel_mgz2nii".
# 230622-02:57:39,583 nipype.workflow INFO:
# 	 [Node] Executing "numpy_numpy_nibabel_mgz2nii" <interfaces.nipype_interface_mgz2nii.Mgz2NiiInterface>
# 230622-02:57:39,799 nipype.workflow INFO:
# 	 [Node] Finished "numpy_numpy_nibabel_mgz2nii", elapsed time 0.214446s.
# 230622-02:57:41,548 nipype.workflow INFO:
# 	 [Job 5] Completed (workflow_segmentation.sub-2.ses-1.run-01.numpy_numpy_nibabel_mgz2nii).
# 230622-02:57:41,549 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 220.31/224.31, Free processors: 10/16.
#                      Currently running:
#                        * workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm
# 230622-02:57:45,22 nipype.workflow INFO:
# 	 [Node] Finished "ants_register-t1-to-qsm", elapsed time 205.627458s.
# 230622-02:57:45,552 nipype.workflow INFO:
# 	 [Job 3] Completed (workflow_segmentation.sub-2.ses-1.run-01.ants_register-t1-to-qsm).
# 230622-02:57:45,553 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:57:45,580 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-2.ses-1.run-01.ants_transform-segmentation-to-qsm" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-2/ses-1/run-01/ants_transform-segmentation-to-qsm".
# 230622-02:57:45,588 nipype.workflow INFO:
# 	 [Node] Executing "ants_transform-segmentation-to-qsm" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 230622-02:57:45,897 nipype.workflow INFO:
# 	 [Node] Finished "ants_transform-segmentation-to-qsm", elapsed time 0.307204s.
# 230622-02:57:47,554 nipype.workflow INFO:
# 	 [Job 7] Completed (workflow_segmentation.sub-2.ses-1.run-01.ants_transform-segmentation-to-qsm).
# 230622-02:57:47,556 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# 230622-02:57:47,585 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_segmentation.sub-2.ses-1.run-01.nipype_datasink" in "/home/jovyan/example-notebooks/structural_imaging/segmentations/workflow_segmentation/sub-2/ses-1/run-01/nipype_datasink".
# 230622-02:57:47,591 nipype.workflow INFO:
# 	 [Node] Executing "nipype_datasink" <nipype.interfaces.io.DataSink>
# 230622-02:57:47,593 nipype.workflow INFO:
# 	 [Node] Finished "nipype_datasink", elapsed time 0.000686s.
# 230622-02:57:49,555 nipype.workflow INFO:
# 	 [Job 9] Completed (workflow_segmentation.sub-2.ses-1.run-01.nipype_datasink).
# 230622-02:57:49,556 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 224.31/224.31, Free processors: 16/16.
# INFO: Finished

# %% [markdown]
# ## View segmentations

# %% [markdown]
# Let's have a look at the generated `segmentations` folder:

# %%
# !tree segmentations -L 1 --dirsfirst
# Out:
# segmentations
# ├── qsm_segmentations
# ├── t1_segmentations
# ├── workflow_segmentation
# ├── log_2023-06-22_02-44-05128275.txt
# └── references.txt
#
# 3 directories, 2 files

# %% [markdown]
# We can see that we have segmentation files in both the QSM space and the T1-weighted space:

# %%
# !tree segmentations/*segmentations
# Out:
# segmentations/qsm_segmentations
# ├── sub-1_ses-1_run-01_T1w_segmentation_nii_trans.nii
# └── sub-2_ses-1_run-01_T1w_segmentation_nii_trans.nii
# segmentations/t1_segmentations
# ├── sub-1_ses-1_run-01_T1w_segmentation_nii.nii
# └── sub-2_ses-1_run-01_T1w_segmentation_nii.nii
#
# 0 directories, 4 files

# %% [markdown]
# Once again, we can view any relevant citations:

# %%
# !cat segmentations/details_and_citations.txt
# Out:
# cat: segmentations/details_and_citations.txt: No such file or directory

# %% [markdown]
# # Run analysis pipeline

# %% [markdown]
# The final pipeline we will run is the analysis pipeline. This simply looks at each of our QSM images and associated segmentations to produce a CSV spreadsheet containing susceptibility statistics for each ROI grouped by subject:

# %%
# !run_5_analysis.py --segmentations segmentations/qsm_segmentations/* --qsm_files qsm/qsm_final/*/*.nii* --output_dir analysis --labels_file /opt/QSMxT/aseg_labels.csv
# Out:
# INFO: Running QSMxT v1.3.5 (commit date: Sat Feb 25 22:06:42 2023 +1000)
# INFO: Command: /opt/QSMxT/run_5_analysis.py --segmentations segmentations/qsm_segmentations/sub-1_ses-1_run-01_T1w_segmentation_nii_trans.nii segmentations/qsm_segmentations/sub-2_ses-1_run-01_T1w_segmentation_nii_trans.nii --qsm_files qsm/qsm_final/_qsmjl_rts0/sub-1_ses-1_run-01_part-phase_T2starw_scaled_romeo-combined_to-phase-wrapped_unwrapped-laplacian_freq_vsharp_rts.nii qsm/qsm_final/_qsmjl_rts0/sub-2_ses-1_run-01_part-phase_T2starw_scaled_romeo-combined_to-phase-wrapped_unwrapped-laplacian_freq_vsharp_rts.nii --output_dir analysis --labels_file /opt/QSMxT/aseg_labels.csv
# INFO: Python interpreter: /opt/miniconda-4.7.12.1/bin/python3
# INFO: Analysing file sub-1_ses-1_run-01_part-phase_T2starw_scaled_romeo-combined_to-phase-wrapped_unwrapped-laplacian_freq_vsharp_rts.nii with segmentation sub-1_ses-1_run-01_T1w_segmentation_nii_trans.nii
# INFO: Analysing file sub-2_ses-1_run-01_part-phase_T2starw_scaled_romeo-combined_to-phase-wrapped_unwrapped-laplacian_freq_vsharp_rts.nii with segmentation sub-2_ses-1_run-01_T1w_segmentation_nii_trans.nii
# INFO: Finished

# %% [markdown]
# Here, we view some susceptibility statistics for the left Putamen:

# %%
# !head analysis/sub-1*csv -n 1
# !cat analysis/*.csv | grep Left-Putamen
# Out:
# roi,num_voxels,min,max,median,mean,std
# Left-Putamen,4609,-0.0671703530702545,0.14612385129488253,0.05384808826375763,0.0522866458532047,0.03184238530548529
# Left-Putamen,4599,-0.04625692917219062,0.14612385129488253,0.05483601350701524,0.05337269823568828,0.031711998574852206

# %% [markdown]
# # Quantitative visualisation

# %% [markdown]
# While QSMxT produces numerical outputs, we can also use some straightforward Python to visualise some of the results.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 22.2 MB/s eta 0:00:00
# Collecting numpy!=1.24.0,>=1.17
#   Downloading numpy-1.25.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 62.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/conda/lib/python3.10/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: numpy, seaborn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.0
#     Uninstalling numpy-1.24.0:
#       Successfully uninstalled numpy-1.24.0
# Successfully installed numpy-1.25.0 seaborn-0.12.2

# %%
# import modules
import numpy as np
import nibabel as nib
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from glob import glob

# %%
# define regions of interest
# see https://github.com/QSMxT/QSMxT/blob/master/aseg_labels.csv for a full list
rois = { 
    "Thalamus" : [9, 10, 48, 49],
    "Pallidum" : [12, 13, 52, 53],
    "Caudate" : [11, 50],
    "Putamen" : [12, 51],
    "Brain stem" : [16],
    "CSF" : [24, 122, 257, 701],
    "White matter" : [2, 7, 41, 46, 177]
}
roi_names = { value: key for key in rois for value in rois[key] }
roi_ids = [value for roi in rois.values() for value in roi]

# %%
# load a reconstruction
qsm = nib.load(glob("qsm/qsm_final/*/*.nii*")[0]).get_fdata().flatten()
seg = nib.load(glob("segmentations/qsm_segmentations/*.nii*")[0]).get_fdata().flatten()

# %%
# retain only the rois
qsm = qsm[np.isin(seg, roi_ids)]
seg = seg[np.isin(seg, roi_ids)]

# %%
# convert to a dataframe for plotting purposes
seg = pd.Series(seg).map(roi_names)
data = pd.DataFrame({ 'qsm' : qsm, 'seg' : seg })

# %%
print(data.groupby('seg')['qsm'].agg(['mean', 'std']).sort_values('mean').round(decimals=3))
# Out:
#                mean    std
# seg
# Brain stem   -0.042  0.028
# White matter -0.002  0.027
# Thalamus      0.029  0.033
# CSF           0.030  0.097
# Pallidum      0.035  0.061
# Putamen       0.047  0.033
# Caudate       0.049  0.024

# %%
medians = data.groupby('seg')['qsm'].median().sort_values()
order = medians.index

# %%
# plot
fig = plt.figure()
ax = sns.boxplot(data, y='qsm', x='seg', fliersize=0, color='lightblue', order=order)
ax.set_xticklabels(ax.get_xticklabels(), ha='right', rotation=45)
ax.set_ylim(-0.2, 0.3)
ax.axhline(y=0, color='pink', linestyle='-', linewidth=1, zorder=-1)
ax.set_xlabel("Region of interest")
ax.set_ylabel("Susceptibility (ppm)")
ax.set_title("QSM")
plt.show()
