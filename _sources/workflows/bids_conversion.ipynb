# %% [markdown]
# # BIDS conversion
#
# Author: Thuy Dao
#
# Citation:
# - [dcm2niix](https://doi.org/10.1016/j.jneumeth.2016.03.001)
# - [bidscoin](https://doi.org/10.3389/fninf.2021.770608)
# - [heudiconv](https://doi.org/10.5281/zenodo.1012598)

# %% [markdown]
# ## Output CPU information

# %%
# !cat /proc/cpuinfo | grep 'vendor' | uniq
# !cat /proc/cpuinfo | grep 'model name' | uniq
# Out:
# vendor_id	: GenuineIntel
# model name	: Intel(R) Xeon(R) Gold 6126 CPU @ 2.60GHz

# %% [markdown]
# ## BIDS conversion
# 1. In this interactive example notebook, we first download DICOM data using `datalad`.
#
# 2. Next we will convert DICOMS into the BIDS data structure using:
#     - 2.1. `dcm2niix` which converts data to NIfTi and then manually organizes the folder.
#     - 2.2. `heudiconv` to automate the conversion and organization with a provided heuristic file.
#     - 2.3. `bidscoin` to automate the conversion and organization with the bidseditor interface (optionally using `--automated` to disable user interaction).

# %% [markdown]
# ## 1. Data preparation
#
# This example uses a phantom dataset generated by the University of Arizona on their Siemens Skyra 3T with Syngo MR VE11c software on 2018_02_08.
#
# Download DICOM data from Datalad.

# %%
# %%bash
# datalad install https://datasets.datalad.org/repronim/heudiconv-reproin-example
# cd heudiconv-reproin-example/REPROIN/dicom && datalad get 001
# Out:
# [INFO] Attempting a clone into /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example
# [INFO] Attempting to clone from https://datasets.datalad.org/repronim/heudiconv-reproin-example to /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example
# [INFO] Attempting to clone from https://datasets.datalad.org/repronim/heudiconv-reproin-example/.git to /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example
# [INFO] Start enumerating objects
# [INFO] Start counting objects
# [INFO] Start compressing objects
# [INFO] Start receiving objects
# [INFO] Start resolving deltas
# [INFO] Completed clone attempts for Dataset(/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example)
# [INFO] scanning for unlocked files (this may take some time)
# install(ok): /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example (dataset)
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0005.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0002-0005.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0003-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0003-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0003-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0003-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0003-0005.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0004-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0004-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0004-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0005-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0005-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0005-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0006-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0006-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0007-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0007-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0008-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0008-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0009-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0009-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0010-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0010-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0011-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0011-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0012-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0012-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0013-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0013-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0014-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0014-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0015-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0015-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0016-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0016-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0017-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0017-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0018-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0018-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0019-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0019-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0020-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0020-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0021-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0021-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0022-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0022-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0023-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0023-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0024-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0024-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0025-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0025-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0026-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0026-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0027-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0027-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0028-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0028-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0029-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0029-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0030-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0030-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0031-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0031-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0032-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0032-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0033-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0033-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0034-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0034-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0035-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0035-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0036-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0036-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0037-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0037-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0038-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0038-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0039-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0039-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0040-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0040-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0041-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0041-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0042-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0042-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0043-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0043-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0044-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0044-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0045-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0045-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0046-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0046-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0047-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0047-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0048-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0048-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0049-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0049-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0050-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0050-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0051-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0051-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0052-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0052-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0053-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0053-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0054-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0054-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0055-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0055-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0056-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0056-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0057-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0057-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0058-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0058-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0059-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0059-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0060-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0060-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0061-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0061-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0062-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0062-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0063-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0063-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0064-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0064-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0065-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0065-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0066-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0066-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0067-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0067-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0068-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0068-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0069-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0069-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0070-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0070-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0071-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0071-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0072-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0072-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0073-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0073-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0074-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0074-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0075-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0075-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0076-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0076-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0077-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0077-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0078-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0078-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0079-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0079-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0080-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0080-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0081-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0081-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0082-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0082-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0083-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0083-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0084-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0084-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0085-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0085-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0086-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0086-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0087-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0087-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0088-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0088-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0089-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0089-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0090-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0090-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0091-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0091-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0092-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0092-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0093-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0093-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0094-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0094-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0095-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0095-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0096-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0096-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0097-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0097-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0098-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0098-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0099-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0099-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0100-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0100-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0101-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0101-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0102-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0102-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0103-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0103-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0104-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0104-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0105-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0105-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0106-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0106-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0107-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0107-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0108-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0108-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0109-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0109-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0110-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0110-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0111-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0111-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0112-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0112-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0113-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0113-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0114-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0114-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0115-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0115-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0116-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0116-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0117-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0117-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0118-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0118-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0119-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0119-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0120-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0120-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0121-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0121-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0122-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0122-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0123-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0123-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0124-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0124-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0125-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0125-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0126-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0126-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0127-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0127-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0128-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0128-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0005.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0006.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0007.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0008.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0009.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0010.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0011.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0012.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0013.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0014.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0015.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0016.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0017.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0018.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0019.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0020.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0021.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0022.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0023.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0024.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0025.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0026.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0027.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0028.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0029.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0030.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0031.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0032.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0033.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0034.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0035.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0036.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0037.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0038.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0039.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0040.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0041.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0042.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0043.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0044.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0045.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0046.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0047.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0048.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0049.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0050.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0051.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0052.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0053.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0054.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0055.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0056.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0057.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0058.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0059.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0060.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0061.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0062.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0063.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0064.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0065.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0066.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0067.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0068.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0069.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0070.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0071.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0072.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0073.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0074.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0075.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0076.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0077.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0078.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0079.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0080.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0081.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0082.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0083.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0084.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0085.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0086.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0087.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0088.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0089.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0090.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0091.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0092.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0093.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0094.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0095.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0096.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0097.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0098.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0099.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0100.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0101.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0102.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0103.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0104.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0105.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0106.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0107.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0108.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0109.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0110.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0111.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0112.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0113.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0114.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0115.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0116.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0117.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0118.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0119.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0120.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0121.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0122.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0123.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0124.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0125.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0126.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0127.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0128.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0129.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0130.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0131.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0132.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0133.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0134.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0135.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0136.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0137.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0138.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0139.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0140.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0141.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0142.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0143.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0144.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0145.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0146.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0147.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0148.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0149.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0150.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0151.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0152.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0153.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0154.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0155.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0156.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0157.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0158.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0159.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0160.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0161.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0162.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0163.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0164.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0165.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0166.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0167.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0168.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0169.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0170.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0171.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0172.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0173.dcm (file) [from origin...]
# ...
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0025.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0026.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0027.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0028.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0029.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0030.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0031.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0032.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0033.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0034.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0035.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0036.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0037.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0038.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0039.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0040.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0041.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0042.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0043.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0044.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0005.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0006.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0007.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0008.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0009.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0010.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0011.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0012.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0013.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0014.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0015.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0016.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0017.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0018.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0019.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0020.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0021.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0022.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0023.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0024.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0025.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0026.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0027.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0028.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0029.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0030.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0031.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0032.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0033.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0034.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0035.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0036.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0037.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0038.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0039.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0040.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0041.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0042.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0043.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0044.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0045.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0046.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0047.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0048.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0049.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0050.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0051.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0052.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0053.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0054.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0055.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0056.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0057.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0058.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0059.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0060.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0061.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0062.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0063.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0064.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0065.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0066.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0067.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0068.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0069.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0070.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0071.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0072.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0073.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0074.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0075.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0076.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0077.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0078.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0079.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0080.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0081.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0082.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0083.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0084.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0085.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0086.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0087.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0088.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0089.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0090.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0091.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0092.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0093.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0094.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0095.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0096.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0097.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0098.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0099.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0100.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0101.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0102.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0103.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0104.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0105.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0106.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0107.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0108.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0109.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0110.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0111.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0112.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0113.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0114.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0115.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0116.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0117.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0118.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0119.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0120.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0121.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0122.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0123.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0124.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0125.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0126.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0127.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0128.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0129.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0130.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0131.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0132.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16/IM-0011-0001.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16/IM-0011-0002.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16/IM-0011-0003.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16/IM-0011-0004.dcm (file) [from origin...]
# get(ok): REPROIN/dicom/001 (directory)
# action summary:
#   get (ok: 792)

# %% [markdown]
# We will be working from a directory called `REPROIN`. Under the REPROIN directory is the `dicom` subdirectory: Under the subject number `001` the session `Patterson_Coben - 1` is nested. Each dicom sequence folder is nested under the session:

# %%
# !tree heudiconv-reproin-example/REPROIN/ -I "*.dcm"
# Out:
# heudiconv-reproin-example/REPROIN/
# └── dicom
#     └── 001
#         └── Patterson_Coben - 1
#             ├── Localizers_4
#             ├── anatT1w_acqMPRAGE_6
#             ├── dwi_dirAP_9
#             ├── fmap_acq4mm_7
#             ├── fmap_acq4mm_8
#             ├── fmap_dirPA_15
#             └── func_taskrest_16
#
# 10 directories, 0 files

# %% [markdown]
# ## 2. Convert DICOMS to BIDS-formatted NIfTI
#
# ### 2.1. Using dcm2niix (manual workflow)
#
# `dcm2niix` converts neuroimaging data from the DICOM format to the NIfTI format and generates a BIDS JSON format sidecar which includes relevant information. However, users need to manually organize these files into a bids-compliant subject directory.
#
# #### 2.1.1. Convert DICOM to NIfTI

# %%
import module
await module.load('dcm2niix/v1.0.20240202')

# %%
# !dcm2niix -h
# Out:
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC8.4.0 x86-64 (64-bit Linux)
# usage: dcm2niix [options] <in_folder>
#  Options :
#   -1..-9 : gz compression level (1=fastest..9=smallest, default 6)
#   -a : adjacent DICOMs (images from same series always in same folder) for faster conversion (n/y, default n)
#   -b : BIDS sidecar (y/n/o [o=only: no NIfTI], default y)
#    -ba : anonymize BIDS (y/n, default y)
#   -c : comment stored in NIfTI aux_file (up to 24 characters e.g. '-c VIP', empty to anonymize e.g. 0020,4000 e.g. '-c ""')
#   -d : directory search depth. Convert DICOMs in sub-folders of in_folder? (0..9, default 5)
#   -e : export as NRRD (y) or MGH (o) or JSON/JNIfTI (j) or BJNIfTI (b) instead of NIfTI (y/n/o/j/b, default n)
#   -f : filename (%a=antenna (coil) name, %b=basename, %c=comments, %d=description, %e=echo number, %f=folder name, %g=accession number, %i=ID of patient, %j=seriesInstanceUID, %k=studyInstanceUID, %m=manufacturer, %n=name of patient, %o=mediaObjectInstanceUID, %p=protocol, %r=instance number, %s=series number, %t=time, %u=acquisition number, %v=vendor, %x=study ID; %z=sequence name; default '%f_%p_%t_%s')
#   -g : generate defaults file (y/n/o/i [o=only: reset and write defaults; i=ignore: reset defaults], default n)
#   -h : show help
#   -i : ignore derived, localizer and 2D images (y/n, default n)
#   -l : losslessly scale 16-bit integers to use dynamic range (y/n/o [yes=scale, no=no, but uint16->int16, o=original], default o)
#   -m : merge 2D slices from same series regardless of echo, exposure, etc. (n/y or 0/1/2, default 2) [no, yes, auto]
#   -n : only convert this series CRC number - can be used up to 16 times (default convert all)
#   -o : output directory (omit to save to input folder)
#   -p : Philips precise float (not display) scaling (y/n, default y)
#   -q : only search directory for DICOMs (y/l/n, default y) [y=show number of DICOMs found, l=additionally list DICOMs found, n=no]
#   -r : rename instead of convert DICOMs (y/n, default n)
#   -s : single file mode, do not convert other images in folder (y/n, default n)
#   -u : up-to-date check
#   -v : verbose (n/y or 0/1/2, default 0) [no, yes, logorrheic]
#   -w : write behavior for name conflicts (0,1,2, default 2: 0=skip duplicates, 1=overwrite, 2=add suffix)
#   -x : crop 3D acquisitions (y/n/i, default n, use 'i'gnore to neither crop nor rotate 3D acquistions)
#   -z : gz compress images (y/o/i/n/3, default n) [y=pigz, o=optimal pigz, i=internal:zlib, n=no, 3=no,3D]
#   --big-endian : byte order (y/n/o, default o) [y=big-end, n=little-end, o=optimal/native]
#   --progress : Slicer format progress information (y/n, default n)
#   --ignore_trigger_times : disregard values in 0018,1060 and 0020,9153
#   --terse : omit filename post-fixes (can cause overwrites)
#   --version : report version
#   --xml : Slicer format features
#  Defaults file : /home/jovyan/.dcm2nii.ini
#  Examples :
#   dcm2niix /Users/chris/dir
#   dcm2niix -c "my comment" /Users/chris/dir
#   dcm2niix -o /users/cr/outdir/ -z y ~/dicomdir
#   dcm2niix -f %p_%s -b y -ba n ~/dicomdir
#   dcm2niix -f mystudy%s ~/dicomdir
#   dcm2niix -o "~/dir with spaces/dir" ~/dicomdir
# Example output filename: 'myFolder_MPRAGE_19770703150928_1.nii'

# %%
# !mkdir dcm2niix_bids
# !dcm2niix n -o ./dcm2niix_bids ./heudiconv-reproin-example/REPROIN/dicom
# Out:
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC8.4.0 x86-64 (64-bit Linux)
# Found 791 DICOM file(s)
# Slices not stacked: orientation varies (vNav or localizer?) [0.0964069 0.780133 0.618141 0.0553476 0.615871 -0.7859] != [-0.522168 0.736033 0.430808 0.0695744 0.540223 -0.838641]
# Convert 2 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00001 (162x162x2x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00004 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00003 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_3_i00002 (162x162x1x1)
# Convert 128 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_1 (160x160x128x1)
# Convert 128 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_2 (160x160x128x1)
# Convert 4 DICOM as ./dcm2niix_bids/dicom_func_task-rest_20190208142838_16 (64x64x44x4)
# Convert 132 DICOM as ./dcm2niix_bids/dicom_fmap_dir-PA_20190208142838_15 (122x122x66x2)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_4_i00001 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_4_i00003 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_4_i00002 (162x162x1x1)
# Convert 16 DICOM as ./dcm2niix_bids/dicom_dwi_dir-AP_20190208142838_9 (122x122x66x16)
# Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# Convert 44 DICOM as ./dcm2niix_bids/dicom_fmap_acq-4mm_20190208142838_7_e1 (64x64x44x1)
# Convert 44 DICOM as ./dcm2niix_bids/dicom_fmap_acq-4mm_20190208142838_7_e2 (64x64x44x1)
# Convert 240 DICOM as ./dcm2niix_bids/dicom_anat-T1w_acq-MPRAGE_20190208142838_6 (224x224x240x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_5_i00003 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_5_i00002 (162x162x1x1)
# Convert 1 DICOM as ./dcm2niix_bids/dicom_anat-scout_20190208142838_5_i00001 (162x162x1x1)
# Convert 44 DICOM as ./dcm2niix_bids/dicom_fmap_acq-4mm_20190208142838_8_e2_ph (64x64x44x1)
# Conversion required 1.111782 seconds (1.107384 for core code).

# %% [markdown]
# #### 2.1.2. Organize data into BIDS structure

# %%
# %%bash
# mkdir -p ./dcm2niix_bids/anat
# mkdir -p ./dcm2niix_bids/fmap
# mkdir -p ./dcm2niix_bids/dwi
# mkdir -p ./dcm2niix_bids/func
#
# find ./dcm2niix_bids -maxdepth 1 -type f -name *anat* -exec mv {} ./dcm2niix_bids/anat \;
# find ./dcm2niix_bids -maxdepth 1 -type f -name *fmap* -exec mv {} ./dcm2niix_bids/fmap \;
# find ./dcm2niix_bids -maxdepth 1 -type f -name *dwi* -exec mv {} ./dcm2niix_bids/dwi \;
# find ./dcm2niix_bids -maxdepth 1 -type f -name *func* -exec mv {} ./dcm2niix_bids/func \;

# %%
# !tree ./dcm2niix_bids/
# Out:
# ./dcm2niix_bids/
# ├── anat
# │   ├── dicom_anat-T1w_acq-MPRAGE_20190208142838_6.json
# │   ├── dicom_anat-T1w_acq-MPRAGE_20190208142838_6.nii
# │   ├── dicom_anat-scout_20190208142838_1.json
# │   ├── dicom_anat-scout_20190208142838_1.nii
# │   ├── dicom_anat-scout_20190208142838_2.json
# │   ├── dicom_anat-scout_20190208142838_2.nii
# │   ├── dicom_anat-scout_20190208142838_3_i00001.json
# │   ├── dicom_anat-scout_20190208142838_3_i00001.nii
# │   ├── dicom_anat-scout_20190208142838_3_i00002.json
# │   ├── dicom_anat-scout_20190208142838_3_i00002.nii
# │   ├── dicom_anat-scout_20190208142838_3_i00003.json
# │   ├── dicom_anat-scout_20190208142838_3_i00003.nii
# │   ├── dicom_anat-scout_20190208142838_3_i00004.json
# │   ├── dicom_anat-scout_20190208142838_3_i00004.nii
# │   ├── dicom_anat-scout_20190208142838_4_i00001.json
# │   ├── dicom_anat-scout_20190208142838_4_i00001.nii
# │   ├── dicom_anat-scout_20190208142838_4_i00002.json
# │   ├── dicom_anat-scout_20190208142838_4_i00002.nii
# │   ├── dicom_anat-scout_20190208142838_4_i00003.json
# │   ├── dicom_anat-scout_20190208142838_4_i00003.nii
# │   ├── dicom_anat-scout_20190208142838_5_i00001.json
# │   ├── dicom_anat-scout_20190208142838_5_i00001.nii
# │   ├── dicom_anat-scout_20190208142838_5_i00002.json
# │   ├── dicom_anat-scout_20190208142838_5_i00002.nii
# │   ├── dicom_anat-scout_20190208142838_5_i00003.json
# │   └── dicom_anat-scout_20190208142838_5_i00003.nii
# ├── dwi
# │   ├── dicom_dwi_dir-AP_20190208142838_9.bval
# │   ├── dicom_dwi_dir-AP_20190208142838_9.bvec
# │   ├── dicom_dwi_dir-AP_20190208142838_9.json
# │   └── dicom_dwi_dir-AP_20190208142838_9.nii
# ├── fmap
# │   ├── dicom_fmap_acq-4mm_20190208142838_7_e1.json
# │   ├── dicom_fmap_acq-4mm_20190208142838_7_e1.nii
# │   ├── dicom_fmap_acq-4mm_20190208142838_7_e2.json
# │   ├── dicom_fmap_acq-4mm_20190208142838_7_e2.nii
# │   ├── dicom_fmap_acq-4mm_20190208142838_8_e2_ph.json
# │   ├── dicom_fmap_acq-4mm_20190208142838_8_e2_ph.nii
# │   ├── dicom_fmap_dir-PA_20190208142838_15.bval
# │   ├── dicom_fmap_dir-PA_20190208142838_15.bvec
# │   ├── dicom_fmap_dir-PA_20190208142838_15.json
# │   └── dicom_fmap_dir-PA_20190208142838_15.nii
# └── func
#     ├── dicom_func_task-rest_20190208142838_16.json
#     └── dicom_func_task-rest_20190208142838_16.nii
#
# 4 directories, 42 files

# %% [markdown]
# ### 2.2. Using HeuDiConv (automated workflow)
# Typical use of heudiconv will require the creation and editing of your heuristics file.
#
# But heudiconv also comes with existing heuristics which can be used as is, like `convertall` or `ReproIn` could be immediately reused and represent two ends of the spectrum in heuristics:
# - `convertall` is very simple and does not automate anything – it is for a user to modify filenames in the prepared conversion table, and then rerun with `-c dcm2niix`
# - `reproin` can be used fully automated, if original sequences were named according to its ReproIn convention.

# %%
await module.load('heudiconv/1.3.1')

# %%
# !heudiconv -f reproin -b -o ./heudiconv_reproin_bids --files ./heudiconv-reproin-example/REPROIN/dicom/001
# Out:
# WARNING: Could not check for version updates: Connection to server could not be made
# INFO: Running heudiconv version 1.3.1 latest Unknown
# INFO: Analyzing 791 dicoms
# INFO: Filtering out 0 dicoms based on their filename
# INFO: Generated sequence info for 1 studies with 11 entries total
# INFO: Processing sequence infos to deduce study/session
# INFO: Study session for StudySessionInfo(locator='Patterson/Coben', session=None, subject='001')
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': '001', 'outdir': '/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben', 'session': None}
# INFO: Processing 11 pre-sorted seqinfo entries
# INFO: Processing 11 seqinfo entries
# WARNING: Deduced datatype to be dwi from DICOM, but got fmap out of fmap_dir-PA
# WARNING: Detected 4 duplicated run(s) for template {bids_subject_session_dir}/anat/{bids_subject_session_prefix}_scout: ['1-anat-scout', '2-anat-scout', '3-anat-scout', '4-anat-scout']
# INFO: Doing conversion using dcm2niix
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_scout (3 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w (240 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 250604-04:53:43,861 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixe0jqya2u/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixe0jqya2u/convert".
# 250604-04:53:43,967 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 250604-04:53:45,832 nipype.interface INFO:
# 	 stdout 2025-06-04T04:53:45.832322:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2025-06-04T04:53:45.832322:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 250604-04:53:45,832 nipype.interface INFO:
# 	 stdout 2025-06-04T04:53:45.832322:Found 240 DICOM file(s)
# INFO: stdout 2025-06-04T04:53:45.832322:Found 240 DICOM file(s)
# 250604-04:53:45,832 nipype.interface INFO:
# 	 stdout 2025-06-04T04:53:45.832322:Convert 240 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv597 (224x224x240x1)
# INFO: stdout 2025-06-04T04:53:45.832322:Convert 240 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv597 (224x224x240x1)
# 250604-04:53:46,451 nipype.interface INFO:
# 	 stdout 2025-06-04T04:53:46.451063:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv597.nii"
# INFO: stdout 2025-06-04T04:53:46.451063:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w_heudiconv597.nii"
# 250604-04:53:46,451 nipype.interface INFO:
# 	 stdout 2025-06-04T04:53:46.451063:Conversion required 0.892119 seconds (0.441830 for core code).
# INFO: stdout 2025-06-04T04:53:46.451063:Conversion required 0.892119 seconds (0.441830 for core code).
# 250604-04:53:46,477 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.95058s.
# INFO: [Node] Finished "convert", elapsed time 0.95058s.
# 250604-04:54:10,535 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta2vnpngal/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta2vnpngal/embedder".
# 250604-04:54:10,552 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 250604-04:54:17,920 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 7.367169s.
# INFO: [Node] Finished "embedder", elapsed time 7.367169s.
# INFO: Post-treating /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_acq-MPRAGE_T1w.json file
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude (88 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 250604-04:54:17,955 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixsuxlzhm1/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixsuxlzhm1/convert".
# 250604-04:54:18,7 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 250604-04:54:18,121 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.121339:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2025-06-04T04:54:18.121339:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 250604-04:54:18,121 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.121339:Found 88 DICOM file(s)
# INFO: stdout 2025-06-04T04:54:18.121339:Found 88 DICOM file(s)
# 250604-04:54:18,121 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.121339:Slices not stacked: echo varies (TE 7.38, 4.92; echo 2, 1). Use 'merge 2D slices' option to force stacking
# INFO: stdout 2025-06-04T04:54:18.121339:Slices not stacked: echo varies (TE 7.38, 4.92; echo 2, 1). Use 'merge 2D slices' option to force stacking
# 250604-04:54:18,121 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.121339:Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e2 (64x64x44x1)
# INFO: stdout 2025-06-04T04:54:18.121339:Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e2 (64x64x44x1)
# 250604-04:54:18,145 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.145303:Compress: "/usr/bin/pigz" -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e2.nii"
# INFO: stdout 2025-06-04T04:54:18.145303:Compress: "/usr/bin/pigz" -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e2.nii"
# 250604-04:54:18,145 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.145303:Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e1 (64x64x44x1)
# INFO: stdout 2025-06-04T04:54:18.145303:Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e1 (64x64x44x1)
# 250604-04:54:18,159 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.159344:Compress: "/usr/bin/pigz" -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e1.nii"
# INFO: stdout 2025-06-04T04:54:18.159344:Compress: "/usr/bin/pigz" -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_magnitude_heudiconv873_e1.nii"
# 250604-04:54:18,159 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:18.159344:Conversion required 0.104805 seconds (0.069369 for core code).
# INFO: stdout 2025-06-04T04:54:18.159344:Conversion required 0.104805 seconds (0.069369 for core code).
# 250604-04:54:18,194 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.185947s.
# INFO: [Node] Finished "convert", elapsed time 0.185947s.
# WARNING: For now not embedding BIDS and info generated .nii.gz itself since sequence produced multiple files
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff (44 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 250604-04:54:18,984 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixhzwgarat/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixhzwgarat/convert".
# 250604-04:54:19,9 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 250604-04:54:19,82 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:19.081871:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2025-06-04T04:54:19.081871:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 250604-04:54:19,82 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:19.081871:Found 44 DICOM file(s)
# INFO: stdout 2025-06-04T04:54:19.081871:Found 44 DICOM file(s)
# 250604-04:54:19,82 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:19.081871:Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv959_e2_ph (64x64x44x1)
# INFO: stdout 2025-06-04T04:54:19.081871:Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv959_e2_ph (64x64x44x1)
# 250604-04:54:19,95 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:19.095543:Compress: "/usr/bin/pigz" -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv959_e2_ph.nii"
# INFO: stdout 2025-06-04T04:54:19.095543:Compress: "/usr/bin/pigz" -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff_heudiconv959_e2_ph.nii"
# 250604-04:54:19,95 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:19.095543:Conversion required 0.042604 seconds (0.029517 for core code).
# INFO: stdout 2025-06-04T04:54:19.095543:Conversion required 0.042604 seconds (0.029517 for core code).
# 250604-04:54:19,124 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.114021s.
# INFO: [Node] Finished "convert", elapsed time 0.114021s.
# 250604-04:54:19,523 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta2m8_717f/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta2m8_717f/embedder".
# 250604-04:54:19,529 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 250604-04:54:20,703 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 1.173789s.
# INFO: [Node] Finished "embedder", elapsed time 1.173789s.
# INFO: Post-treating /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_acq-4mm_phasediff.json file
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi (16 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 250604-04:54:20,718 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix5uudc78e/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix5uudc78e/convert".
# 250604-04:54:20,727 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 250604-04:54:20,861 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:20.861007:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2025-06-04T04:54:20.861007:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 250604-04:54:20,861 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:20.861007:Found 16 DICOM file(s)
# INFO: stdout 2025-06-04T04:54:20.861007:Found 16 DICOM file(s)
# 250604-04:54:20,861 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:20.861007:Convert 16 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv779 (122x122x66x16)
# INFO: stdout 2025-06-04T04:54:20.861007:Convert 16 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv779 (122x122x66x16)
# 250604-04:54:21,233 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:21.233210:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv779.nii"
# INFO: stdout 2025-06-04T04:54:21.233210:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi_heudiconv779.nii"
# 250604-04:54:21,233 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:21.233210:Conversion required 0.466862 seconds (0.161808 for core code).
# INFO: stdout 2025-06-04T04:54:21.233210:Conversion required 0.466862 seconds (0.161808 for core code).
# 250604-04:54:21,263 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.535425s.
# INFO: [Node] Finished "convert", elapsed time 0.535425s.
# 250604-04:54:40,925 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetazcbeirvx/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetazcbeirvx/embedder".
# 250604-04:54:40,929 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 250604-04:54:41,849 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 0.918597s.
# INFO: [Node] Finished "embedder", elapsed time 0.918597s.
# INFO: Post-treating /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/dwi/sub-001_dir-AP_dwi.json file
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi (132 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 250604-04:54:41,873 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixg3fmx3zu/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixg3fmx3zu/convert".
# 250604-04:54:41,932 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 250604-04:54:42,64 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:42.064575:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2025-06-04T04:54:42.064575:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 250604-04:54:42,65 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:42.064575:Found 132 DICOM file(s)
# INFO: stdout 2025-06-04T04:54:42.064575:Found 132 DICOM file(s)
# 250604-04:54:42,65 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:42.064575:Convert 132 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv590 (122x122x66x2)
# INFO: stdout 2025-06-04T04:54:42.064575:Convert 132 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv590 (122x122x66x2)
# 250604-04:54:42,167 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:42.167747:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv590.nii"
# INFO: stdout 2025-06-04T04:54:42.167747:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi_heudiconv590.nii"
# 250604-04:54:42,167 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:42.167747:Conversion required 0.188278 seconds (0.089655 for core code).
# INFO: stdout 2025-06-04T04:54:42.167747:Conversion required 0.188278 seconds (0.089655 for core code).
# 250604-04:54:42,196 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.26308s.
# INFO: [Node] Finished "convert", elapsed time 0.26308s.
# 250604-04:54:44,794 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetadlhpi7tg/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetadlhpi7tg/embedder".
# 250604-04:54:44,806 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 250604-04:54:48,657 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 3.849705s.
# INFO: [Node] Finished "embedder", elapsed time 3.849705s.
# INFO: Post-treating /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/fmap/sub-001_dir-PA_epi.json file
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold (4 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func . Converter: dcm2niix . Output types: ('nii.gz', 'dicom')
# 250604-04:54:48,677 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixqgww5csj/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixqgww5csj/convert".
# 250604-04:54:48,687 nipype.workflow INFO:
# 	 [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# INFO: [Node] Executing "convert" <nipype.interfaces.dcm2nii.Dcm2niix>
# 250604-04:54:48,741 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:48.741404:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# INFO: stdout 2025-06-04T04:54:48.741404:Chris Rorden's dcm2niiX version v1.0.20220720  (JP2:OpenJPEG) (JP-LS:CharLS) GCC10.2.1 x86-64 (64-bit Linux)
# 250604-04:54:48,741 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:48.741404:Found 4 DICOM file(s)
# INFO: stdout 2025-06-04T04:54:48.741404:Found 4 DICOM file(s)
# 250604-04:54:48,741 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:48.741404:Convert 4 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv588 (64x64x44x4)
# INFO: stdout 2025-06-04T04:54:48.741404:Convert 4 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv588 (64x64x44x4)
# 250604-04:54:48,830 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:48.830371:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv588.nii"
# INFO: stdout 2025-06-04T04:54:48.830371:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold_heudiconv588.nii"
# 250604-04:54:48,830 nipype.interface INFO:
# 	 stdout 2025-06-04T04:54:48.830371:Conversion required 0.098970 seconds (0.018073 for core code).
# INFO: stdout 2025-06-04T04:54:48.830371:Conversion required 0.098970 seconds (0.018073 for core code).
# 250604-04:54:48,862 nipype.workflow INFO:
# 	 [Node] Finished "convert", elapsed time 0.173641s.
# INFO: [Node] Finished "convert", elapsed time 0.173641s.
# 250604-04:54:49,113 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta2x3x8h7r/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta2x3x8h7r/embedder".
# 250604-04:54:49,116 nipype.workflow INFO:
# 	 [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# INFO: [Node] Executing "embedder" <nipype.interfaces.utility.wrappers.Function>
# 250604-04:54:49,262 nipype.workflow INFO:
# 	 [Node] Finished "embedder", elapsed time 0.144823s.
# INFO: [Node] Finished "embedder", elapsed time 0.144823s.
# INFO: Post-treating /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/func/sub-001_task-rest_bold.json file
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-01 (128 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-02 (128 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-03 (5 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Converting /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat/sub-001_scout__dup-04 (3 DICOMs) -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001/anat . Converter: dcm2niix . Output types: ('dicom',)
# INFO: Adding "IntendedFor" to the fieldmaps in /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben/sub-001.
# INFO: Populating template files under /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben
# INFO: PROCESSING DONE: {'subject': '001', 'outdir': '/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv_reproin_bids/Patterson/Coben', 'session': None}

# %% [markdown]
# ### 2.3. Using bidscoin (automated workflow)
#
# BIDScoin requires the source data repository to be organized according to a `subject/[session]/data` structure where `data` folder can be structured in DICOM series layout, DICOMDIR layout, flat DICOM layout. Refer to [this doc](https://bidscoin.readthedocs.io/en/stable/preparation.html) for more details.
#
# To perform BIDS conversion, run:
#
# - (1a) `bidsmapper` command
# - once `bidsmapper` finishes, it automatically launches (1b) the `bidseditor`. *Note*: The `--automated` flag skips the manual editing step with bidseditor
# - (2) `bidscoiner` command
#
# ![image.png](https://bidscoin.readthedocs.io/en/stable/_images/bidsmap_flow.png)

# %%
import module
await module.load('bidscoin/4.3.3')

# %%
# %%bash
# mkdir bidscoin_bids
# bidsmapper ./heudiconv-reproin-example/REPROIN/dicom ./bidscoin_bids --subprefix '00' --sesprefix 'Patterson_Coben' --automated  # Scans your data and creates a study bidsmap non-interactively
# bidscoiner ./heudiconv-reproin-example/REPROIN/dicom ./bidscoin_bids    # Converts your data to BIDS using the study bidsmap
# Out:
# INFO |
# INFO | -------------- START BIDSmapper ------------
# INFO | >>> bidsmapper sourcefolder=/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom bidsfolder=/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids bidsmap=bidsmap.yaml template=/home/jovyan/.bidscoin/4.3.3+qt5/templates/bidsmap_dccn.yaml plugins=[] subprefix=00 sesprefix=Patterson_Coben store=False force=False
# INFO | No existing bidsmap file found: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/code/bidscoin/bidsmap.yaml
# INFO | Reading: /home/jovyan/.bidscoin/4.3.3+qt5/templates/bidsmap_dccn.yaml
# INFO | Checking the bidsmap run-items:
# SUCCESS | All datatypes and options in the template bidsmap are valid
# INFO | Mapping: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1 (subject 1/1)
# VERBOSE | Executing plugin: dcm2niix2bids -> /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1
# INFO | Discovered 'exclude' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4/IM-0012-0001-0001.dcm
# INFO | Discovered 'anat' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6/IM-0001-0001.dcm
# INFO | Discovered 'dwi' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/dwi_dirAP_9/IM-0004-0001.dcm
# INFO | Discovered 'fmap' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_7/IM-0002-0001-0001.dcm
# INFO | Discovered 'fmap' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8/IM-0003-0001.dcm
# INFO | Discovered 'fmap' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15/IM-0010-0001.dcm
# INFO | Discovered 'func' DICOM sample: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16/IM-0011-0001.dcm
# INFO | Checking the bidsmap run-items:            ]/1 [00:00<00:00,  3.22subject/s]
# SUCCESS | All run-items in the bidsmap are valid
# INFO | bids-validator 1.14.6 test results (* = in .bidsignore):
# INFO | False:	exclude/sub-DICOM_task-anatscoutMPRcor_acq-anatscout_echo-1_GR.*
# SUCCESS | All generated bidsnames are BIDS-valid
# INFO | Writing bidsmap to: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/code/bidscoin/bidsmap.yaml
# INFO | -------------- FINISHED! -------------------
# INFO |
# SUCCESS | No BIDScoin errors or warnings were reported
# INFO |
# INFO | For the complete log see: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/code/bidscoin/bidsmapper.log
# NB: That folder may contain privacy sensitive information, e.g. pathnames in logfiles and provenance data samples
# INFO |
# INFO | -------------- START BIDScoiner 4.3.3+qt5: BIDS 1.9.0 ------------
# INFO | >>> bidscoiner sourcefolder=/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom bidsfolder=/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids participant=None force=False bidsmap=bidsmap.yaml
# INFO | Creating dataset description file: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/dataset_description.json
# INFO | Creating a template README file (adjust it to your needs): /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/README
# INFO | Reading: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/code/bidscoin/bidsmap.yaml
# INFO | Checking the bidsmap run-items:
# SUCCESS | All run-items in the bidsmap are valid
# INFO | ------------------- Subject 1/1 -------------------
# INFO | >>> Coining datasources in: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1
# VERB                                      ubject/s]OSE | Executing plugin: dcm2niix2bids
# INFO | --> Leaving out: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/Localizers_4
# INFO | --> Coining: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6
# VERBOSE | Command:                        ubject/s]
# dcm2niix -b y -z y -i n -l n -f "sub-1_ses-1_acq-anatT1wacqMPRAGE_T1w" -o "/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/anat" "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/anatT1w_acqMPRAGE_6"
# VERBOSE | Output:                         ubject/s]
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC12.2.0 x86-64 (64-bit Linux)
# Found 240 DICOM file(s)
# Convert 240 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/anat/sub-1_ses-1_acq-anatT1wacqMPRAGE_T1w (224x224x240x1)
# Conversion required 1.576807 seconds (1.574546 for core code).
#
# INFO | --> Coining: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/dwi_dirAP_9
# VERBOSE | Command:                        ubject/s]
# dcm2niix -b y -z y -i n -l n -f "sub-1_ses-1_acq-dwidirAP_dir-AP_dwi" -o "/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/dwi" "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/dwi_dirAP_9"
# VERBOSE | Output:                         ubject/s]
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC12.2.0 x86-64 (64-bit Linux)
# Found 16 DICOM file(s)
# Convert 16 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/dwi/sub-1_ses-1_acq-dwidirAP_dir-AP_dwi (122x122x66x16)
# Conversion required 1.527986 seconds (1.524680 for core code).
#
# INFO | --> Coining: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_7
# VERBOSE | Command:                        ubject/s]
# dcm2niix -b y -z y -i n -l n -f "sub-1_ses-1_acq-fmapacq4mm_magnitude1" -o "/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap" "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_7"
# VERBOSE | Output:                         ubject/s]
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC12.2.0 x86-64 (64-bit Linux)
# Found 88 DICOM file(s)
# Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1_e1 (64x64x44x1)
# Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1_e2 (64x64x44x1)
# Conversion required 0.101947 seconds (0.101925 for core code).
#
# VERBOSE | Found dcm2niix ['e1'] postfixes, renaming
# /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1_e1.nii.gz ->
# /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1.nii.gz
# VERBOSE | Found dcm2niix ['e2'] postfixes, renaming
# /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1_e2.nii.gz ->
# /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude2.nii.gz
# INFO | --> Coining: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8
# VERBOSE | Command:                        ubject/s]
# dcm2niix -b y -z y -i n -l n -f "sub-1_ses-1_acq-fmapacq4mm_phasediff" -o "/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap" "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_acq4mm_8"
# VERBOSE | Output:                         ubject/s]
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC12.2.0 x86-64 (64-bit Linux)
# Found 44 DICOM file(s)
# Convert 44 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_phasediff_e2_ph (64x64x44x1)
# Conversion required 0.047804 seconds (0.047796 for core code).
#
# VERBOSE | Found dcm2niix ['e2', 'ph'] postfixes, renaming
# /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_phasediff_e2_ph.nii.gz ->
# /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_phasediff.nii.gz
# INFO | --> Coining: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15
# VERBOSE | Command:                        ubject/s]
# dcm2niix -b y -z y -i n -l n -f "sub-1_ses-1_acq-fmapdirPA_fieldmap" -o "/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap" "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/fmap_dirPA_15"
# VERBOSE | Output:                         ubject/s]
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC12.2.0 x86-64 (64-bit Linux)
# Found 132 DICOM file(s)
# Convert 132 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapdirPA_fieldmap (122x122x66x2)
# Conversion required 0.297794 seconds (0.297726 for core code).
#
# INFO | --> Coining: /home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16
# VERBOSE | Command:                        ubject/s]
# dcm2niix -b y -z y -i n -l n -f "sub-1_ses-1_task-functaskrest_dir-AP_bold" -o "/home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/func" "/home/jovyan/Git_repositories/example-notebooks/books/workflows/heudiconv-reproin-example/REPROIN/dicom/001/Patterson_Coben - 1/func_taskrest_16"
# VERBOSE | Output:                         ubject/s]
# Chris Rorden's dcm2niiX version v1.0.20240202  (JP2:OpenJPEG) (JP-LS:CharLS) GCC12.2.0 x86-64 (64-bit Linux)
# Found 4 DICOM file(s)
# Convert 4 DICOM as /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/func/sub-1_ses-1_task-functaskrest_dir-AP_bold (64x64x44x4)
# Conversion required 0.073761 seconds (0.073719 for core code).
#
# VERBOSE | Writing acquisition time data to: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/sub-1_ses-1_scans.tsv
# VERBOSE | Writing sub-1 subject data to: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/participants.tsv
# VERBOSE | Writing subject meta data to: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/participants.json
# WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1.json (i.e. the fieldmap may not be used)
# WARN                                      ubject/s]ING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude2.json (i.e. the fieldmap may not be used)
# WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_phasediff.json (i.e. the fieldmap may not be used)
# WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapdirPA_fieldmap.json (i.e. the fieldmap may not be used)
# INFO | --------------                             ]:03<00:00,  3.96s/subject]FINISHED! ------------
# INFO |
# INFO | The following BIDScoin errors and warnings were reported:
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 2025-06-04 05:31:50 - WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude1.json (i.e. the fieldmap may not be used)
# 2025-06-04 05:31:50 - WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_magnitude2.json (i.e. the fieldmap may not be used)
# 2025-06-04 05:31:50 - WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapacq4mm_phasediff.json (i.e. the fieldmap may not be used)
# 2025-06-04 05:31:50 - WARNING | Empty IntendedFor/B0FieldSource/B0FieldIdentifier fieldmap values in /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/sub-1/ses-1/fmap/sub-1_ses-1_acq-fmapdirPA_fieldmap.json (i.e. the fieldmap may not be used)
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# INFO | For the complete log see: /home/jovyan/Git_repositories/example-notebooks/books/workflows/bidscoin_bids/code/bidscoin/bidscoiner.log
# NB: That folder may contain privacy sensitive information, e.g. pathnames in logfiles and provenance data samples

# %%
# !tree ./bidscoin_bids/
# Out:
# ./bidscoin_bids/
# ├── README
# ├── code
# │   └── bidscoin
# │       ├── bidscoiner.errors
# │       ├── bidscoiner.log
# │       ├── bidscoiner.tsv
# │       ├── bidsmap.yaml
# │       ├── bidsmapper.errors
# │       └── bidsmapper.log
# ├── dataset_description.json
# ├── participants.json
# ├── participants.tsv
# └── sub-1
#     └── ses-1
#         ├── anat
#         │   ├── sub-1_ses-1_acq-anatT1wacqMPRAGE_T1w.json
#         │   └── sub-1_ses-1_acq-anatT1wacqMPRAGE_T1w.nii.gz
#         ├── dwi
#         │   ├── sub-1_ses-1_acq-dwidirAP_dir-AP_dwi.bval
#         │   ├── sub-1_ses-1_acq-dwidirAP_dir-AP_dwi.bvec
#         │   ├── sub-1_ses-1_acq-dwidirAP_dir-AP_dwi.json
#         │   └── sub-1_ses-1_acq-dwidirAP_dir-AP_dwi.nii.gz
#         ├── fmap
#         │   ├── sub-1_ses-1_acq-fmapacq4mm_magnitude1.json
#         │   ├── sub-1_ses-1_acq-fmapacq4mm_magnitude1.nii.gz
#         │   ├── sub-1_ses-1_acq-fmapacq4mm_magnitude2.json
#         │   ├── sub-1_ses-1_acq-fmapacq4mm_magnitude2.nii.gz
#         │   ├── sub-1_ses-1_acq-fmapacq4mm_phasediff.json
#         │   ├── sub-1_ses-1_acq-fmapacq4mm_phasediff.nii.gz
#         │   ├── sub-1_ses-1_acq-fmapdirPA_fieldmap.bval
#         │   ├── sub-1_ses-1_acq-fmapdirPA_fieldmap.bvec
#         │   ├── sub-1_ses-1_acq-fmapdirPA_fieldmap.json
#         │   └── sub-1_ses-1_acq-fmapdirPA_fieldmap.nii.gz
#         ├── func
#         │   ├── sub-1_ses-1_task-functaskrest_dir-AP_bold.json
#         │   └── sub-1_ses-1_task-functaskrest_dir-AP_bold.nii.gz
#         └── sub-1_ses-1_scans.tsv
#
# 8 directories, 29 files
