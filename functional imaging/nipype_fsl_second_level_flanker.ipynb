# %% [markdown]
# <a href="https://hub.play-sydney.neurodesk.org/user/neurodesk-example-notebooks-toudo5lh/lab/workspaces/auto-4/tree/functional%20imaging/nipype_fsl_second_level_flanker.ipynb" target="_parent"><img src="https://img.shields.io/badge/launch-binder-579aca.svg?logo=data:image/png;base64,..." alt="Open In Binder"/>  </a>
# <a href="https://colab.research.google.com/github/NeuroDesk/example-notebooks/blob/main/functional%20imaging/nipype_fsl_second_level_flanker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>   </a>

# %% [markdown]
# Author: Monika Doerig
#
# Original peper: https://www.frontiersin.org/articles/10.3389/fnimg.2022.953215/full
#
# Original code: https://osf.io/prg53/?view_only=9d7974834a484cdb972bcc3989589b78

# %% [markdown]
# ## Setup Neurodesk

# %%
# %%capture
import os
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  os.environ["LD_PRELOAD"] = "";
  os.environ["APPTAINER_BINDPATH"] = "/content"
  os.environ["MPLCONFIGDIR"] = "/content/matplotlib-mpldir"
  os.environ["LMOD_CMD"] = "/usr/share/lmod/lmod/libexec/lmod"

  # !curl -J -O https://raw.githubusercontent.com/NeuroDesk/neurocommand/main/googlecolab_setup.sh
  # !chmod +x googlecolab_setup.sh
  # !./googlecolab_setup.sh

  os.environ["MODULEPATH"] = ':'.join(map(str, list(map(lambda x: os.path.join(os.path.abspath('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/'), x),os.listdir('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/')))))

# %% [markdown]
# # Second level GLM using Nipype FSL
#
# In this notebook, we recreate the second-level GLM of FSL GUI using nipype code. For each nipype node, we list the corresponding fsl command from the log file. The dataset we use is a Flanker task, which can be downloaded [here](https://openneuro.org/datasets/ds000102/versions/00001).
#
# We also borrow some helps from this [document](https://nipype.readthedocs.io/en/latest/users/examples/fmri_fsl.html).

# %%
#load fsl module
import lmod
await lmod.purge(force=True)
await lmod.load('fsl/6.0.5.1')
await lmod.list()
# Out:
# ['fsl/6.0.5.1']

# %%
import os
os.environ["FSLDIR"]="/cvmfs/neurodesk.ardc.edu.au/containers/fsl_6.0.5.1_20221016/fsl_6.0.5.1_20221016.simg/opt/fsl-6.0.5.1/"
os.environ["FSLOUTPUTTYPE"]="NIFTI_GZ"

# %% [markdown]
# ## Preparation
# Import all the relevant libraries needed for the preprocessing stage.

# %%
from __future__ import print_function
from __future__ import division
from builtins import str
from builtins import range

import os, stat  # system functions
import getpass
from glob import glob

import numpy as np
from nipype import Function
from nipype.interfaces import fsl, utility as util, io as nio
import nipype.pipeline.engine as pe  # pypeline engine
import nipype.algorithms.modelgen as model  # model generation
import nipype.algorithms.rapidart as ra  # artifact detection

# %% [markdown]
# #### Set up data path

# %%
# adapted code
# Input: Set path of first level outputs
data_dir = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/'
# Output: Set path where nipype will store stepwise results
exp_dir = '/neurodesktop-storage/Data/Flanker/output_level2/'

# %% [markdown]
# #### Start the workflow

# %%
wf = pe.Workflow(name='level2', base_dir=exp_dir)
wf.config["execution"]["crashfile_format"] = "txt"

# %% [markdown]
# The following two nodes (`infosource` & `dg`) together define all inputs required for the preprocessing workflow

# %%
# we want to group the outcome by contrast not subject
contr_list = [1,2,3,4]
infosource = pe.Node(util.IdentityInterface(fields=["contr_id"]),
                  name="infosource")
infosource.iterables = [("contr_id", contr_list)]

# %%
# here we use SelectFiles, instead of DataGrabber, because the former is more flexible with formatting syntax
templates = {
    "reg_copes":"*/reg_copes/*/*/cope{contr_id}_flirt.nii.gz",
    "reg_varcopes":"*/reg_varcopes/*/*/varcope{contr_id}_flirt.nii.gz",
    "reg_masks":"*/reg_masks/*/*/*.nii.gz"
}
dg = pe.Node(interface=nio.SelectFiles(templates),
             name="selectfiles")
dg.inputs.base_directory = data_dir

wf.connect([
        (infosource, dg, [("contr_id", "contr_id")])
])

# %% [markdown]
# ## Second-level GLM
#
# Combining results from multiple runs of one subject into one

# %% [markdown]
# ### Higher-level input files preparation

# %% [markdown]
# #### Step 1: Merge registered copes & varcopes & masks
#
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmerge -t mask (masks from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t cope (copes from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t varcop (varcopes from all 52 inputs)
# ```

# %%
copemerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskmerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="maskmerge")


def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i, [])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles



wf.connect(dg, 'reg_copes', copemerge, 'in_files')
wf.connect(dg, 'reg_varcopes', varcopemerge, 'in_files')
wf.connect(dg, 'reg_masks', maskmerge, 'in_files')

# %% [markdown]
# #### Step 2: Making mask
#
# In FSL, there are many commands about `maskunique`, which is unless for the second level. We can ignore it.
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
# ```

# %%
minmask = pe.Node(
    interface=fsl.ImageMaths(op_string='-Tmin'),
    iterfield=['in_file'],
    name='minmask')

wf.connect(maskmerge, 'merged_file', minmask, 'in_file')

# %% [markdown]
# #### Step 3: Masking copes & varcopes
#
# **Corresponding FSL command:**
#
# we have four contrasts so the following commands repeat four times
#
# ```
# /usr/local/fsl/bin/fslmaths cope1 -mas mask cope1
# /usr/local/fsl/bin/fslmaths varcope1 -mas mask varcope1
# ```

# %%
maskcope = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskcope')

maskvarcope = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskvarcope')

wf.connect(copemerge, 'merged_file', maskcope, 'in_file')
wf.connect(minmask, 'out_file', maskcope, 'in_file2')
wf.connect(varcopemerge, 'merged_file', maskvarcope, 'in_file')
wf.connect(minmask, 'out_file', maskvarcope, 'in_file2')

# %% [markdown]
# ### Set up second-level contrasts and fixed-effects

# %%
def get_contrasts_l2(in_files):
    import numpy as np
    total = len(in_files)
    print(in_files)
    print(total)
    n_sub = 26
    ev_list = ['ev'+str(x) for x in range(1,n_sub+1)]
    weight_mtx = np.zeros((26,26))
    weight_mtx = weight_mtx.astype(np.float64)
    np.fill_diagonal(weight_mtx,1.)
    #contr = ['','T',ev_list,list(weight_mtx[0])] --> original paper
    contr = np.array(['','T', ev_list, list(weight_mtx[0])], dtype=object) #adaptation so the construction of the array works
    contr_lst = np.tile(contr, (n_sub, 1))
    contr_lst = [list(x) for x in contr_lst]
    for i in range(n_sub):
        contr_lst[i][3] = list(weight_mtx[i])

    reg_dict = {k:None for k in ev_list}
    for k in reg_dict.keys():
        start_lst = [0.0] * total
        idx = ev_list.index(k)
        start_idx = idx*2
        end_idx = idx*2 + 1
        start_lst[start_idx] = 1.
        start_lst[end_idx] = 1.
        reg_dict[k] = start_lst
        
    return contr_lst, reg_dict

contrastgen_l2 = pe.Node(util.Function(input_names=['in_files'],
                                    output_names=['contr_lst', 'reg_dict'],
                                    function=get_contrasts_l2),
                      iterfield=['in_files'],
                      name='contrastgen_l2')

wf.connect(dg,'reg_copes', contrastgen_l2, 'in_files')

# %% [markdown]
# Nipype recommands using [L2Model](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#l2model), which only works for the single subject. It takes the number of runs (copes at the first level) as input and does estimations for subject one by one.
# Instead, we use [MultipleRegressDesign](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#multipleregressdesign). As it's name indicates, this one can deal with multiple predictors (subjects) at the same time.

# %%
level2model = pe.Node(interface=fsl.MultipleRegressDesign(),
                      name='l2model')

wf.connect([(contrastgen_l2, level2model, [('contr_lst','contrasts'),
                                        ('reg_dict','regressors')])])

# %%
level2estimate = pe.Node(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="level2estimate",
    iterfield=['cope_file', 'var_cope_file'])

wf.connect([
    (maskcope, level2estimate, [('out_file', 'cope_file')]),
    (maskvarcope, level2estimate, [('out_file', 'var_cope_file')]),
    (minmask, level2estimate, [('out_file', 'mask_file')]),
    (level2model, level2estimate, [('design_mat', 'design_file'),
                                   ('design_con', 't_con_file'), 
                                   ('design_grp', 'cov_split_file')]),
])

# %%
datasink = pe.Node(nio.DataSink(), name='sinker')
datasink.inputs.base_directory=os.path.join(exp_dir, "level2_results")

int2string = lambda x: 'contrast_'+str(x)
    
wf.connect(infosource, ('contr_id',int2string), datasink, 'container')
wf.connect([(level2estimate, datasink, [('stats_dir', 'stats_dir')])])

# %%
# Create 1st-level analysis output graph
wf.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=os.path.join(wf.base_dir, wf.name, 'graph.png'))
# Out:
# 230605-08:50:43,31 nipype.workflow INFO:
# 	 Generated workflow graph: /neurodesktop-storage/Data/Flanker/output_level2/level2/graph.png (graph2use=colored, simple_form=True).

# %%
# Run Workflow
wf.run(plugin="MultiProc", plugin_args={"n_procs": 8})
# Out:
# 230605-08:50:51,190 nipype.workflow INFO:
# 	 Workflow level2 settings: ['check', 'execution', 'logging', 'monitoring']
# 230605-08:50:51,255 nipype.workflow INFO:
# 	 Running in parallel.
# 230605-08:50:51,316 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 219.50/219.50, Free processors: 8/8.
# 230605-08:50:51,464 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/selectfiles".
# 230605-08:50:51,467 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/selectfiles".
# 230605-08:50:51,469 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/selectfiles".
# 230605-08:50:51,471 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/selectfiles".
# 230605-08:50:51,548 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 230605-08:50:51,548 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 230605-08:50:51,549 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 230605-08:50:51,549 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 230605-08:50:51,569 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.016752s.
# 230605-08:50:51,569 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.016912s.
# 230605-08:50:51,569 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.016219s.
# 230605-08:50:51,569 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.016199s.
# 230605-08:50:53,319 nipype.workflow INFO:
# 	 [Job 0] Completed (level2.selectfiles).
# 230605-08:50:53,323 nipype.workflow INFO:
# 	 [Job 1] Completed (level2.selectfiles).
# 230605-08:50:53,324 nipype.workflow INFO:
# 	 [Job 2] Completed (level2.selectfiles).
# 230605-08:50:53,325 nipype.workflow INFO:
# 	 [Job 3] Completed (level2.selectfiles).
# 230605-08:50:53,327 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 219.50/219.50, Free processors: 8/8.
# 230605-08:50:53,455 nipype.workflow INFO:
# 	 [Job 4] Cached (level2.copemerge).
# 230605-08:50:53,462 nipype.workflow INFO:
# 	 [Job 5] Cached (level2.varcopemerge).
# 230605-08:50:53,468 nipype.workflow INFO:
# 	 [Job 6] Cached (level2.maskmerge).
# 230605-08:50:53,473 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:53,484 nipype.workflow INFO:
# 	 [Job 8] Cached (level2.copemerge).
# 230605-08:50:53,481 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/contrastgen_l2".
# 230605-08:50:53,486 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:53,492 nipype.workflow INFO:
# 	 [Job 9] Cached (level2.varcopemerge).
# 230605-08:50:53,493 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l2" <nipype.interfaces.utility.wrappers.Function>
# 230605-08:50:53,501 nipype.workflow INFO:
# 	 [Job 10] Cached (level2.maskmerge).
# ['/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope1_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope1_flirt.nii.gz', ...
# 52
# 230605-08:50:53,506 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:53,506 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.010587s.
# 230605-08:50:53,510 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/contrastgen_l2".
# 230605-08:50:53,524 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:53,535 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l2" <nipype.interfaces.utility.wrappers.Function>
# ['/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope2_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope2_flirt.nii.gz', ...
# 52
# 230605-08:50:53,547 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.00586s.
# 230605-08:50:55,320 nipype.workflow INFO:
# 	 [Job 7] Completed (level2.contrastgen_l2).
# 230605-08:50:55,322 nipype.workflow INFO:
# 	 [Job 11] Completed (level2.contrastgen_l2).
# 230605-08:50:55,324 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 219.50/219.50, Free processors: 8/8.
# 230605-08:50:55,380 nipype.workflow INFO:
# 	 [Job 12] Cached (level2.copemerge).
# 230605-08:50:55,387 nipype.workflow INFO:
# 	 [Job 13] Cached (level2.varcopemerge).
# 230605-08:50:55,392 nipype.workflow INFO:
# 	 [Job 14] Cached (level2.maskmerge).
# 230605-08:50:55,397 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:55,405 nipype.workflow INFO:
# 	 [Job 16] Cached (level2.copemerge).
# 230605-08:50:55,402 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/contrastgen_l2".
# 230605-08:50:55,406 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:55,411 nipype.workflow INFO:
# 	 [Job 17] Cached (level2.varcopemerge).
# 230605-08:50:55,413 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l2" <nipype.interfaces.utility.wrappers.Function>
# ['/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope3_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope3_flirt.nii.gz', ...
# 	 [Job 18] Cached (level2.maskmerge).
#
# 52
# 230605-08:50:55,422 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:55,421 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.005335s.
# 230605-08:50:55,424 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/contrastgen_l2".
# 230605-08:50:55,427 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.contrastgen_l2".
# 230605-08:50:55,431 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l2" <nipype.interfaces.utility.wrappers.Function>
# ['/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope4_flirt.nii.gz', '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope4_flirt.nii.gz', ...
# 52
# 230605-08:50:55,439 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l2", elapsed time 0.005321s.
# 230605-08:50:57,322 nipype.workflow INFO:
# 	 [Job 15] Completed (level2.contrastgen_l2).
# 230605-08:50:57,323 nipype.workflow INFO:
# 	 [Job 19] Completed (level2.contrastgen_l2).
# 230605-08:50:57,325 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 219.50/219.50, Free processors: 8/8.
# 230605-08:50:57,406 nipype.workflow INFO:
# 	 [Job 20] Cached (level2.minmask).
# 230605-08:50:57,434 nipype.workflow INFO:
# 	 [Job 21] Cached (level2.l2model).
# 230605-08:50:57,439 nipype.workflow INFO:
# 	 [Job 22] Cached (level2.minmask).
# 230605-08:50:57,464 nipype.workflow INFO:
# 	 [Job 23] Cached (level2.l2model).
# 230605-08:50:57,481 nipype.workflow INFO:
# 	 [Job 24] Cached (level2.minmask).
# 230605-08:50:57,506 nipype.workflow INFO:
# 	 [Job 25] Cached (level2.l2model).
# 230605-08:50:57,522 nipype.workflow INFO:
# 	 [Job 26] Cached (level2.minmask).
# 230605-08:50:57,550 nipype.workflow INFO:
# 	 [Job 27] Cached (level2.l2model).
# 230605-08:50:59,400 nipype.workflow INFO:
# 	 [Job 28] Cached (level2.maskcope).
# 230605-08:50:59,404 nipype.workflow INFO:
# 	 [Job 29] Cached (level2.maskvarcope).
# 230605-08:50:59,426 nipype.workflow INFO:
# 	 [Job 30] Cached (level2.maskcope).
# 230605-08:50:59,444 nipype.workflow INFO:
# 	 [Job 31] Cached (level2.maskvarcope).
# 230605-08:50:59,449 nipype.workflow INFO:
# 	 [Job 32] Cached (level2.maskcope).
# 230605-08:50:59,453 nipype.workflow INFO:
# 	 [Job 33] Cached (level2.maskvarcope).
# 230605-08:50:59,457 nipype.workflow INFO:
# 	 [Job 34] Cached (level2.maskcope).
# 230605-08:50:59,461 nipype.workflow INFO:
# 	 [Job 35] Cached (level2.maskvarcope).
# 230605-08:51:01,326 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 219.50/219.50, Free processors: 8/8.
# 230605-08:51:01,411 nipype.workflow INFO:
# 	 [Job 36] Cached (level2.level2estimate).
# 230605-08:51:01,431 nipype.workflow INFO:
# 	 [Job 37] Cached (level2.level2estimate).
# 230605-08:51:01,438 nipype.workflow INFO:
# 	 [Job 38] Cached (level2.level2estimate).
# 230605-08:51:01,444 nipype.workflow INFO:
# 	 [Job 39] Cached (level2.level2estimate).
# 230605-08:51:03,416 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_1/sinker".
# 230605-08:51:03,422 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230605-08:51:03,430 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_2/sinker".
# 230605-08:51:03,435 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230605-08:51:03,465 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_3/sinker".
# 230605-08:51:03,469 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230605-08:51:03,470 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/neurodesktop-storage/Data/Flanker/output_level2/level2/_contr_id_4/sinker".
# 230605-08:51:03,475 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230605-08:51:05,330 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 218.70/219.50, Free processors: 4/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
# 230605-08:51:20,654 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 17.181548s.
# 230605-08:51:21,288 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 17.86444s.
# 230605-08:51:21,347 nipype.workflow INFO:
# 	 [Job 40] Completed (level2.sinker).
# 230605-08:51:21,348 nipype.workflow INFO:
# 	 [Job 42] Completed (level2.sinker).
# 230605-08:51:21,350 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 219.10/219.50, Free processors: 6/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
# 230605-08:51:21,549 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 18.071604s.
# 230605-08:51:21,644 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 18.206745s.
# 230605-08:51:23,349 nipype.workflow INFO:
# 	 [Job 41] Completed (level2.sinker).
# 230605-08:51:23,350 nipype.workflow INFO:
# 	 [Job 43] Completed (level2.sinker).
# 230605-08:51:23,352 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 219.50/219.50, Free processors: 8/8.

# %% [markdown]
# ## The second-level GLM
#
# Here we choose the four copes from subject-22
#
# ### Regapply
#
# This happens before the second-level GLM, all results from the first level are needed to be registered into the standard space
#
# copes from subject-22, run-2

# %%
# %%capture
conda install -c conda-forge nilearn
conda install -c conda-forge matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

import nilearn
from nilearn import surface
from nilearn import plotting

fsaverage = nilearn.datasets.fetch_surf_fsaverage()
plotting.show()

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/22/reg_copes/_subject_id_22/_warpfunc1/cope1_flirt.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/22/reg_copes/_subject_id_22/_warpfunc1/cope2_flirt.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/22/reg_copes/_subject_id_22/_warpfunc1/cope3_flirt.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level1/level1_results/22/reg_copes/_subject_id_22/_warpfunc1/cope4_flirt.nii.gz'

# %%
plotting.plot_stat_map(nipype_cope1, bg_img=nipype_cope1, title = 'Nipype - COPE1', cmap = 'bwr', colorbar = False)

plotting.plot_stat_map(nipype_cope2, bg_img=nipype_cope2, title = 'Nipype - COPE2', cmap = 'bwr', colorbar = False)

plotting.plot_stat_map(nipype_cope3, bg_img=nipype_cope3, title = 'Nipype - COPE3', cmap = 'bwr', colorbar = False)

plotting.plot_stat_map(nipype_cope4, bg_img=nipype_cope4, title = 'Nipype - COPE4', cmap = 'bwr', colorbar = False)
plt.show()

# %% [markdown]
# ### Copes from the second-level GLM
#
# copes from subject-22

# %%
nipype_cope1 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_1/stats_dir/_contr_id_1/stats/cope22.nii.gz'
nipype_cope2 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_2/stats_dir/_contr_id_2/stats/cope22.nii.gz'
nipype_cope3 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_3/stats_dir/_contr_id_3/stats/cope22.nii.gz'
nipype_cope4 = '/neurodesktop-storage/Data/Flanker/output_level2/level2_results/contrast_4/stats_dir/_contr_id_4/stats/cope22.nii.gz'

# %%
plotting.plot_glass_brain(nipype_cope1, bg_img=nipype_cope1, title = 'Nipype - COPE1')
plotting.plot_glass_brain(nipype_cope2, bg_img=nipype_cope2, title = 'Nipype - COPE2')
plotting.plot_glass_brain(nipype_cope3, bg_img=nipype_cope3, title = 'Nipype - COPE3')
plotting.plot_glass_brain(nipype_cope4, bg_img=nipype_cope4, title = 'Nipype - COPE4')
plt.show()
